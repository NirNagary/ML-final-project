# %%
tickers = [
    "MSFT", "AAPL", "NVDA", "AMZN", "GOOGL", "META", "BRK.B", "LLY",
    "TSM", "AVGO", "TSLA", "V", "NVO", "JPM", "WMT", "UNH", "MA", "XOM",
    "ASML", "JNJ", "HD", "PG", "COST", "TM", "AMD", "MRK", "ABBV", "ORCL",
    "CRM", "CVX", "BAC", "NFLX", "ADBE", "KO", "ACN", "PEP", "FMX", "SAP",
    "TMO", "LIN", "MCD", "NVS", "ABT", "DIS", "SHEL", "AZN", "WFC", "CSCO",
    "TMUS", "DHR", "BABA", "INTU", "INTC", "QCOM", "AMAT", "GE", "IBM", "CMCSA",
    "VZ", "PDD", "UBER", "CAT", "AXP", "NOW", "TXN", "BX", "NKE", "UNP", "TTE",
    "AMGN", "PFE", "HSBC", "BHP", "MS", "LOW", "ISRG", "PM", "HDB", "RY", "SPGI",
    "COP", "SYK", "HON", "LRCX", "GS", "UPS", "PLD", "MUFG", "UL", "BA", "T",
    "BLK", "SCHW", "BUD", "BKNG", "RTX", "SNY", "ETN", "ELV", "NEE", "TJX", "VRTX",
    "MDT", "PGR", "SONY","FMC", "CIVI", "UI", "AZEK", "YMM", "RHP", "BZ", "TKO",
    "NYT", "GPS", "ALTR", "NFE", "XRAY", "CCCS", "SPSC", "STAG",
    "IVZ", "HAS", "DAR", "RMBS", "HQY", "RGLD", "ICL", "BILL",
    "VOYA", "CFR", "ITCI", "ENSG", "MAT", "FOUR", "GNRC", "THO",
    "BRX", "IBP", "WTS", "CGNX", "CHRD", "CACC", "AAON", "BERY",
    "MMYT", "LBTYK", "ALSN", "CBSH", "EXEL", "NOV", "ADT", "BFAM",
    "CRSP", "HRB", "MTZ", "MASI", "MTSI", "RLI", "DDS", "LSTR",
    "AGNC", "WFG", "STWD", "VNT", "IONS", "CAVA", "ANF", "OGE",
    "OLN", "CMA", "LYFT", "UGP", "AM", "VNOM", "CART", "ARW",
    "TNET", "CR", "SFM", "CSAN", "KVYO", "ATKR", "AN", "POST",
    "HXL", "VFC", "SIGI", "ATI", "BROS", "NOVT", "ALGM", "GTLS",
    "BBIO", "HLNE", "SSB", "FLR", "CMC", "KGC", "BYD", "PNFP",
    "WAL", "QLYS", "NE", "MUR", "NEU", "REYN", "WH", "NSIT",
    "TMHC", "CHX", "G", "GXO", "FAF", "ELP", "FRSH", "CAE",
    "MARA", "DRS", "BC", "ESAB", "MNSO", "BPOP", "LFUS", "WTFC",
    "ALTM", "TKR", "RRR", "GRFS", "OBDC", "CIGI", "RCM", "SMAR",
    "FYBR", "MLI", "GIL", "WHR", "FTAI", "OMF", "PBF", "BPMC",
    "PB", "BLCO", "MTH", "CIG", "ENLC", "ZION", "TRNO", "ESNT",
    "ESI", "ADC", "BRZE", "LANC", "TENB", "MSM","MXCT", "BALY", "SRI", "IVVD", "BWMN", "EQBK", "SD", "DJCO",
    "ATLC", "LSEA", "DENN", "SMBC", "GUTS", "ASLE", "CCBG", "VPG",
    "LWLG", "OFIX", "AEON", "LIND", "LND", "MTW", "CTLP", "RSVR",
    "ABUS", "AMNB", "NN", "LAND", "FPH", "HCAT", "ESPR", "JOUT",
    "ALNT", "RXT", "CATX", "GCBC", "ANNX", "RGP", "EGY", "TPB",
    "ZH", "VTRU", "DGICA", "CWCO", "RCEL", "CLFD", "DGICB", "AXGN",
    "ZIMV", "ALCC", "TRDA", "ADTN", "HONE", "CAC", "SRDX", "AVAH",
    "HAFC", "AURA", "STTK", "MCS", "TBPH", "TGB", "KODK", "TERN",
    "HTBI", "MGX", "NTGR", "NFBK", "TRC", "BETR", "ORC", "GDEV",
    "URG", "RDZN", "WTI", "PNNT", "GHRS", "GATO", "EHAB", "GLAD",
    "TSAT", "MED", "BBCP", "BLZE", "CELC", "XERS", "SVM", "MVIS",
    "WASH", "GLRE", "IVR", "AVNW", "ANSC", "OCS", "OSG", "DHIL",
    "EAF", "THFF", "CVRX", "SLAM", "AVXL", "AMRN", "CRMT", "FFWM",
    "DCGO", "OLP", "AUDC", "ALRS", "BTMD", "GDOT", "NYXH", "SPFI",
    "FBLG", "ACRE", "PGC", "CLOV", "CCG", "DOMO", "MCB", "PGEN",
    "NPCE", "ONEW", "NVEC", "EPIX", "LYTS", "FARO", "TMC", "GFR",
    "ESQ", "THRD", "CCNE", "PBPB", "NBN", "STRW", "FSBC", "BHRB",
    "LXEO", "IAUX", "LAW", "MGTX", "RMR", "NGNE", "AROW", "GBLI",
    "ACTG", "INZY", "ITOS", "STEM", "ARMN", "MODV", "NCMI", "ANRO",
    "NETD", "VALU", "HRZN", "OPY", "VNET", "SGU", "ZYXI", "OSPN"
]

# %%
import requests
import json

# Your Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'

# The URL for the stocks endpoint
url = 'https://api.twelvedata.com/stocks'

# Parameters for the API request
params = {
    'apikey': api_key
}

# Make the GET request to the Twelve Data API
response = requests.get(url, params=params)

# Initialize a counter for numbering the US stocks
counter = 1

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    data = response.json()
    
    # Check if 'data' key is in response (as expected format)
    if 'data' in data:
        # Loop through each stock in the response
        for stock in data['data']:
            # Check if the stock is from the United States
            if stock.get('country') == 'United States':
                # Print the numbered list of US stocks
                print(f"{counter}. Symbol: {stock['symbol']}, Name: {stock['name']}, Currency: {stock['currency']}, Exchange: {stock['exchange']}, Country: {stock['country']}, Type: {stock['type']}")
                # Increment the counter
                counter += 1
    else:
        # If 'data' key is not in response, print the whole response (for debugging)
        print(json.dumps(data, indent=4))
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}, Response: {response.text}")
# Out:
# 1. Symbol: A, Name: Agilent Technologies, Inc., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 2. Symbol: AA, Name: Alcoa Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 3. Symbol: AAALY, Name: Aareal Bank AG, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 4. Symbol: AABB, Name: Asia Broadband, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 5. Symbol: AABVF, Name: Aberdeen International Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 6. Symbol: AACAF, Name: AAC Technologies Holdings Inc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 7. Symbol: AACAY, Name: AAC Technologies Holdings Inc, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 8. Symbol: AACG, Name: ATA Creativity Global, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Depositary Receipt
# 9. Symbol: AACI, Name: Armada Acquisition Corp. I, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 10. Symbol: AACIU, Name: Armada Acquisition Corp. I Unit, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 11. Symbol: AACIW, Name: Armada Acquisition Corp. I, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 12. Symbol: AACS, Name: American Commerce Solutions, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 13. Symbol: AACT, Name: Ares Acquisition Corporation II Class A Ordinary Shares, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 14. Symbol: AACTF, Name: Aurora Solar Technologies Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 15. Symbol: AADI, Name: Aadi Bioscience, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 16. Symbol: AAEEF, Name: Altair Res Inc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 17. Symbol: AAFRF, Name: Airtel Africa Plc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 18. Symbol: AAGC, Name: All American Gold Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 19. Symbol: AAGFF, Name: Aftermath Silver Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20. Symbol: AAGH, Name: America Great Health, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 21. Symbol: AAGIY, Name: AIA Group, Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 22. Symbol: AAGR, Name: African Agriculture Holdings Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 23. Symbol: AAGRW, Name: African Agriculture Holdings Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 24. Symbol: AAHIF, Name: Asahi Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 25. Symbol: AAIGF, Name: AIA Group, Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 26. Symbol: AAIRF, Name: American Aires Inc,, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 27. Symbol: AAL, Name: American Airlines Group Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 28. Symbol: AALBF, Name: A. Alberts Industries, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 29. Symbol: AAMAF, Name: Atlas Mara Co Nvest Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 30. Symbol: AAMC, Name: Altisource Asset Management Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 31. Symbol: AAME, Name: Atlantic American Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 32. Symbol: AAMMF, Name: Almadex Minerals Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 33. Symbol: AAMTF, Name: Armada Mercantile Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 34. Symbol: AAN, Name: Aaron's Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 35. Symbol: AANNF, Name: Aroundtown SA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 36. Symbol: AAOI, Name: Applied Optoelectronics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 37. Symbol: AAON, Name: AAON Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 38. Symbol: AAP, Name: Advance Auto Parts Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 39. Symbol: AAPI, Name: Apple iSports Group Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 40. Symbol: AAPJ, Name: AAP, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 41. Symbol: AAPL, Name: Apple Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 42. Symbol: AAPT, Name: All American Pet Company, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 43. Symbol: AAPX, Name: ETF Opportunities Trust T-Rex 2X Long Apple Daily Target ETF, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 44. Symbol: AAQL, Name: Antiaging Quantum Living Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 45. Symbol: AARTY, Name: AIRTEL AFRICA PLC, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 46. Symbol: AASP, Name: All-American SportPark, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 47. Symbol: AASZF, Name: Atlantic Sapphire ASA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 48. Symbol: AAT, Name: American Assets Trust Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: REIT
# 49. Symbol: AATC, Name: Autoscope Technologies Corporation, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 50. Symbol: AATGD, Name: ATI Airtest Technologies Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 51. Symbol: AATGF, Name: ATI Airtest Technologies Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 52. Symbol: AATRL, Name: AMG Capital Trust II, Currency: USD, Exchange: OTC, Country: United States, Type: Preferred Stock
# 53. Symbol: AATV, Name: Adaptive Ad Systems, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 54. Symbol: AAU, Name: Almaden Minerals Ltd, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 55. Symbol: AAUCF, Name: ALLIED GOLD CORP., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 56. Symbol: AAUGF, Name: Angold Resources Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 57. Symbol: AAUKF, Name: Anglo American plc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 58. Symbol: AAVMY, Name: Abn Amro BK N V, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 59. Symbol: AAVVF, Name: Advantage Oil & Gas Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 60. Symbol: AAVXF, Name: Abivax SA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 61. Symbol: AAWH, Name: Ascend Wellness Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 62. Symbol: AAXT, Name: Aamaxan Transport Group, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 63. Symbol: AB, Name: AllianceBernstein Holding LP, Currency: USD, Exchange: NYSE, Country: United States, Type: Limited Partnership
# 64. Symbol: ABAKF, Name: Aberdeen Asia-Pacific Income Investment Co. Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 65. Symbol: ABANF, Name: Automatic Bank Services Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 66. Symbol: ABAT, Name: American Battery Technology Co., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 67. Symbol: ABBAF, Name: Aberdeen Asian Income Fund, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 68. Symbol: ABBB, Name: Auburn Bancorp, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 69. Symbol: ABBNY, Name: ABB LTD SPONS ADR, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 70. Symbol: ABBRF, Name: AbraPlata Resource Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 71. Symbol: ABBV, Name: AbbVie Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 72. Symbol: ABBY, Name: Abby, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 73. Symbol: ABC, Name: AmerisourceBergen Corporation, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 74. Symbol: ABCAF, Name: Athabasca Minerals Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 75. Symbol: ABCB, Name: Ameris Bancorp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 76. Symbol: ABCE, Name: ABCO Energy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 77. Symbol: ABCFF, Name: Abacus Mining & Exploration Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 78. Symbol: ABCL, Name: AbCellera Biologics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 79. Symbol: ABCP, Name: AmBase Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 80. Symbol: ABCZF, Name: Abcam PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 81. Symbol: ABDDF, Name: Ab Dynamics PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 82. Symbol: ABEC, Name: Analytica Bio-Energy Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 83. Symbol: ABEO, Name: Abeona Therapeutics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 84. Symbol: ABEPF, Name: Vision Lithium Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 85. Symbol: ABEV, Name: Ambev SA, Currency: USD, Exchange: NYSE, Country: United States, Type: Depositary Receipt
# 86. Symbol: ABFRF, Name: Aberforth Smaller Companies Trust PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 87. Symbol: ABG, Name: Asbury Automotive Group Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 88. Symbol: ABGOF, Name: Abengoa S.A., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 89. Symbol: ABGSF, Name: ABG Sundal Collier Holding ASA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 90. Symbol: ABHBY, Name: ALFEN BEHEER B V UNSPN ADS ECH REP 1 ORD SHS, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 91. Symbol: ABILF, Name: Ability Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 92. Symbol: ABIO, Name: ARCA biopharma Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 93. Symbol: ABIT, Name: Athena Bitcoin Global, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 94. Symbol: ABL, Name: Abacus Life Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 95. Symbol: ABLE, Name: Able Energy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 96. Symbol: ABLLL, Name: Abacus Life, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Exchange-Traded Note
# 97. Symbol: ABLT, Name: American Biltrite, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 98. Symbol: ABLV, Name: Able View Global Inc. - Class B Ordinary Shares, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 99. Symbol: ABLZF, Name: ABB Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 100. Symbol: ABM, Name: ABM Industries Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 101. Symbol: ABMBF, Name: Abcourt Mines Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 102. Symbol: ABMC, Name: American Bio Medica Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 103. Symbol: ABMRF, Name: ABN Amro Group NV, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 104. Symbol: ABMT, Name: Advanced BioMedical Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 105. Symbol: ABNAF, Name: Aben Resources, Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 106. Symbol: ABNB, Name: Airbnb, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 107. Symbol: ABNC, Name: American Bancorp, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 108. Symbol: ABOIF, Name: ABOITIZ EQUITY VENTURES INC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 109. Symbol: ABOS, Name: Acumen Pharmaceuticals, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 110. Symbol: ABPR, Name: Airborne Security & Protective Services, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 111. Symbol: ABQQ, Name: AB INTL Group Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 112. Symbol: ABR, Name: Arbor Realty Trust Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: REIT
# 113. Symbol: ABR-D, Name: Arbor Realty Trust 6.375% Serie, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 114. Symbol: ABR-E, Name: Arbor Realty Trust 6.25% Series, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 115. Symbol: ABRMF, Name: ARBOR METALS CORP., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 116. Symbol: ABR.PR.D, Name: Arbor Realty Trust, Inc., Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 117. Symbol: ABR.PR.E, Name: Arbor Realty Trust, Inc., Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 118. Symbol: ABR.PR.F, Name: Arbor Realty Trust 6.25% Series, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 119. Symbol: ABSCF, Name: AB Science, Paris, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 120. Symbol: ABSI, Name: Absci Corporation, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 121. Symbol: ABSOF, Name: ABS-CBN Holdings Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 122. Symbol: ABSSF, Name: AirBoss of America Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 123. Symbol: ABT, Name: Abbott Laboratories, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 124. Symbol: ABTI, Name: Alterola Biotech, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 125. Symbol: ABTO, Name: AB&T Financial Corp. (NC), Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 126. Symbol: ABTS, Name: Abits Group Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 127. Symbol: ABTZY, Name: Aboitiz Equity Ventures, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 128. Symbol: ABUS, Name: Arbutus Biopharma Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 129. Symbol: ABVC, Name: American BriVision (Holding) Corporation, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 130. Symbol: ABVG, Name: Affinity Beverage Group, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 131. Symbol: ABVN, Name: ABV Consulting Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 132. Symbol: ABVX, Name: Abivax SA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Depositary Receipt
# 133. Symbol: ABWN, Name: Airborne Wireless Network, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 134. Symbol: ABXXF, Name: Abaxx Technologies Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 135. Symbol: ABZPF, Name: Aboitiz Power Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 136. Symbol: ABZPY, Name: Aboitiz Power Corp., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 137. Symbol: ABZT, Name: ABLAZE TECHNOLOGIES INC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 138. Symbol: ABZUF, Name: Abzu Gold, Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 139. Symbol: AC, Name: Associated Capital Group Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 140. Symbol: ACA, Name: Arcosa Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 141. Symbol: ACAB, Name: Atlantic Coastal Acquisition Corp. II, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 142. Symbol: ACABU, Name: Atlantic Coastal Acquisition Corp II, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 143. Symbol: ACABW, Name: Atlantic Coastal Acquisition Corp. II, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 144. Symbol: ACAC, Name: Acies Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 145. Symbol: ACACU, Name: Acri Capital Acquisition Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 146. Symbol: ACACW, Name: Acri Capital Acquisition Corporation, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 147. Symbol: ACAD, Name: ACADIA Pharmaceuticals Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 148. Symbol: ACAH, Name: Atlantic Coastal Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 149. Symbol: ACAHU, Name: Atlantic Coastal Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 150. Symbol: ACAI, Name: Safeplus International Holdings Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 151. Symbol: ACAN, Name: Americann Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 152. Symbol: ACAVF, Name: ACE Aviation Holdings Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 153. Symbol: ACAX, Name: Alset Capital Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 154. Symbol: ACAXR, Name: Alset Capital Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 155. Symbol: ACAXW, Name: Alset Capital Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 156. Symbol: ACAZF, Name: Acadian Timber Corp, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 157. Symbol: ACB, Name: Aurora Cannabis Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 158. Symbol: ACBA, Name: Ace Global Business Acquisition Limited, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 159. Symbol: ACBAU, Name: Ace Global Business Acquisition Limited, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 160. Symbol: ACBAW, Name: Ace Global Business Acquisition Limited, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 161. Symbol: ACBCQ, Name: Albina Community Bancorp, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 162. Symbol: ACBD, Name: Annabidiol Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 163. Symbol: ACBM, Name: Acro Biomedical Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 164. Symbol: ACCA, Name: Acacia Diversified Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 165. Symbol: ACCD, Name: Accolade Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 166. Symbol: ACCFF, Name: Accord Financial Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 167. Symbol: ACCMF, Name: AAC Clyde Space AB , Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 168. Symbol: ACCO, Name: ACCO Brands Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 169. Symbol: ACCR, Name: Access-Power & Co Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 170. Symbol: ACCYY, Name: Accor SA Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 171. Symbol: ACDC, Name: ProFrac Holding Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 172. Symbol: ACDSF, Name: Ascendas Real Estate Investment Trust, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 173. Symbol: ACDVF, Name: Air Canada, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 174. Symbol: ACDXF, Name: AMERICAN COPPER DEV CORP, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 175. Symbol: ACEHF, Name: Ace Hardware Indonesia Tbk, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 176. Symbol: ACEJF, Name: Acea Spar, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 177. Symbol: ACEL, Name: Accel Entertainment Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 178. Symbol: ACET, Name: Adicet Bio, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 179. Symbol: ACEYY, Name: Acer Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 180. Symbol: ACFL, Name: AMC Financial Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 181. Symbol: ACFN, Name: Acorn Energy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 182. Symbol: ACGBF, Name: Agricultural Bank of China, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 183. Symbol: ACGBY, Name: Agricultural Bank of China, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 184. Symbol: ACGI, Name: Amacore Group, Inc. (The), Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 185. Symbol: ACGJ, Name: ACI Global Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 186. Symbol: ACGL, Name: Arch Capital Group Ltd, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 187. Symbol: ACGLN, Name: Arch Capital Group Ltd., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 188. Symbol: ACGLO, Name: Arch Capital Group Ltd, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Preferred Stock
# 189. Symbol: ACGX, Name: Alliance Creative Group, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 190. Symbol: ACGYF, Name: Subsea 7 S.A., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 191. Symbol: ACHC, Name: Acadia Healthcare Co Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 192. Symbol: ACHFF, Name: Arch Biopartners Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 193. Symbol: ACHL, Name: Achilles Therapeutics plc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 194. Symbol: ACHR, Name: Archer Aviation Inc., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 195. Symbol: ACHV, Name: Achieve Life Sciences Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 196. Symbol: ACI, Name: Albertsons Cos Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 197. Symbol: ACIC, Name: American Coastal Insurance Corporation, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 198. Symbol: ACIU, Name: AC Immune SA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 199. Symbol: ACIW, Name: ACI Worldwide Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 200. Symbol: ACIXF, Name: ACARIX AB, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 201. Symbol: ACJJF, Name: Acom Co. Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 202. Symbol: ACKAY, Name: Arcelik  A.S., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 203. Symbol: ACKDF, Name: Auckland International Airport Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 204. Symbol: ACKRF, Name: American Creek Resources, Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 205. Symbol: ACLEW, Name: ALTERNUS CLEAN ENERGY INC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 206. Symbol: ACLH, Name: Act Clean Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 207. Symbol: ACLHF, Name: Acme Lithium Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 208. Symbol: ACLIF, Name: ACCELLERON INDUSTRIES AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 209. Symbol: ACLLF, Name: Atco Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 210. Symbol: ACLLY, Name: Accelleron Industries AG, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 211. Symbol: ACLS, Name: Axcelis Technologies Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 212. Symbol: ACLTF, Name: Atco Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 213. Symbol: ACLX, Name: Arcellx, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 214. Symbol: ACM, Name: AECOM, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 215. Symbol: ACMB, Name: Agro Capital Management Corp, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 216. Symbol: ACMDY, Name: Atlas Consolidated Mining & Development Corp., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 217. Symbol: ACMR, Name: ACM Research Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 218. Symbol: ACMT, Name: ACMAT Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 219. Symbol: ACMTA, Name: ACMAT Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 220. Symbol: ACN, Name: Accenture PLC, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 221. Symbol: ACNB, Name: ACNB Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 222. Symbol: ACNDF, Name: Ascendas India Trust, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 223. Symbol: ACNE, Name: Alice Consolidated Mines, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 224. Symbol: ACNFF, Name: Amsterdam Commodities N.V., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 225. Symbol: ACNI, Name: American Community Newspapers, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 226. Symbol: ACNNF, Name: AusCann Group Holdings Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 227. Symbol: ACNT, Name: Ascent Industries Co., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 228. Symbol: ACNV, Name: Accelera Innovations, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 229. Symbol: ACOGF, Name: Alpha Cognition Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 230. Symbol: ACON, Name: Aclarion, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 231. Symbol: ACONW, Name: Aclarion, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 232. Symbol: ACOPF, Name: A2 Milk Co Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 233. Symbol: ACOPY, Name: The A2 Milk Co Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 234. Symbol: ACOR, Name: Acorda Therapeutics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 235. Symbol: ACP-A, Name: Abrdn Income Credit Strategies Fund, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 236. Symbol: ACP.PR.A, Name: Aberdeen Income Credit Strategies Fund, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 237. Symbol: ACPRF, Name: ARCPACIFIC RES CORP., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 238. Symbol: ACR, Name: ACRES Commercial Realty Corp., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 239. Symbol: ACRB, Name: Asia Carbon Industries, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 240. Symbol: ACR-C, Name: ACRES Commercial Realty Corp. 8, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 241. Symbol: ACR-D, Name: ACRES Commercial Realty Corp. 7, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 242. Symbol: ACRDF, Name: Acreage Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 243. Symbol: ACRE, Name: Ares Commercial Real Estate Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: REIT
# 244. Symbol: ACRFF, Name: Accor SA Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 245. Symbol: ACRG, Name: American Clean Resources Group Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 246. Symbol: ACRHF, Name: Acreage Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 247. Symbol: ACRL, Name: Atacama Resources International, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 248. Symbol: ACR.PR.C, Name: ACRES Commercial Realty Corp., Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 249. Symbol: ACR.PR.D, Name: ACRES Commercial Realty Corp., Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 250. Symbol: ACRS, Name: Aclaris Therapeutics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 251. Symbol: ACRU, Name: AMERICREW INC., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 252. Symbol: ACRV, Name: Acrivon Therapeutics, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 253. Symbol: ACRX, Name: AcelRx Pharmaceuticals Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 254. Symbol: ACRXF, Name: ACERINOX SA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 255. Symbol: ACSAF, Name: ACS Actividades De Construccion Y Servicios SA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 256. Symbol: ACSAY, Name: ACS Actividades De Construccion Y Servicios SA, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 257. Symbol: ACST, Name: Acasti Pharma Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 258. Symbol: ACSYF, Name: Accsys Technologies PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 259. Symbol: ACTG, Name: Acacia Research Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 260. Symbol: ACTHF, Name: ADURO CLEAN TECHNOLOGIES INC., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 261. Symbol: ACTL, Name: Artec Global Media, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 262. Symbol: ACTX, Name: Advanced Container Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 263. Symbol: ACU, Name: Acme United Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 264. Symbol: ACUR, Name: Acura Pharmaceuticals, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 265. Symbol: ACUS, Name: Acusphere, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 266. Symbol: ACUT, Name: Accustem Sciences Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 267. Symbol: ACVA, Name: ACV Auctions Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 268. Symbol: ACWRF, Name: Acceleware Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 269. Symbol: ACXIF, Name: Acciona S.A., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 270. Symbol: ACXP, Name: Acurx Pharmaceuticals, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 271. Symbol: ADAD, Name: Adaiah Distribution Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 272. Symbol: ADAG, Name: Adagene Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 273. Symbol: ADAP, Name: Adaptimmune Therapeutics Plc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Depositary Receipt
# 274. Symbol: ADBCF, Name: Adelaide Brighton Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 275. Symbol: ADBE, Name: Adobe Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 276. Symbol: ADBKF, Name: Addiko Bank AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 277. Symbol: ADBN, Name: Americana Distribution, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 278. Symbol: ADBRF, Name: Aldebaran Resources Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 279. Symbol: ADC, Name: Agree Realty Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: REIT
# 280. Symbol: ADCNF, Name: ADICON HLDGS LTD., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 281. Symbol: ADCOF, Name: Adcore Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 282. Symbol: ADC.PR.A, Name: Agree Realty Corporation, Currency: USD, Exchange: NYSE, Country: United States, Type: Preferred Stock
# 283. Symbol: ADCT, Name: ADC Therapeutics SA, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 284. Symbol: ADCV, Name: AD Capital U.S., Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 285. Symbol: ADD, Name: Color Star Technology Co. Ltd., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 286. Symbol: ADDC, Name: Addmaster Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 287. Symbol: ADDDF, Name: adidas AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 288. Symbol: ADDLF, Name: ADDLIFE AB, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 289. Symbol: ADDYY, Name: adidas AG, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 290. Symbol: ADEA, Name: Adeia Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 291. Symbol: ADEC, Name: Alternative Energy Development Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 292. Symbol: ADERY, Name: Aida Engineering Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 293. Symbol: ADES, Name: ADES International Holding PLC, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 294. Symbol: ADEVF, Name: ADEVINTA ASA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 295. Symbol: ADEVY, Name: ADEVINTA ASA, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 296. Symbol: ADFJF, Name: ADF Group Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 297. Symbol: ADFS, Name: American Defense Systems, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 298. Symbol: ADGCF, Name: ADVANCE LITHIUM CORP, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 299. Symbol: ADGI, Name: Adagio Therapeutics, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 300. Symbol: ADGL, Name: AllDigital Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 301. Symbol: ADGO, Name: Advantego Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 302. Symbol: ADHC, Name: American Diversified Holdings Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 303. Symbol: ADHI, Name: Arsenal Digital Holdings Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 304. Symbol: ADHLF, Name: Applied Development Holdings Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 305. Symbol: ADI, Name: Analog Devices Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 306. Symbol: ADIA, Name: Adia Nutrition, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 307. Symbol: ADIL, Name: Adial Pharmaceuticals Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 308. Symbol: ADKT, Name: Adirondack Trust Co. (Saratoga Springs, NY), Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 309. Symbol: ADLDY, Name: Adelaide Brighton Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 310. Symbol: ADLI, Name: American Medical Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 311. Symbol: ADLRF, Name: ALARIS EQUITY PARTNERS INCOME TR       UNIT REG S 3C7, Currency: USD, Exchange: OTC, Country: United States, Type: Unit
# 312. Symbol: ADM, Name: Archer-Daniels-Midland Co, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 313. Symbol: ADMA, Name: ADMA Biologics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 314. Symbol: ADMG, Name: Adamant DRI Processing and Minerals Group, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 315. Symbol: ADMLF, Name: Adriatic Metals PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 316. Symbol: ADMQ, Name: ADM Endeavors Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 317. Symbol: ADMT, Name: ADM Tronics Unlimited, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 318. Symbol: ADMWF, Name: ADMIRAL ACQUISITION LTD, Currency: USD, Exchange: OTC, Country: United States, Type: Warrant
# 319. Symbol: ADN, Name: Advent Technologies Holdings, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 320. Symbol: ADNT, Name: Adient PLC, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 321. Symbol: ADNWW, Name: Advent Technologies Holdings, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 322. Symbol: ADOC, Name: Edoc Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 323. Symbol: ADOCR, Name: Edoc Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 324. Symbol: ADOCW, Name: Edoc Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 325. Symbol: ADOCY, Name: Adocia ACT, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 326. Symbol: ADOOY, Name: Adaro Energy PT, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 327. Symbol: ADP, Name: Automatic Data Processing Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 328. Symbol: ADPPF, Name: Adler Group S.A., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 329. Symbol: ADPT, Name: Adaptive Biotechnologies Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 330. Symbol: ADPXY, Name: Audio Pixels Holdings Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 331. Symbol: ADRNY, Name: Koninklijke Ahold Delhaize N.V., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 332. Symbol: ADRT, Name: Ault Disruptive Technologies Corporation, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 333. Symbol: ADRT.UN, Name: , Currency: USD, Exchange: NYSE, Country: United States, Type: Unit
# 334. Symbol: ADRZF, Name: Andritz AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 335. Symbol: ADRZY, Name: Andritz AG, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 336. Symbol: ADSE, Name: ADS-TEC Energy PLC, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 337. Symbol: ADSEW, Name: ADS-TEC Energy PLC, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 338. Symbol: ADSGF, Name: ADESSO AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 339. Symbol: ADSK, Name: Autodesk Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 340. Symbol: ADST, Name: AdStar, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 341. Symbol: ADSV, Name: Allied Security Innovations, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 342. Symbol: ADT, Name: ADT Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 343. Symbol: ADTC, Name: Advanced Deposition Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 344. Symbol: ADTH, Name: AdTheorent Holding Company, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 345. Symbol: ADTHW, Name: AdTheorent Holding Company, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 346. Symbol: ADTLF, Name: Adriatic Metals PLC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 347. Symbol: ADTN, Name: ADTRAN Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 348. Symbol: ADTTF, Name: Advantest Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 349. Symbol: ADTX, Name: Aditx Therapeutics Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 350. Symbol: ADUS, Name: Addus HomeCare Corp, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 351. Symbol: ADV, Name: Advantage Solutions Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 352. Symbol: ADVM, Name: Adverum Biotechnologies Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 353. Symbol: ADVOF, Name: ADVA AG Optical Networking, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 354. Symbol: ADVT, Name: Advantis Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 355. Symbol: ADVWW, Name: Advantage Solutions Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 356. Symbol: ADVZF, Name: Adventus Mng Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 357. Symbol: ADWPF, Name: Andrew Peller Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 358. Symbol: ADXDF, Name: Adex Mining, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 359. Symbol: ADXN, Name: Addex Therapeutics Ltd, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Depositary Receipt
# 360. Symbol: ADXS, Name: Advaxis Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 361. Symbol: ADYEY, Name: Adyen N.V., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 362. Symbol: ADYRF, Name: Adyton Resources Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 363. Symbol: ADYX, Name: Adynxx, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 364. Symbol: ADYYF, Name: Adyen N.V., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 365. Symbol: ADZZF, Name: Advance Residence Investment Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 366. Symbol: AE, Name: Adams Resources & Energy Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 367. Symbol: AEAE, Name: AltEnergy Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 368. Symbol: AEAEU, Name: AltEnergy Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 369. Symbol: AEAEW, Name: AltEnergy Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 370. Symbol: AEBZY, Name: Anadolu Efes Biracilik Ve Malt AS, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 371. Symbol: AECFF, Name: Action Energy Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 372. Symbol: AECX, Name: CurrentC Power Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 373. Symbol: AEDC, Name: American Energy Development Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 374. Symbol: AEDFF, Name: Aedifica Sicafi, Bruxelles, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 375. Symbol: AEE, Name: Ameren Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 376. Symbol: AEEI, Name: American Environmental Energy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 377. Symbol: AEFC, Name: Aegon Funding Company LLC 5.10%, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 378. Symbol: AEG, Name: Aegon NV, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 379. Symbol: AEGOF, Name: Aegon N.V., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 380. Symbol: AEGXF, Name: Aecon Group Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 381. Symbol: AEGY, Name: Alternative Energy Partners Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 382. Symbol: AEHL, Name: Antelope Enterprise Holdings Limited, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 383. Symbol: AEHR, Name: Aehr Test Systems, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# ...
# 20283. Symbol: ZEVYW, Name: LIGHTNING EMOTORS INC WTS, Currency: USD, Exchange: OTC, Country: United States, Type: Warrant
# 20284. Symbol: ZFOX, Name: ZeroFox Holdings, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20285. Symbol: ZFOXW, Name: ZeroFox Holdings, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20286. Symbol: ZFSVF, Name: Zurich Insurance Group Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20287. Symbol: ZG, Name: Zillow Group Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20288. Symbol: ZGCO, Name: Ziegler Companies, Inc. (THE), Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20289. Symbol: ZGN, Name: Ermenegildo Zegna N.V., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20290. Symbol: ZGSI, Name: Zero Gravity Solutions, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20291. Symbol: ZGXNF, Name: Zigexn Co Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20292. Symbol: ZH, Name: Zhihu Inc., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20293. Symbol: ZHCLF, Name: Zenith Capital Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20294. Symbol: ZHEXF, Name: Zhejiang Expressway Co. Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20295. Symbol: ZHIXF, Name: ZHIXIN GROUP HLDG LTD, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20296. Symbol: ZHSHF, Name: Zhongsheng Group Holdings Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20297. Symbol: ZHUD, Name: Zhuding International Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20298. Symbol: ZHUZF, Name: Zhuzhou CRRC Times Electric Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20299. Symbol: ZHUZY, Name: Zhuzhou CRRC Times Electric Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20300. Symbol: ZHYBF, Name: Zhong Yuan Bio-Technology Holdings Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20301. Symbol: ZHYLF, Name: Zhaoheng Hydropower Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20302. Symbol: ZI, Name: ZoomInfo Technologies Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20303. Symbol: ZICX, Name: Zicix Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20304. Symbol: ZIJMF, Name: Zijin Mining Group Company Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20305. Symbol: ZIJMY, Name: Zijin Mining Group Company Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20306. Symbol: ZIM, Name: ZIM Integrated Shipping Services Ltd., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20307. Symbol: ZIMCF, Name: ZIM Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20308. Symbol: ZIMV, Name: ZimVie Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20309. Symbol: ZION, Name: Zions Bancorp NA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20310. Symbol: ZIONL, Name: Zions Bancorp NA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Exchange-Traded Note
# 20311. Symbol: ZIONO, Name: Zions Bancorp NA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Preferred Stock
# 20312. Symbol: ZIONP, Name: Zions Bancorp NA, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Preferred Stock
# 20313. Symbol: ZIP, Name: ZIPRECRUITER, INC., Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20314. Symbol: ZIPL, Name: ZipLink, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20315. Symbol: ZIVO, Name: Zivo Bioscience, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20316. Symbol: ZIVOW, Name: ZIVO Bioscience, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20317. Symbol: ZIVZF, Name: VelocityShares Daily Inverse VIX Medium-Term ETN, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20318. Symbol: ZIZTF, Name: Zip Co Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20319. Symbol: ZJYL, Name: JIN MEDICAL INTERNATIONAL LTD. - Ordinary Shares, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20320. Symbol: ZKBEF, Name: SWISSCANTO, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20321. Symbol: ZKGCF, Name: ZKGC NEW ENERGY LTD, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20322. Symbol: ZKH, Name: ZKH Group Limited, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20323. Symbol: ZKIN, Name: ZK International Group Co Ltd, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20324. Symbol: ZLAB, Name: Zai Lab Ltd, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Depositary Receipt
# 20325. Symbol: ZLDAF, Name: Zelira Therapeutics Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20326. Symbol: ZLDPF, Name: Zealand Pharma A/S, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20327. Symbol: ZLDSF, Name: ZALANDO SE, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20328. Symbol: ZLIOF, Name: ZoomLion Heavy Industry Science and Technology Co Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20329. Symbol: ZLIOY, Name: ZoomLion Heavy Industry Science and Technology Co Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20330. Symbol: ZLNDY, Name: ZALANDO SE, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20331. Symbol: ZLPSF, Name: zooplus AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20332. Symbol: ZLS, Name: Zalatoris II Acquisition Corp - Class A Ordinary Shares, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20333. Symbol: ZLSCF, Name: ZYUS LIFE SCIENCES CORP, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20334. Symbol: ZM, Name: Zoom Video Communications Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20335. Symbol: ZMDTF, Name: Zoomd Technologies Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20336. Symbol: ZMGD, Name: Zamage Digital Art Imaging, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20337. Symbol: ZMMPY, Name: ZAMP S.A S/ADR, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20338. Symbol: ZMPLF, Name: Zimplats Holdings Limited, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20339. Symbol: ZMRK, Name: Zalemark Holding Co., Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20340. Symbol: ZMSPF, Name: Zecotek Photonics, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20341. Symbol: ZMTBY, Name: Zumtobel Ag Dornbirn, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20342. Symbol: ZMWYF, Name: Zoomaway Travel, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20343. Symbol: ZNAE, Name: Zane Interactive Publishing Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20344. Symbol: ZNCXF, Name: Zincx Res Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20345. Symbol: ZNKKY, Name: Zenkoku Hosho Co Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20346. Symbol: ZNNC, Name: Zann Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20347. Symbol: ZNOG, Name: Zion Oil & Gas Inc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20348. Symbol: ZNOGW, Name: Zion Oil & Gas, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20349. Symbol: ZNRG, Name: Znergy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20350. Symbol: ZNTL, Name: Zentalis Pharmaceuticals Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20351. Symbol: ZNWLF, Name: ZINNWALD LITHIUM PLC., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20352. Symbol: ZNXT, Name: ZNext Mining Corp., Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20353. Symbol: ZNZNF, Name: ZINZINO AB, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20354. Symbol: ZOM, Name: Zomedica Pharmaceuticals Corp, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20355. Symbol: ZONX, Name: Zonzia Media, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20356. Symbol: ZOONF, Name: ZOONO GROUP LTD., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20357. Symbol: ZPAS, Name: Zoompass Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20358. Symbol: ZPHRF, Name: Zephyr Energy plc, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20359. Symbol: ZPHYF, Name: Zephyr Minerals Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20360. Symbol: ZPRVF, Name: SSGA SPDR ETFS EUROPE II PLC, Currency: USD, Exchange: OTC, Country: United States, Type: ETF
# 20361. Symbol: ZPTAF, Name: Surge Energy, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20362. Symbol: ZRFY, Name: Zerify Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20363. Symbol: ZRSEF, Name: Zur Rose Group AG, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20364. Symbol: ZRVT, Name: Zurvita Holdings, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20365. Symbol: ZS, Name: Zscaler Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20366. Symbol: ZSB, Name: USCF Sustainable Battery Metals Strategy Fund, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20367. Symbol: ZSHGY, Name: Zhongsheng Group Holdings Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20368. Symbol: ZSHOF, Name: ZENSHO HLDGS CO LTD, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20369. Symbol: ZSTN, Name: ZST Digital Networks, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20370. Symbol: ZSYC, Name: SMART CLOSET INC., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20371. Symbol: ZTARF, Name: ZETA RES LTD, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20372. Symbol: ZTCOF, Name: Zte Corp., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20373. Symbol: ZTEK, Name: Zentek Ltd., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20374. Symbol: ZTEN, Name: The RBB Fund, Inc. F/m 10-Year Investment Grade Corporate Bond ETF, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20375. Symbol: ZTLLF, Name: Zonetail Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20376. Symbol: ZTMUF, Name: Zimtu Capital Corp, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20377. Symbol: ZTNO, Name: Zoom Technologies, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20378. Symbol: ZTO, Name: ZTO Express Cayman Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Depositary Receipt
# 20379. Symbol: ZTRE, Name: The RBB Fund, Inc. F/m 3-Year Investment Grade Corporate Bond ETF, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20380. Symbol: ZTS, Name: Zoetis Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20381. Symbol: ZTST, Name: ZTST, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20382. Symbol: ZTSTF, Name: ZTEST Electronics, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20383. Symbol: ZTWO, Name: The RBB Fund, Inc. F/m 2-Year Investment Grade Corporate Bond ETF, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20384. Symbol: ZUKI, Name: Zuki Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20385. Symbol: ZULU, Name: ZULU TEK INC, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20386. Symbol: ZUMRF, Name: ZoomerMedia Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20387. Symbol: ZUMZ, Name: Zumiez Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20388. Symbol: ZUO, Name: Zuora Inc, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20389. Symbol: ZURA, Name: Zura Bio Ltd., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20390. Symbol: ZURVY, Name: Zurich Insurance Group Ltd, Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20391. Symbol: ZUSFF, Name: BMO ULTRA SHORT TERM US BOND ETF, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20392. Symbol: ZUUS, Name: ZEUUS INC., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20393. Symbol: ZVIA, Name: Zevia PBC, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20394. Symbol: ZVLO, Name: zvelo, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20395. Symbol: ZVOI, Name: Zovio Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20396. Symbol: ZVRA, Name: KemPharm Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20397. Symbol: ZVSA, Name: ZyVersa Therapeutics, Inc., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20398. Symbol: ZVTK, Name: Zevotek, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20399. Symbol: ZVZZT, Name: , Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20400. Symbol: ZWBC, Name: GoldKey Corporation, Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20401. Symbol: ZWRKU, Name: Z-Work Acquisition Corp., Currency: USD, Exchange: NASDAQ, Country: United States, Type: Unit
# 20402. Symbol: ZWS, Name: Zurn Water Solutions Corporation, Currency: USD, Exchange: NYSE, Country: United States, Type: Common Stock
# 20403. Symbol: ZYME, Name: Zymeworks Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20404. Symbol: ZYXI, Name: Zynex Inc, Currency: USD, Exchange: NASDAQ, Country: United States, Type: Common Stock
# 20405. Symbol: ZZHGF, Name: ZhongAn Online P & C Insurance Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20406. Symbol: ZZHGY, Name: ZhongAn Online P & C Insurance Co., Ltd., Currency: USD, Exchange: OTC, Country: United States, Type: American Depositary Receipt
# 20407. Symbol: ZZLL, Name: ZZLL Information Technology, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock
# 20408. Symbol: ZZZOF, Name: Zinc One Resources, Inc., Currency: USD, Exchange: OTC, Country: United States, Type: Common Stock

# %%
import requests
import random

# Your Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'

# The URL for the stocks endpoint
url = 'https://api.twelvedata.com/stocks'

# Parameters for the API request
params = {
    'apikey': api_key
}

# Your list of stocks to exclude
exclude_stocks = [
       "MSFT", "AAPL", "NVDA", "AMZN", "GOOGL", "META", "BRK.B", "LLY",
    "TSM", "AVGO", "TSLA", "V", "NVO", "JPM", "WMT", "UNH", "MA", "XOM",
    "ASML", "JNJ", "HD", "PG", "COST", "TM", "AMD", "MRK", "ABBV", "ORCL",
    "CRM", "CVX", "BAC", "NFLX", "ADBE", "KO", "ACN", "PEP", "FMX", "SAP",
    "TMO", "LIN", "MCD", "NVS", "ABT", "DIS", "SHEL", "AZN", "WFC", "CSCO",
    "TMUS", "DHR", "BABA", "INTU", "INTC", "QCOM", "AMAT", "GE", "IBM", "CMCSA",
    "VZ", "PDD", "UBER", "CAT", "AXP", "NOW", "TXN", "BX", "NKE", "UNP", "TTE",
    "AMGN", "PFE", "HSBC", "BHP", "MS", "LOW", "ISRG", "PM", "HDB", "RY", "SPGI",
    "COP", "SYK", "HON", "LRCX", "GS", "UPS", "PLD", "MUFG", "UL", "BA", "T",
    "BLK", "SCHW", "BUD", "BKNG", "RTX", "SNY", "ETN", "ELV", "NEE", "TJX", "VRTX",
    "MDT", "PGR", "SONY","FMC", "CIVI", "UI", "AZEK", "YMM", "RHP", "BZ", "TKO",
    "NYT", "GPS", "ALTR", "NFE", "XRAY", "CCCS", "SPSC", "STAG",
    "IVZ", "HAS", "DAR", "RMBS", "HQY", "RGLD", "ICL", "BILL",
    "VOYA", "CFR", "ITCI", "ENSG", "MAT", "FOUR", "GNRC", "THO",
    "BRX", "IBP", "WTS", "CGNX", "CHRD", "CACC", "AAON", "BERY",
    "MMYT", "LBTYK", "ALSN", "CBSH", "EXEL", "NOV", "ADT", "BFAM",
    "CRSP", "HRB", "MTZ", "MASI", "MTSI", "RLI", "DDS", "LSTR",
    "AGNC", "WFG", "STWD", "VNT", "IONS", "CAVA", "ANF", "OGE",
    "OLN", "CMA", "LYFT", "UGP", "AM", "VNOM", "CART", "ARW",
    "TNET", "CR", "SFM", "CSAN", "KVYO", "ATKR", "AN", "POST",
    "HXL", "VFC", "SIGI", "ATI", "BROS", "NOVT", "ALGM", "GTLS",
    "BBIO", "HLNE", "SSB", "FLR", "CMC", "KGC", "BYD", "PNFP",
    "WAL", "QLYS", "NE", "MUR", "NEU", "REYN", "WH", "NSIT",
    "TMHC", "CHX", "G", "GXO", "FAF", "ELP", "FRSH", "CAE",
    "MARA", "DRS", "BC", "ESAB", "MNSO", "BPOP", "LFUS", "WTFC",
    "ALTM", "TKR", "RRR", "GRFS", "OBDC", "CIGI", "RCM", "SMAR",
    "FYBR", "MLI", "GIL", "WHR", "FTAI", "OMF", "PBF", "BPMC",
    "PB", "BLCO", "MTH", "CIG", "ENLC", "ZION", "TRNO", "ESNT",
    "ESI", "ADC", "BRZE", "LANC", "TENB", "MSM","MXCT", "BALY", "SRI", "IVVD", "BWMN", "EQBK", "SD", "DJCO",
    "ATLC", "LSEA", "DENN", "SMBC", "GUTS", "ASLE", "CCBG", "VPG",
    "LWLG", "OFIX", "AEON", "LIND", "LND", "MTW", "CTLP", "RSVR",
    "ABUS", "AMNB", "NN", "LAND", "FPH", "HCAT", "ESPR", "JOUT",
    "ALNT", "RXT", "CATX", "GCBC", "ANNX", "RGP", "EGY", "TPB",
    "ZH", "VTRU", "DGICA", "CWCO", "RCEL", "CLFD", "DGICB", "AXGN",
    "ZIMV", "ALCC", "TRDA", "ADTN", "HONE", "CAC", "SRDX", "AVAH",
    "HAFC", "AURA", "STTK", "MCS", "TBPH", "TGB", "KODK", "TERN",
    "HTBI", "MGX", "NTGR", "NFBK", "TRC", "BETR", "ORC", "GDEV",
    "URG", "RDZN", "WTI", "PNNT", "GHRS", "GATO", "EHAB", "GLAD",
    "TSAT", "MED", "BBCP", "BLZE", "CELC", "XERS", "SVM", "MVIS",
    "WASH", "GLRE", "IVR", "AVNW", "ANSC", "OCS", "OSG", "DHIL",
    "EAF", "THFF", "CVRX", "SLAM", "AVXL", "AMRN", "CRMT", "FFWM",
    "DCGO", "OLP", "AUDC", "ALRS", "BTMD", "GDOT", "NYXH", "SPFI",
    "FBLG", "ACRE", "PGC", "CLOV", "CCG", "DOMO", "MCB", "PGEN",
    "NPCE", "ONEW", "NVEC", "EPIX", "LYTS", "FARO", "TMC", "GFR",
    "ESQ", "THRD", "CCNE", "PBPB", "NBN", "STRW", "FSBC", "BHRB",
    "LXEO", "IAUX", "LAW", "MGTX", "RMR", "NGNE", "AROW", "GBLI",
    "ACTG", "INZY", "ITOS", "STEM", "ARMN", "MODV", "NCMI", "ANRO",
    "NETD", "VALU", "HRZN", "OPY", "VNET", "SGU", "ZYXI", "OSPN"
]

# Make the GET request to the Twelve Data API
response = requests.get(url, params=params)

# Initialize a list to hold all available stocks from Twelve Data
all_stocks = []

# Check if the request was successful
if response.status_code == 200:
    # Convert the response to JSON
    data = response.json()
    
    # Ensure the 'data' key is in the response
    if 'data' in data:
        # Loop through each stock in the response
        for stock in data['data']:
            if stock.get('country') == 'United States':
            # Add the stock symbol to the list of all stocks
                all_stocks.append(stock['symbol'])

    # Filter out the stocks from the exclude list
    filtered_stocks = [stock for stock in all_stocks if stock not in exclude_stocks]
    
    # Select 500 random stocks from the filtered list
    # Ensure the list has enough elements to avoid ValueError
    if len(filtered_stocks) >= 800:
        random_stocks = random.sample(filtered_stocks, 800)
        print("500 random stocks not in the exclude list:")
        for i, stock in enumerate(random_stocks, start=1):
            print(f"{i}. {stock}")
    else:
        print("Not enough stocks available to select 500 unique stocks after filtering.")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}, Response: {response.text}")
# Out:
# 500 random stocks not in the exclude list:
# 1. JCSE
# 2. CLNNW
# 3. AENTW
# 4. EVGRU
# 5. EVI
# 6. GRGR
# 7. VPGLF
# 8. LNSPF
# 9. KNX
# 10. ZBRA
# 11. ARET
# 12. ATLKY
# 13. NERV
# 14. CTCX
# 15. SPLY
# 16. XPDB
# 17. KLKLF
# 18. KOOYF
# 19. LIZI
# 20. RLLCF
# 21. BKKT
# 22. LEHKQ
# 23. DRXGY
# 24. OVCHF
# 25. MRKR
# 26. AILLO
# 27. FIGP
# 28. PRO
# 29. HSON
# 30. SGC
# 31. ROMA
# 32. RWODW
# 33. PARAP
# 34. MCAG
# 35. AHIX
# 36. CDE
# 37. RNWR
# 38. VWSYF
# 39. NCTKY
# 40. ARBKF
# 41. TKOI
# 42. JWSM
# 43. ECC.PR.D
# 44. EMEXF
# 45. LTRX
# 46. CNGKY
# 47. FFIEW
# 48. DCSX
# 49. CESDF
# 50. SNAX
# 51. PTABF
# 52. CBOBA
# 53. PEPG
# 54. MODD
# 55. IMRSQ
# 56. PBCRY
# 57. CAOHF
# 58. ZSHGY
# 59. PAZRF
# 60. FRMA
# 61. CTUY
# 62. PFX
# 63. AIFLY
# 64. PBBK
# 65. QOMOR
# 66. CASA
# 67. FBSI
# 68. STMM
# 69. WFTSF
# 70. UTRX
# 71. IRM
# 72. APTY
# 73. TSUBF
# 74. TONR
# 75. AQNB
# 76. CTBG
# 77. VXLLF
# 78. SPTN
# 79. UPC
# 80. RHCGF
# 81. QBAK
# 82. ARKOW
# 83. CMCAW
# 84. PAQC
# 85. MGWFF
# 86. UTRK
# 87. TMNSF
# 88. ZAPP
# 89. EKTAF
# 90. FITX
# 91. GAB.PR.G
# 92. KEYS
# 93. ANDR
# 94. REATS
# 95. NGVT
# 96. SMPP
# 97. BYFC
# 98. MTLHY
# 99. KASHF
# 100. HPURF
# 101. CME
# 102. ASPHF
# 103. CNLTP
# 104. IMTV
# 105. CVGI
# 106. LDI
# 107. RYTM
# 108. BKYI
# 109. NKLA
# 110. SNMP
# 111. HTHT
# 112. ZVSA
# 113. RCMH
# 114. BYPLF
# 115. CPKF
# 116. HYSNF
# 117. ETSLF
# 118. ZPRVF
# 119. AKBLF
# 120. TANH
# 121. MLTX
# 122. EONGY
# 123. BRBL
# 124. TRIP
# 125. WAFDP
# 126. BGOUF
# 127. AXXTF
# 128. GNE
# 129. DPMAY
# 130. POCI
# 131. BIOF
# 132. EOSC
# 133. VGANF
# 134. ZJYL
# 135. ASAN
# 136. SNWAF
# 137. CJPRY
# 138. OTGBS
# 139. LFTSF
# 140. IRNG
# 141. BIOR
# 142. PFG
# 143. SGCFF
# 144. EHVVF
# 145. OXY.WT
# 146. THRGF
# 147. INTEU
# 148. MJGCF
# 149. TRRCF
# 150. SAAGF
# 151. NUS
# 152. RYLPF
# 153. ARWR
# 154. ANSS
# 155. KWGPF
# 156. ASAI
# 157. HYTLF
# 158. CHSCN
# 159. OXBC
# 160. AIBBU
# 161. FNCSF
# 162. NZTCF
# 163. TNSSF
# 164. RUM
# 165. TSAVF
# 166. CPYYF
# 167. ORBN
# 168. STZHF
# 169. PKTEF
# 170. WTRO
# 171. GROV
# 172. HLX
# 173. BYCBF
# 174. TTCIF
# 175. HMMR
# 176. PRSI
# 177. BBOE
# 178. VYGVQ
# 179. CNLK
# 180. REFG
# 181. PBBIF
# 182. TY.PR.
# 183. SQZZF
# 184. BRSYF
# 185. SRLZF
# 186. AGL
# 187. KGLDF
# 188. VYGR
# 189. GLMD
# 190. TEAF
# 191. CQCQ
# 192. BRYN
# 193. TMPLS
# 194. DADA
# 195. IINX
# 196. STR
# 197. NHLG
# 198. BLJZY
# 199. ADSEW
# 200. DOCRF
# 201. FGFT
# 202. DLTH
# 203. DUERF
# 204. GEGR
# 205. TLOFF
# 206. FDP
# 207. RYOOF
# 208. NRSDY
# 209. ASFX
# 210. ELS
# 211. CBHC
# 212. AHG
# 213. CDZIP
# 214. FBRT
# 215. SNTAF
# 216. AMCI
# 217. BADFF
# 218. IMMVF
# 219. ALBKF
# 220. JGLCF
# 221. BRRDF
# 222. DRFS
# 223. BIPH
# 224. IDND
# 225. IHREF
# 226. NWXPF
# 227. DEIWY
# 228. AKRO
# 229. SOBS
# 230. FNMFN
# 231. ILKAF
# 232. MOBXW
# 233. LOCO
# 234. DRCR
# 235. STHZF
# 236. SNRG
# 237. TTWO
# 238. OTEC
# 239. GMSC
# 240. BBW
# 241. ATOM
# 242. FMCKN
# 243. SDZXF
# 244. PBAJ
# 245. VIAAY
# 246. BGNRF
# 247. WLDBF
# 248. CWK
# 249. DBRG.PR.J
# 250. FRRPF
# 251. GAMN
# 252. MKTAY
# 253. ACLTF
# 254. BEWFF
# 255. VCIG
# 256. DNAG
# 257. SALRF
# 258. AVVH
# 259. VTR
# 260. CORG
# 261. OXLCM
# 262. YORKF
# 263. MG
# 264. HSTC
# 265. CVI
# 266. ZETA
# 267. VHAQ
# 268. PTITF
# 269. CTUNF
# 270. TNTTF
# 271. PWMCF
# 272. GWWTF
# 273. TTGT
# 274. WPNTF
# 275. CCLD
# 276. FPSUF
# 277. OBIIF
# 278. MSEX
# 279. NRT
# 280. IMAQU
# 281. AKZOF
# 282. BGUUF
# 283. BR
# 284. HRMY
# 285. QS
# 286. GRCU
# 287. TCNT
# 288. CP
# 289. COEPW
# 290. RYMM
# 291. JAN
# 292. ADC.PR.A
# 293. ASKE
# 294. BIRDF
# 295. DGHI
# 296. ARRJF
# 297. BOSC
# 298. FCNCA
# 299. BTGHF
# 300. NVRI
# 301. BXDIF
# 302. THBRF
# 303. BRBR
# 304. YSG
# 305. POGHF
# 306. KWR
# 307. REFR
# 308. IROQ
# 309. FUGRF
# 310. PNDZF
# 311. RLJ.PR.A
# 312. SNDL
# 313. GLACR
# 314. CNTMF
# 315. BBUZ
# 316. FLEX
# 317. GTH
# 318. TYRA
# 319. VRSN
# 320. GREN
# 321. SHNXY
# 322. CAMLF
# 323. ARRPY
# 324. RSSPS
# 325. YUANF
# 326. DGTCF
# 327. BTZI
# 328. ISUN
# 329. ICABF
# 330. JDWPF
# 331. RBA
# 332. FNBT
# 333. ACET
# 334. MBINO
# 335. ASCCY
# 336. RBEPS
# 337. TVFCF
# 338. SVNDY
# 339. TNYZF
# 340. ENBP
# 341. ADEA
# 342. CHYHY
# 343. ICABY
# 344. WBQNL
# 345. BGAVF
# 346. UCCPF
# 347. ENO
# 348. BFST
# 349. BVILY
# 350. PCG.PR.D
# 351. AVOZ
# 352. PCRFY
# 353. ZLDSF
# 354. HTRC
# 355. HIGR
# 356. FNRN
# 357. MNPP
# 358. JBLU
# 359. GILT
# 360. BAKPF
# 361. ALCUF
# 362. SRKZF
# 363. HZEN
# 364. OLYMY
# 365. BGPPF
# 366. SNPS
# 367. SGGKY
# 368. PARAA
# 369. EMHI
# 370. SSGGF
# 371. CSPHF
# 372. WHCA
# 373. CBBLF
# 374. THBD
# 375. RERE
# 376. BRLAF
# 377. RC
# 378. IFJPY
# 379. WRN
# 380. SURVF
# 381. RH
# 382. CRPLF
# 383. NSLYF
# 384. FRNRF
# 385. GLBZ
# 386. CLHI
# 387. SODE
# 388. NSARP
# 389. AXFOY
# 390. HHS
# 391. JJMTF
# 392. BLLYF
# 393. NPAB
# 394. APPIF
# 395. BBXIA
# 396. PZRIF
# 397. GNENF
# 398. USDP
# 399. HCI
# 400. RAIFY
# 401. FHN.PR.F
# 402. SXYAY
# 403. PTGX
# 404. MHLD
# 405. DC
# 406. PRTLQ
# 407. FBIO
# 408. BOREF
# 409. VRMEW
# 410. FCCI
# 411. CSLMR
# 412. SEKEF
# 413. SEZNL
# 414. CLNFF
# 415. CBDD
# 416. BILI
# 417. TAKOF
# 418. MIDD
# 419. BCNAF
# 420. PCDVF
# 421. TRUHF
# 422. BLVDF
# 423. GARQF
# 424. DMEC
# 425. BANF
# 426. HERF
# 427. GRGSF
# 428. ZURA
# 429. WHGRF
# 430. CONN
# 431. PEGR
# 432. ACRS
# 433. TJIPF
# 434. EIFZF
# 435. ADI
# 436. AONNY
# 437. VYYRF
# 438. IVRO
# 439. YMHAD
# 440. NFPC
# 441. ATOS
# 442. FOCIF
# 443. OILRF
# 444. BIDCF
# 445. FUIZF
# 446. DPZUF
# 447. FDCFF
# 448. VCLD
# 449. MTEHF
# 450. IAACF
# 451. RADR
# 452. MEEEF
# 453. MOMO
# 454. AMBZ
# 455. IOR
# 456. TATLY
# 457. BSEFY
# 458. MKL
# 459. HYMLF
# 460. TNMD
# 461. PSSWF
# 462. CNDL
# 463. ASCBU
# 464. RCACW
# 465. CYBD
# 466. UNLRF
# 467. KALY
# 468. FCGY
# 469. ISQWF
# 470. SUPV
# 471. UVV
# 472. BG
# 473. VERF
# 474. FLIC
# 475. UCLE
# 476. AWCA
# 477. GNFT
# 478. QCLSF
# 479. NTLK
# 480. OGLFS
# 481. MRRLF
# 482. PDPG
# 483. SCRH
# 484. YCBD
# 485. CLBR
# 486. MDTC
# 487. ZPHRF
# 488. HCBC
# 489. KTRA
# 490. SYPT
# 491. APPEF
# 492. AGRIW
# 493. PSBD
# 494. RAMPF
# 495. FEERF
# 496. SPDE
# 497. TXHG
# 498. PTOVF
# 499. FULT
# 500. ITMTF
# 501. DECK
# 502. EMGDF
# 503. SMFRF
# 504. RSVNS
# 505. BLPEF
# 506. TOIPF
# 507. IPDQF
# 508. KRUS
# 509. TOP
# 510. TROLB
# 511. URGYF
# 512. ADNWW
# 513. SENS
# 514. PCB
# 515. OAOFY
# 516. UGLDF
# 517. ASKH
# 518. CRFU
# 519. HALMY
# 520. DGBBF
# 521. DGNG
# 522. FRST
# 523. NMGC
# 524. BTI
# 525. NXRA
# 526. PLYM
# 527. CGKEF
# 528. MCK
# 529. NIRLQ
# 530. CNIKF
# 531. RGR
# 532. ADIA
# 533. CKEFF
# 534. VRTHF
# 535. APELF
# 536. IXNZF
# 537. BBRW
# 538. MCBK
# 539. MLLUY
# 540. AFAR
# 541. ACGBY
# 542. TOOD
# 543. CHOOF
# 544. QRHC
# 545. CNVS
# 546. NVDEF
# 547. GAEC
# 548. NRC
# 549. FLLLF
# 550. INSSF
# 551. HVRRY
# 552. GORO
# 553. MOPN
# 554. GWIN
# 555. UMRRF
# 556. HCGI
# 557. TS
# 558. SHG
# 559. GSPE
# 560. IMPP
# 561. GMPXF
# 562. ENBMF
# 563. HTWSF
# 564. CKHGY
# 565. HGBL
# 566. PPCCY
# 567. WLMSQ
# 568. CATV
# 569. SGDVV
# 570. ARQ
# 571. CYBQY
# 572. SHECY
# 573. MNRIF
# 574. LGNZZ
# 575. HWM
# 576. CMSQF
# 577. MLKNA
# 578. CKPT
# 579. ZZLL
# 580. SLGWF
# 581. SILS
# 582. BMO
# 583. BLRDF
# 584. STVN
# 585. VNTRF
# 586. LVS
# 587. CGGGF
# 588. CNVVY
# 589. UCL
# 590. AVDX
# 591. JNSH
# 592. BKGFF
# 593. TAIT
# 594. BNGI
# 595. INLX
# 596. NKGFF
# 597. AMNNF
# 598. LGL.WT
# 599. GENE
# 600. JETR
# 601. SFNC
# 602. BRK.A
# 603. LASE
# 604. FFIC
# 605. ASTTF
# 606. AMIX
# 607. REG
# 608. SQFT
# 609. LHTV
# 610. SHOM
# 611. VIAO
# 612. IGPFF
# 613. NREF.PR.A
# 614. APPS
# 615. QSPW
# 616. PNTG
# 617. ACACU
# 618. OXLCN
# 619. AMKAF
# 620. BTCS
# 621. SPXCF
# 622. SGDH
# 623. CCCMF
# 624. LNC
# 625. DTNOF
# 626. SRLY
# 627. KBLB
# 628. PSNL
# 629. SOHU
# 630. ROVMF
# 631. TDCSF
# 632. IPSOF
# 633. SWISF
# 634. ODP
# 635. TOGOF
# 636. FANH
# 637. WMG
# 638. BHACW
# 639. CAXPF
# 640. LASLY
# 641. MTX
# 642. SWRAF
# 643. GCLMF
# 644. RAIL
# 645. GXAI
# 646. LPRRF
# 647. MBCI
# 648. HUDAU
# 649. SEMR
# 650. PEXZF
# 651. VANI
# 652. PRMO
# 653. MAXN
# 654. CSGU
# 655. PEB-H
# 656. PARR
# 657. SSEXF
# 658. AXR
# 659. SLSSF
# 660. FRFGF
# 661. BCVVF
# 662. EFOI
# 663. XTCYF
# 664. REKR
# 665. SSEZF
# 666. RCFA.UN
# 667. RKLB
# 668. TU
# 669. CNSJF
# 670. GORV
# 671. GLPEY
# 672. ACLX
# 673. VCXB.UN
# 674. PCLI
# 675. SMWPY
# 676. CHYI
# 677. CLRCU
# 678. RRVCS
# 679. BHFAP
# 680. BCEKF
# 681. HIVE
# 682. DEC
# 683. ODZA
# 684. AES
# 685. NWTNW
# 686. GRNQ
# 687. BKEN
# 688. CRSR
# 689. UK
# 690. STKH
# 691. CECO
# 692. IJJP
# 693. MOR
# 694. ZUO
# 695. MITI
# 696. ITW
# 697. SECVY
# 698. GXYYY
# 699. ATLMF
# 700. PNXLF
# 701. RAND
# 702. ISCCF
# 703. LFVN
# 704. SLNLF
# 705. DGMLF
# 706. JKHY
# 707. ALKEF
# 708. UZE
# 709. HAGHY
# 710. TRNLY
# 711. RNR.PR.F
# 712. RENI
# 713. CGASY
# 714. BLFY
# 715. CUPUF
# 716. CCOJF
# 717. PH
# 718. MPRA
# 719. SGIC
# 720. LLYVK
# 721. SGBG
# 722. BRSP
# 723. DOMAW
# 724. SBUM
# 725. PXXXF
# 726. WTCZF
# 727. WSTG
# 728. SLOFF
# 729. RELT
# 730. FXLV
# 731. COUR
# 732. DGEAF
# 733. EME
# 734. KPDCF
# 735. EVTNF
# 736. QBIEY
# 737. ALKS
# 738. TLNE
# 739. PNBC
# 740. PANHF
# 741. AVPTW
# 742. FSUGY
# 743. AGCZ
# 744. XESP
# 745. VGGOF
# 746. LZB
# 747. NFYS
# 748. OFG
# 749. ATRC
# 750. FVVSF
# 751. ESMT
# 752. VIAV
# 753. MSDL
# 754. HCKG
# 755. DISA
# 756. CDIOW
# 757. VLTAF
# 758. LUXH
# 759. TBVPF
# 760. CRYO
# 761. SHMP
# 762. VSOLF
# 763. CNLTN
# 764. PGXPF
# 765. LQWC
# 766. GOMRF
# 767. STKKF
# 768. RECAF
# 769. ULTHF
# 770. PHX
# 771. FA
# 772. CBD.WI
# 773. WING
# 774. BDRFY
# 775. QSI
# 776. IVCB
# 777. XTXXF
# 778. CATKU
# 779. COPHF
# 780. HQGE
# 781. SYBJF
# 782. PGGG
# 783. IMJX
# 784. EGBB
# 785. NBMFF
# 786. AUIAF
# 787. TTNDF
# 788. SNTMF
# 789. TARS
# 790. FURY
# 791. WSOUF
# 792. MILFF
# 793. BYRG
# 794. MJARF
# 795. STCGF
# 796. PRLPF
# 797. BCEXF
# 798. WETG
# 799. WDS
# 800. ATHM

# %%
len(tickers)
# Out:
# 1215

# %%
tickers= []

# %%
for item in random_stocks:
    tickers.append(item)
len(tickers)
# Out:
# 1215

# %%
import requests
import pandas as pd

# Replace 'your_api_key' with your actual Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'
symbol = 'AAPL'

# Make the API request
url = f"https://api.twelvedata.com/profile?symbol={symbol}&apikey={api_key}"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Convert the JSON response to a dictionary
    data = response.json()
    
    # Convert the dictionary to a pandas dataframe
    # Since the response is a single dictionary, we'll convert it to a dataframe by first turning it into a list
    df = pd.DataFrame([data])
    
    print(df)
else:
    print("Failed to retrieve data. Status code:", response.status_code)
df.columns
# Out:
#   symbol       name exchange mic_code      sector              industry  \
# 0   AAPL  Apple Inc   NASDAQ     XNGS  Technology  Consumer Electronics
#
#    employees                website  \
# 0     161000  https://www.apple.com
#
#                                          description          type  \
# 0  Apple Inc. designs, manufactures, and markets ...  Common Stock
#
#                    CEO             address       city    zip state  \
# 0  Mr. Timothy D. Cook  One Apple Park Way  Cupertino  95014    CA
#
#          country         phone
# 0  United States  408 996 1010
# Index(['symbol', 'name', 'exchange', 'mic_code', 'sector', 'industry',
#        'employees', 'website', 'description', 'type', 'CEO', 'address', 'city',
#        'zip', 'state', 'country', 'phone'],
#       dtype='object')

# %%
import requests
import pandas as pd

# Replace 'your_api_key' with your actual Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'
symbol = 'AAPL'

# Make the API request for stock splits
url = f"https://api.twelvedata.com/splits?symbol={symbol}&apikey={api_key}&range=full"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Convert the JSON response to a dictionary
    data = response.json()
    
    # Extract the splits data
    splits_data = data.get('splits', [])
    
    # Convert the splits data to a pandas dataframe
    df_splits = pd.DataFrame(splits_data)
    
    # Display the dataframe
    print(df_splits)
else:
    print("Failed to retrieve data. Status code:", response.status_code)
df_splits.columns
# Out:
#          date    description    ratio  from_factor  to_factor
# 0  2020-08-31  4-for-1 split  0.25000            4          1
# 1  2014-06-09  7-for-1 split  0.14286            7          1
# 2  2005-02-28  2-for-1 split  0.50000            2          1
# 3  2000-06-21  2-for-1 split  0.50000            2          1
# 4  1987-06-16  2-for-1 split  0.50000            2          1
# Index(['date', 'description', 'ratio', 'from_factor', 'to_factor'], dtype='object')

# %%
len(tickers)
# Out:
# 915

# %%
# Out:
# 915

# %% [markdown]
# income statement quarterly

# %%
import requests
import pandas as pd
import time
import os

# API Key should be kept private
api_key = '3cc2c2885bea431abf95d6f776acc139'

csv_file_name = 'income_statements.csv'


write_header = not os.path.exists(csv_file_name)

# Iterate over each ticker symbol
for symbol in tickers:
    print(f"Processing {symbol}...")
    url = f"https://api.twelvedata.com/income_statement?symbol={symbol}&apikey={api_key}&period=annual"
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200 and response.json().get('status') != 'error':
        data = response.json()
        
        # Extract and flatten the income statement data
        income_statement_data = data.get('income_statement', [])
        flattened_data = []
        for item in income_statement_data:
            flattened_item = {**item, **item.get('operating_expense', {}), **item.get('non_operating_interest', {})}
            flattened_item.pop('operating_expense', None)
            flattened_item.pop('non_operating_interest', None)
            flattened_data.append(flattened_item)
        
        # Convert the flattened data to a DataFrame
        df_income_statement = pd.DataFrame(flattened_data)
        df_income_statement['ticker'] = symbol
        # Append DataFrame to the CSV file
        df_income_statement.to_csv(csv_file_name, mode='a', index=False, header=write_header)
        
        # Ensure the header is not written again in subsequent writes
        write_header = False
        
        print(f"Data for {symbol} added to {csv_file_name}.")
    else:
        print(f"No data for {symbol} or failed to retrieve data. Status code: {response.status_code}")
    
    # Wait for 12 seconds before processing the next ticker
    time.sleep(12)

print("All requested data processed.")
# Out:
# Processing MSFT...
# Data for MSFT added to income_statements.csv.
# Processing AAPL...
# Data for AAPL added to income_statements.csv.
# Processing NVDA...
# Data for NVDA added to income_statements.csv.
# Processing AMZN...
# Data for AMZN added to income_statements.csv.
# Processing GOOGL...
# Data for GOOGL added to income_statements.csv.
# Processing META...
# Data for META added to income_statements.csv.
# Processing BRK.B...
# Data for BRK.B added to income_statements.csv.
# Processing LLY...
# Data for LLY added to income_statements.csv.
# Processing TSM...
# Data for TSM added to income_statements.csv.
# Processing AVGO...
# Data for AVGO added to income_statements.csv.
# Processing TSLA...
# Data for TSLA added to income_statements.csv.
# Processing V...
# Data for V added to income_statements.csv.
# Processing NVO...
# Data for NVO added to income_statements.csv.
# Processing JPM...
# Data for JPM added to income_statements.csv.
# Processing WMT...
# Data for WMT added to income_statements.csv.
# Processing UNH...
# Data for UNH added to income_statements.csv.
# Processing MA...
# Data for MA added to income_statements.csv.
# Processing XOM...
# Data for XOM added to income_statements.csv.
# Processing ASML...
# Data for ASML added to income_statements.csv.
# Processing JNJ...
# Data for JNJ added to income_statements.csv.
# Processing HD...
# Data for HD added to income_statements.csv.
# Processing PG...
# Data for PG added to income_statements.csv.
# Processing COST...
# Data for COST added to income_statements.csv.
# Processing TM...
# Data for TM added to income_statements.csv.
# Processing AMD...
# Data for AMD added to income_statements.csv.
# Processing MRK...
# Data for MRK added to income_statements.csv.
# Processing ABBV...
# Data for ABBV added to income_statements.csv.
# Processing ORCL...
# Data for ORCL added to income_statements.csv.
# Processing CRM...
# Data for CRM added to income_statements.csv.
# Processing CVX...
# Data for CVX added to income_statements.csv.
# Processing BAC...
# Data for BAC added to income_statements.csv.

# %% [markdown]
# income statement yearly

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# Replace 'your_api_key' with your actual Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'  # Remember to keep your API keys private
symbol = 'AAPL'

# Calculate the start date as 5 years back from today
start_date = (datetime.now() - timedelta(days=10*365)).strftime('%Y-%m-%d')

# Make the API request for the income statement with quarterly data, including the start date
url = f"https://api.twelvedata.com/income_statement?symbol={symbol}&apikey={api_key}&period=annual"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    
    # Extract the income statement data
    income_statement_data = data.get('income_statement', [])
    
    # Process the data
    flattened_data = []
    for item in income_statement_data:
        flattened_item = {**item, **item.get('operating_expense', {}), **item.get('non_operating_interest', {})}
        flattened_item.pop('operating_expense', None)
        flattened_item.pop('non_operating_interest', None)
        flattened_data.append(flattened_item)
    
    df_income_statement = pd.DataFrame(flattened_data)
    
    # Sorting and resetting index
    df_income_statement.sort_values(by='fiscal_date', inplace=True)
    df_income_statement.reset_index(drop=True, inplace=True)
    
    print(df_income_statement)
else:
    print("Failed to retrieve data. Status code:", response.status_code)

# Check how many rows were retrieved to estimate the coverage
print(f"Retrieved {len(df_income_statement)} rows of data.")
# Out:
#   fiscal_date         sales  cost_of_goods  gross_profit  operating_income  \
# 0  2020-09-30  274515000000   169559000000  104956000000       66288000000
# 1  2021-09-30  365817000000   212981000000  152836000000      108949000000
# 2  2022-09-30  394328000000   223546000000  170782000000      119437000000
# 3  2023-09-30  383285000000   214137000000  169148000000      114301000000
#
#    other_income_expense  pretax_income   income_tax   net_income  eps_basic  \
# 0             -87000000    67091000000   9680000000  57411000000       3.31
# 1              60000000   109207000000  14527000000  94680000000       5.67
# 2            -228000000   119103000000  19300000000  99803000000       6.15
# 3            -382000000   113736000000  16741000000  96995000000       6.16
#
#    ...          ebit        ebitda  net_income_continuous_operations  \
# 0  ...   69964000000   81020000000                       57411000000
# 1  ...  111852000000  123136000000                       94680000000
# 2  ...  122034000000  133138000000                       99803000000
# 3  ...  117669000000  129188000000                       96995000000
#
#    minority_interests  preferred_stock_dividends  research_and_development  \
# 0                None                       None               18752000000
# 1                None                       None               21914000000
# 2                None                       None               26251000000
# 3                None                       None               29915000000
#
#   selling_general_and_administrative other_operating_expenses      income  \
# 0                        19916000000                     None  3763000000
# 1                        21973000000                     None  2843000000
# 2                        25094000000                     None  2825000000
# 3                        24932000000                     None  3750000000
#
#       expense
# 0  2873000000
# 1  2645000000
# 2  2931000000
# 3  3933000000
#
# [4 rows x 23 columns]
# Retrieved 4 rows of data.

# %%
import requests
import pandas as pd

# Replace 'your_api_key' with your actual Twelve Data API key
api_key = '3cc2c2885bea431abf95d6f776acc139'
symbol = 'FMX'
period = 'quarterly'  # Ensure the data is fetched by quarters

# Construct the API URL
url = f'https://api.twelvedata.com/cash_flow?symbol={symbol}&apikey={api_key}&period={period}'

# Make the API request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Convert the JSON response to a pandas DataFrame
    data = response.json()
    
    # Extract 'cash_flow' data
    cash_flow_data = data['cash_flow']
    
    # Normalize the data and create a DataFrame
    df_cash_flow = pd.json_normalize(cash_flow_data)
    
    # Add the 'meta' information as new columns if needed
    for key in data['meta']:
        df_cash_flow[key] = data['meta'][key]
    
    # Sort the DataFrame by 'fiscal_date' to ensure it's in chronological order
    df_cash_flow.sort_values(by='fiscal_date', inplace=True)
    
    # Reset index after sorting
    df_cash_flow.reset_index(drop=True, inplace=True)
    
    print(df_cash_flow.head())  # Display the first few rows of the DataFrame
else:
    print(f"Failed to fetch data: {response.status_code}")
df_cash_flow.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12344\1513728967.py in ?()
#      27     for key in data['meta']:
#      28         df_cash_flow[key] = data['meta'][key]
#      29
#      30     # Sort the DataFrame by 'fiscal_date' to ensure it's in chronological order
# ---> 31     df_cash_flow.sort_values(by='fiscal_date', inplace=True)
#      32
#      33     # Reset index after sorting
#      34     df_cash_flow.reset_index(drop=True, inplace=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'fiscal_date'

# %%
csv_file_name = 'cash_flow_data.csv'

# Check if the CSV file already exists to decide on writing headers or not
write_header = not os.path.exists(csv_file_name)

# Iterate over each ticker symbol
for symbol in tickers:
    print(f"Processing {symbol}...")
    url = f'https://api.twelvedata.com/cash_flow?symbol={symbol}&apikey={api_key}&period=annual'
    
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200 and 'cash_flow' in response.json():
        data = response.json()
        
        # Check if cash_flow data is not empty
        if 'cash_flow' in data and data['cash_flow']:
            # Normalize the data and create a DataFrame
            df_cash_flow = pd.json_normalize(data['cash_flow'])
            
            # Add the 'meta' information as new columns, if needed
            if 'meta' in data:
                for key in data['meta']:
                    df_cash_flow[key] = data['meta'][key]
            
            # Check if 'fiscal_date' column exists before sorting
            if 'fiscal_date' in df_cash_flow.columns:
                df_cash_flow.sort_values(by='fiscal_date', inplace=True)
                df_cash_flow.reset_index(drop=True, inplace=True)
            else:
                print(f"'fiscal_date' column not found in data for {symbol}.")
            
            # Append DataFrame to the CSV file
            df_cash_flow.to_csv(csv_file_name, mode='a', index=False, header=write_header)
            
            # Ensure the header is not written again in subsequent writes
            write_header = False
            
            print(f"Data for {symbol} added to {csv_file_name}.")
        else:
            print(f"No cash flow data available for {symbol}.")
    else:
        print(f"Failed to fetch data for {symbol}. Status code: {response.status_code}")
    
    # Wait for 12 seconds before processing the next ticker
    time.sleep(12)

print("All requested data processed.")
# Out:
# Processing MSFT...
# Data for MSFT added to cash_flow_data.csv.
# Processing AAPL...
# Data for AAPL added to cash_flow_data.csv.
# Processing NVDA...
# Data for NVDA added to cash_flow_data.csv.
# Processing AMZN...
# Data for AMZN added to cash_flow_data.csv.
# Processing GOOGL...
# Data for GOOGL added to cash_flow_data.csv.
# Processing META...
# Data for META added to cash_flow_data.csv.
# Processing BRK.B...
# Data for BRK.B added to cash_flow_data.csv.
# Processing LLY...
# Data for LLY added to cash_flow_data.csv.
# Processing TSM...
# Data for TSM added to cash_flow_data.csv.
# Processing AVGO...
# Data for AVGO added to cash_flow_data.csv.
# Processing TSLA...
# Data for TSLA added to cash_flow_data.csv.
# Processing V...
# Data for V added to cash_flow_data.csv.
# Processing NVO...
# Data for NVO added to cash_flow_data.csv.
# Processing JPM...
# Data for JPM added to cash_flow_data.csv.
# Processing WMT...
# Data for WMT added to cash_flow_data.csv.
# Processing UNH...
# Data for UNH added to cash_flow_data.csv.
# Processing MA...
# Data for MA added to cash_flow_data.csv.
# Processing XOM...
# Data for XOM added to cash_flow_data.csv.
# Processing ASML...
# Data for ASML added to cash_flow_data.csv.
# Processing JNJ...
# Data for JNJ added to cash_flow_data.csv.
# Processing HD...
# Data for HD added to cash_flow_data.csv.
# Processing PG...
# Data for PG added to cash_flow_data.csv.
# Processing COST...
# Data for COST added to cash_flow_data.csv.
# Processing TM...
# Data for TM added to cash_flow_data.csv.
# Processing AMD...
# Data for AMD added to cash_flow_data.csv.
# Processing MRK...
# Data for MRK added to cash_flow_data.csv.
# Processing ABBV...
# Data for ABBV added to cash_flow_data.csv.
# Processing ORCL...
# Data for ORCL added to cash_flow_data.csv.
# Processing CRM...
# Data for CRM added to cash_flow_data.csv.
# Processing CVX...
# Data for CVX added to cash_flow_data.csv.
# Processing BAC...
# Data for BAC added to cash_flow_data.csv.
# Processing NFLX...
# Data for NFLX added to cash_flow_data.csv.
# Processing ADBE...
# Data for ADBE added to cash_flow_data.csv.
# Processing KO...
# Data for KO added to cash_flow_data.csv.
# Processing ACN...
# Data for ACN added to cash_flow_data.csv.
# Processing PEP...
# Data for PEP added to cash_flow_data.csv.
# Processing FMX...
# No cash flow data available for FMX.
# Processing SAP...
# Data for SAP added to cash_flow_data.csv.
# Processing TMO...
# Data for TMO added to cash_flow_data.csv.
# Processing LIN...
# Data for LIN added to cash_flow_data.csv.
# Processing MCD...
# Data for MCD added to cash_flow_data.csv.
# Processing NVS...
# Data for NVS added to cash_flow_data.csv.
# Processing ABT...
# Data for ABT added to cash_flow_data.csv.
# Processing DIS...
# Data for DIS added to cash_flow_data.csv.
# Processing SHEL...
# Data for SHEL added to cash_flow_data.csv.
# Processing AZN...
# Data for AZN added to cash_flow_data.csv.
# Processing WFC...
# Data for WFC added to cash_flow_data.csv.
# Processing CSCO...
# Data for CSCO added to cash_flow_data.csv.
# Processing TMUS...
# Data for TMUS added to cash_flow_data.csv.
# Processing DHR...
# Data for DHR added to cash_flow_data.csv.
# Processing BABA...
# Data for BABA added to cash_flow_data.csv.
# Processing INTU...
# Data for INTU added to cash_flow_data.csv.
# Processing INTC...
# Data for INTC added to cash_flow_data.csv.
# Processing QCOM...
# Data for QCOM added to cash_flow_data.csv.
# Processing AMAT...
# Data for AMAT added to cash_flow_data.csv.
# Processing GE...
# Data for GE added to cash_flow_data.csv.
# Processing IBM...
# Data for IBM added to cash_flow_data.csv.
# Processing CMCSA...
# Data for CMCSA added to cash_flow_data.csv.
# Processing VZ...
# Data for VZ added to cash_flow_data.csv.
# Processing PDD...
# Data for PDD added to cash_flow_data.csv.
# Processing UBER...
# Data for UBER added to cash_flow_data.csv.
# Processing CAT...
# Data for CAT added to cash_flow_data.csv.
# Processing AXP...
# Data for AXP added to cash_flow_data.csv.
# Processing NOW...
# Data for NOW added to cash_flow_data.csv.
# Processing TXN...
# Data for TXN added to cash_flow_data.csv.
# Processing BX...
# Data for BX added to cash_flow_data.csv.
# Processing NKE...
# Data for NKE added to cash_flow_data.csv.
# Processing UNP...
# Data for UNP added to cash_flow_data.csv.
# Processing TTE...
# Data for TTE added to cash_flow_data.csv.
# Processing AMGN...
# Data for AMGN added to cash_flow_data.csv.
# Processing PFE...
# Data for PFE added to cash_flow_data.csv.
# Processing HSBC...
# No cash flow data available for HSBC.
# Processing BHP...
# No cash flow data available for BHP.
# Processing MS...
# Data for MS added to cash_flow_data.csv.
# Processing LOW...
# Data for LOW added to cash_flow_data.csv.
# Processing ISRG...
# Data for ISRG added to cash_flow_data.csv.
# Processing PM...
# Data for PM added to cash_flow_data.csv.
# Processing HDB...
# No cash flow data available for HDB.
# Processing RY...
# Data for RY added to cash_flow_data.csv.
# Processing SPGI...
# Data for SPGI added to cash_flow_data.csv.
# Processing COP...
# Data for COP added to cash_flow_data.csv.
# Processing SYK...
# Data for SYK added to cash_flow_data.csv.
# Processing HON...
# Data for HON added to cash_flow_data.csv.
# Processing LRCX...
# Data for LRCX added to cash_flow_data.csv.
# Processing GS...
# Data for GS added to cash_flow_data.csv.
# Processing UPS...
# Data for UPS added to cash_flow_data.csv.
# Processing PLD...
# Data for PLD added to cash_flow_data.csv.
# Processing MUFG...
# No cash flow data available for MUFG.
# Processing UL...
# No cash flow data available for UL.
# Processing BA...
# Data for BA added to cash_flow_data.csv.
# Processing T...
# Data for T added to cash_flow_data.csv.
# Processing BLK...
# Data for BLK added to cash_flow_data.csv.
# Processing SCHW...
# Data for SCHW added to cash_flow_data.csv.
# Processing BUD...
# No cash flow data available for BUD.
# Processing BKNG...
# Data for BKNG added to cash_flow_data.csv.
# Processing RTX...
# Data for RTX added to cash_flow_data.csv.
# Processing SNY...
# No cash flow data available for SNY.
# Processing ETN...
# Data for ETN added to cash_flow_data.csv.
# Processing ELV...
# Data for ELV added to cash_flow_data.csv.
# Processing NEE...
# Data for NEE added to cash_flow_data.csv.
# Processing TJX...
# Data for TJX added to cash_flow_data.csv.
# Processing VRTX...
# Data for VRTX added to cash_flow_data.csv.
# Processing MDT...
# Data for MDT added to cash_flow_data.csv.
# Processing PGR...
# Data for PGR added to cash_flow_data.csv.
# Processing SONY...
# Data for SONY added to cash_flow_data.csv.
# Processing FMC...
# Data for FMC added to cash_flow_data.csv.
# Processing CIVI...
# Data for CIVI added to cash_flow_data.csv.
# Processing UI...
# Data for UI added to cash_flow_data.csv.
# Processing AZEK...
# Data for AZEK added to cash_flow_data.csv.
# Processing YMM...
# No cash flow data available for YMM.
# Processing RHP...
# Data for RHP added to cash_flow_data.csv.
# Processing BZ...
# Data for BZ added to cash_flow_data.csv.
# Processing TKO...
# Data for TKO added to cash_flow_data.csv.
# Processing NYT...
# Data for NYT added to cash_flow_data.csv.
# Processing GPS...
# Data for GPS added to cash_flow_data.csv.
# Processing ALTR...
# Data for ALTR added to cash_flow_data.csv.
# Processing NFE...
# Data for NFE added to cash_flow_data.csv.
# Processing XRAY...
# Data for XRAY added to cash_flow_data.csv.
# Processing CCCS...
# Data for CCCS added to cash_flow_data.csv.
# Processing SPSC...
# Data for SPSC added to cash_flow_data.csv.
# Processing STAG...
# Data for STAG added to cash_flow_data.csv.
# Processing IVZ...
# Data for IVZ added to cash_flow_data.csv.
# Processing HAS...
# Data for HAS added to cash_flow_data.csv.
# Processing DAR...
# Data for DAR added to cash_flow_data.csv.
# Processing RMBS...
# Data for RMBS added to cash_flow_data.csv.
# Processing HQY...
# Data for HQY added to cash_flow_data.csv.
# Processing RGLD...
# Data for RGLD added to cash_flow_data.csv.
# Processing ICL...
# Data for ICL added to cash_flow_data.csv.
# Processing BILL...
# Data for BILL added to cash_flow_data.csv.
# Processing VOYA...
# Data for VOYA added to cash_flow_data.csv.
# Processing CFR...
# Data for CFR added to cash_flow_data.csv.
# Processing ITCI...
# Data for ITCI added to cash_flow_data.csv.
# Processing ENSG...
# Data for ENSG added to cash_flow_data.csv.
# Processing MAT...
# Data for MAT added to cash_flow_data.csv.
# Processing FOUR...
# Data for FOUR added to cash_flow_data.csv.
# Processing GNRC...
# Data for GNRC added to cash_flow_data.csv.
# Processing THO...
# Data for THO added to cash_flow_data.csv.
# Processing BRX...
# Data for BRX added to cash_flow_data.csv.
# Processing IBP...
# Data for IBP added to cash_flow_data.csv.
# Processing WTS...
# Data for WTS added to cash_flow_data.csv.
# Processing CGNX...
# Data for CGNX added to cash_flow_data.csv.
# Processing CHRD...
# Data for CHRD added to cash_flow_data.csv.
# Processing CACC...
# Data for CACC added to cash_flow_data.csv.
# Processing AAON...
# Data for AAON added to cash_flow_data.csv.
# Processing BERY...
# Data for BERY added to cash_flow_data.csv.
# Processing MMYT...
# Data for MMYT added to cash_flow_data.csv.
# Processing LBTYK...
# Data for LBTYK added to cash_flow_data.csv.
# Processing ALSN...
# Data for ALSN added to cash_flow_data.csv.
# Processing CBSH...
# Data for CBSH added to cash_flow_data.csv.
# Processing EXEL...
# Data for EXEL added to cash_flow_data.csv.
# Processing NOV...
# Data for NOV added to cash_flow_data.csv.
# Processing ADT...
# Data for ADT added to cash_flow_data.csv.
# Processing BFAM...
# Data for BFAM added to cash_flow_data.csv.
# Processing CRSP...
# Data for CRSP added to cash_flow_data.csv.
# Processing HRB...
# Data for HRB added to cash_flow_data.csv.
# Processing MTZ...
# Data for MTZ added to cash_flow_data.csv.
# Processing MASI...
# Data for MASI added to cash_flow_data.csv.
# Processing MTSI...
# Data for MTSI added to cash_flow_data.csv.
# Processing RLI...
# Data for RLI added to cash_flow_data.csv.
# Processing DDS...
# Data for DDS added to cash_flow_data.csv.
# Processing LSTR...
# Data for LSTR added to cash_flow_data.csv.
# Processing AGNC...
# Data for AGNC added to cash_flow_data.csv.
# Processing WFG...
# Data for WFG added to cash_flow_data.csv.
# Processing STWD...
# Data for STWD added to cash_flow_data.csv.
# Processing VNT...
# Data for VNT added to cash_flow_data.csv.
# Processing IONS...
# Data for IONS added to cash_flow_data.csv.
# Processing CAVA...
# Data for CAVA added to cash_flow_data.csv.
# Processing ANF...
# Data for ANF added to cash_flow_data.csv.
# Processing OGE...
# Data for OGE added to cash_flow_data.csv.
# Processing OLN...
# Data for OLN added to cash_flow_data.csv.
# Processing CMA...
# Data for CMA added to cash_flow_data.csv.
# Processing LYFT...
# Data for LYFT added to cash_flow_data.csv.
# Processing UGP...
# Data for UGP added to cash_flow_data.csv.
# Processing AM...
# Data for AM added to cash_flow_data.csv.
# Processing VNOM...
# Data for VNOM added to cash_flow_data.csv.
# Processing CART...
# Data for CART added to cash_flow_data.csv.
# Processing ARW...
# Data for ARW added to cash_flow_data.csv.
# Processing TNET...
# Data for TNET added to cash_flow_data.csv.
# Processing CR...
# Data for CR added to cash_flow_data.csv.
# Processing SFM...
# Data for SFM added to cash_flow_data.csv.
# Processing CSAN...
# Data for CSAN added to cash_flow_data.csv.
# Processing KVYO...
# Data for KVYO added to cash_flow_data.csv.
# Processing ATKR...
# Data for ATKR added to cash_flow_data.csv.
# Processing AN...
# Data for AN added to cash_flow_data.csv.
# Processing POST...
# Data for POST added to cash_flow_data.csv.
# Processing HXL...
# Data for HXL added to cash_flow_data.csv.
# Processing VFC...
# Data for VFC added to cash_flow_data.csv.
# Processing SIGI...
# Data for SIGI added to cash_flow_data.csv.
# Processing ATI...
# Data for ATI added to cash_flow_data.csv.
# Processing BROS...
# Data for BROS added to cash_flow_data.csv.
# Processing NOVT...
# Data for NOVT added to cash_flow_data.csv.
# Processing ALGM...
# Data for ALGM added to cash_flow_data.csv.
# Processing GTLS...
# Data for GTLS added to cash_flow_data.csv.
# Processing BBIO...
# Data for BBIO added to cash_flow_data.csv.
# Processing HLNE...
# Data for HLNE added to cash_flow_data.csv.
# Processing SSB...
# Data for SSB added to cash_flow_data.csv.
# Processing FLR...
# Data for FLR added to cash_flow_data.csv.
# Processing CMC...
# Data for CMC added to cash_flow_data.csv.
# Processing KGC...
# Data for KGC added to cash_flow_data.csv.
# Processing BYD...
# Data for BYD added to cash_flow_data.csv.
# Processing PNFP...
# Data for PNFP added to cash_flow_data.csv.
# Processing WAL...
# Data for WAL added to cash_flow_data.csv.
# Processing QLYS...
# Data for QLYS added to cash_flow_data.csv.
# Processing NE...
# Data for NE added to cash_flow_data.csv.
# Processing MUR...
# Data for MUR added to cash_flow_data.csv.
# Processing NEU...
# Data for NEU added to cash_flow_data.csv.
# Processing REYN...
# Data for REYN added to cash_flow_data.csv.
# Processing WH...
# Data for WH added to cash_flow_data.csv.
# Processing NSIT...
# Data for NSIT added to cash_flow_data.csv.
# Processing TMHC...
# Data for TMHC added to cash_flow_data.csv.
# Processing CHX...
# Data for CHX added to cash_flow_data.csv.
# Processing G...
# Data for G added to cash_flow_data.csv.
# Processing GXO...
# Data for GXO added to cash_flow_data.csv.
# Processing FAF...
# Data for FAF added to cash_flow_data.csv.
# Processing ELP...
# Data for ELP added to cash_flow_data.csv.
# Processing FRSH...
# Data for FRSH added to cash_flow_data.csv.
# Processing CAE...
# Data for CAE added to cash_flow_data.csv.
# Processing MARA...
# Data for MARA added to cash_flow_data.csv.
# Processing DRS...
# Data for DRS added to cash_flow_data.csv.
# Processing BC...
# Data for BC added to cash_flow_data.csv.
# Processing ESAB...
# Data for ESAB added to cash_flow_data.csv.
# Processing MNSO...
# No cash flow data available for MNSO.
# Processing BPOP...
# Data for BPOP added to cash_flow_data.csv.
# Processing LFUS...
# Data for LFUS added to cash_flow_data.csv.
# Processing WTFC...
# Data for WTFC added to cash_flow_data.csv.
# Processing ALTM...
# Data for ALTM added to cash_flow_data.csv.
# Processing TKR...
# Data for TKR added to cash_flow_data.csv.
# Processing RRR...
# Data for RRR added to cash_flow_data.csv.
# Processing GRFS...
# Data for GRFS added to cash_flow_data.csv.
# Processing OBDC...
# Data for OBDC added to cash_flow_data.csv.
# Processing CIGI...
# Data for CIGI added to cash_flow_data.csv.
# Processing RCM...
# Data for RCM added to cash_flow_data.csv.
# Processing SMAR...
# Data for SMAR added to cash_flow_data.csv.
# Processing FYBR...
# Data for FYBR added to cash_flow_data.csv.
# Processing MLI...
# Data for MLI added to cash_flow_data.csv.
# Processing GIL...
# Data for GIL added to cash_flow_data.csv.
# Processing WHR...
# Data for WHR added to cash_flow_data.csv.
# Processing FTAI...
# Data for FTAI added to cash_flow_data.csv.
# Processing OMF...
# Data for OMF added to cash_flow_data.csv.
# Processing PBF...
# Data for PBF added to cash_flow_data.csv.
# Processing BPMC...
# Data for BPMC added to cash_flow_data.csv.
# Processing PB...
# Data for PB added to cash_flow_data.csv.
# Processing BLCO...
# Data for BLCO added to cash_flow_data.csv.
# Processing MTH...
# Data for MTH added to cash_flow_data.csv.
# Processing CIG...
# Data for CIG added to cash_flow_data.csv.
# Processing ENLC...
# Data for ENLC added to cash_flow_data.csv.
# Processing ZION...
# Data for ZION added to cash_flow_data.csv.
# Processing TRNO...
# Data for TRNO added to cash_flow_data.csv.
# Processing ESNT...
# Data for ESNT added to cash_flow_data.csv.
# Processing ESI...
# Data for ESI added to cash_flow_data.csv.
# Processing ADC...
# Data for ADC added to cash_flow_data.csv.
# Processing BRZE...
# Data for BRZE added to cash_flow_data.csv.
# Processing LANC...
# Data for LANC added to cash_flow_data.csv.
# Processing TENB...
# Data for TENB added to cash_flow_data.csv.
# Processing MSM...
# Data for MSM added to cash_flow_data.csv.
# Processing MXCT...
# Data for MXCT added to cash_flow_data.csv.
# Processing BALY...
# Data for BALY added to cash_flow_data.csv.
# Processing SRI...
# Data for SRI added to cash_flow_data.csv.
# Processing IVVD...
# Data for IVVD added to cash_flow_data.csv.
# Processing BWMN...
# Data for BWMN added to cash_flow_data.csv.
# Processing EQBK...
# Data for EQBK added to cash_flow_data.csv.
# Processing SD...
# Data for SD added to cash_flow_data.csv.
# Processing DJCO...
# Data for DJCO added to cash_flow_data.csv.
# Processing ATLC...
# Data for ATLC added to cash_flow_data.csv.
# Processing LSEA...
# Data for LSEA added to cash_flow_data.csv.
# Processing DENN...
# Data for DENN added to cash_flow_data.csv.
# Processing SMBC...
# Data for SMBC added to cash_flow_data.csv.
# Processing GUTS...
# Data for GUTS added to cash_flow_data.csv.
# Processing ASLE...
# Data for ASLE added to cash_flow_data.csv.
# Processing CCBG...
# Data for CCBG added to cash_flow_data.csv.
# Processing VPG...
# Data for VPG added to cash_flow_data.csv.
# Processing LWLG...
# Data for LWLG added to cash_flow_data.csv.
# Processing OFIX...
# Data for OFIX added to cash_flow_data.csv.
# Processing AEON...
# Data for AEON added to cash_flow_data.csv.
# Processing LIND...
# Data for LIND added to cash_flow_data.csv.
# Processing LND...
# Data for LND added to cash_flow_data.csv.
# Processing MTW...
# Data for MTW added to cash_flow_data.csv.
# Processing CTLP...
# Data for CTLP added to cash_flow_data.csv.
# Processing RSVR...
# Data for RSVR added to cash_flow_data.csv.
# Processing ABUS...
# Data for ABUS added to cash_flow_data.csv.
# Processing AMNB...
# Data for AMNB added to cash_flow_data.csv.
# Processing NN...
# Data for NN added to cash_flow_data.csv.
# Processing LAND...
# Data for LAND added to cash_flow_data.csv.
# Processing FPH...
# Data for FPH added to cash_flow_data.csv.
# Processing HCAT...
# Data for HCAT added to cash_flow_data.csv.
# Processing ESPR...
# Data for ESPR added to cash_flow_data.csv.
# Processing JOUT...
# Data for JOUT added to cash_flow_data.csv.
# Processing ALNT...
# Data for ALNT added to cash_flow_data.csv.
# Processing RXT...
# Data for RXT added to cash_flow_data.csv.
# Processing CATX...
# Data for CATX added to cash_flow_data.csv.
# Processing GCBC...
# Data for GCBC added to cash_flow_data.csv.
# Processing ANNX...
# Data for ANNX added to cash_flow_data.csv.
# Processing RGP...
# Data for RGP added to cash_flow_data.csv.
# Processing EGY...
# Data for EGY added to cash_flow_data.csv.
# Processing TPB...
# Data for TPB added to cash_flow_data.csv.
# Processing ZH...
# No cash flow data available for ZH.
# Processing VTRU...
# Data for VTRU added to cash_flow_data.csv.
# Processing DGICA...
# Data for DGICA added to cash_flow_data.csv.
# Processing CWCO...
# Data for CWCO added to cash_flow_data.csv.
# Processing RCEL...
# Data for RCEL added to cash_flow_data.csv.
# Processing CLFD...
# Data for CLFD added to cash_flow_data.csv.
# Processing DGICB...
# Data for DGICB added to cash_flow_data.csv.
# Processing AXGN...
# Data for AXGN added to cash_flow_data.csv.
# Processing ZIMV...
# Data for ZIMV added to cash_flow_data.csv.
# Processing ALCC...
# Data for ALCC added to cash_flow_data.csv.
# Processing TRDA...
# Data for TRDA added to cash_flow_data.csv.
# Processing ADTN...
# Data for ADTN added to cash_flow_data.csv.
# Processing HONE...
# Data for HONE added to cash_flow_data.csv.
# Processing CAC...
# Data for CAC added to cash_flow_data.csv.
# Processing SRDX...
# Data for SRDX added to cash_flow_data.csv.
# Processing AVAH...
# Data for AVAH added to cash_flow_data.csv.
# Processing HAFC...
# Data for HAFC added to cash_flow_data.csv.
# Processing AURA...
# Data for AURA added to cash_flow_data.csv.
# Processing STTK...
# Data for STTK added to cash_flow_data.csv.
# Processing MCS...
# Data for MCS added to cash_flow_data.csv.
# Processing TBPH...
# Data for TBPH added to cash_flow_data.csv.
# Processing TGB...
# Data for TGB added to cash_flow_data.csv.
# Processing KODK...
# Data for KODK added to cash_flow_data.csv.
# Processing TERN...
# Data for TERN added to cash_flow_data.csv.
# Processing HTBI...
# Data for HTBI added to cash_flow_data.csv.
# Processing MGX...
# Data for MGX added to cash_flow_data.csv.
# Processing NTGR...
# Data for NTGR added to cash_flow_data.csv.
# Processing NFBK...
# Data for NFBK added to cash_flow_data.csv.
# Processing TRC...
# Data for TRC added to cash_flow_data.csv.
# Processing BETR...
# Data for BETR added to cash_flow_data.csv.
# Processing ORC...
# Data for ORC added to cash_flow_data.csv.
# Processing GDEV...
# Data for GDEV added to cash_flow_data.csv.
# Processing URG...
# Data for URG added to cash_flow_data.csv.
# Processing RDZN...
# Data for RDZN added to cash_flow_data.csv.
# Processing WTI...
# Data for WTI added to cash_flow_data.csv.
# Processing PNNT...
# Data for PNNT added to cash_flow_data.csv.
# Processing GHRS...
# Data for GHRS added to cash_flow_data.csv.
# Processing GATO...
# Data for GATO added to cash_flow_data.csv.
# Processing EHAB...
# Data for EHAB added to cash_flow_data.csv.
# Processing GLAD...
# Data for GLAD added to cash_flow_data.csv.
# Processing TSAT...
# Data for TSAT added to cash_flow_data.csv.
# Processing MED...
# Data for MED added to cash_flow_data.csv.
# Processing BBCP...
# Data for BBCP added to cash_flow_data.csv.
# Processing BLZE...
# Data for BLZE added to cash_flow_data.csv.
# Processing CELC...
# Data for CELC added to cash_flow_data.csv.
# Processing XERS...
# Data for XERS added to cash_flow_data.csv.
# Processing SVM...
# Data for SVM added to cash_flow_data.csv.
# Processing MVIS...
# Data for MVIS added to cash_flow_data.csv.
# Processing WASH...
# Data for WASH added to cash_flow_data.csv.
# Processing GLRE...
# Data for GLRE added to cash_flow_data.csv.
# Processing IVR...
# Data for IVR added to cash_flow_data.csv.
# Processing AVNW...
# Data for AVNW added to cash_flow_data.csv.
# Processing ANSC...
# Data for ANSC added to cash_flow_data.csv.
# Processing OCS...
# Data for OCS added to cash_flow_data.csv.
# Processing OSG...
# Data for OSG added to cash_flow_data.csv.
# Processing DHIL...
# Data for DHIL added to cash_flow_data.csv.
# Processing EAF...
# Data for EAF added to cash_flow_data.csv.
# Processing THFF...
# Data for THFF added to cash_flow_data.csv.
# Processing CVRX...
# Data for CVRX added to cash_flow_data.csv.
# Processing SLAM...
# Data for SLAM added to cash_flow_data.csv.
# Processing AVXL...
# Data for AVXL added to cash_flow_data.csv.
# Processing AMRN...
# Data for AMRN added to cash_flow_data.csv.
# Processing CRMT...
# Data for CRMT added to cash_flow_data.csv.
# Processing FFWM...
# Data for FFWM added to cash_flow_data.csv.
# Processing DCGO...
# Data for DCGO added to cash_flow_data.csv.
# Processing OLP...
# Data for OLP added to cash_flow_data.csv.
# Processing AUDC...
# Data for AUDC added to cash_flow_data.csv.
# Processing ALRS...
# Data for ALRS added to cash_flow_data.csv.
# Processing BTMD...
# Data for BTMD added to cash_flow_data.csv.
# Processing GDOT...
# Data for GDOT added to cash_flow_data.csv.
# Processing NYXH...
# Data for NYXH added to cash_flow_data.csv.
# Processing SPFI...
# Data for SPFI added to cash_flow_data.csv.
# Processing FBLG...
# Data for FBLG added to cash_flow_data.csv.
# Processing ACRE...
# Data for ACRE added to cash_flow_data.csv.
# Processing PGC...
# Data for PGC added to cash_flow_data.csv.
# Processing CLOV...
# Data for CLOV added to cash_flow_data.csv.
# Processing CCG...
# No cash flow data available for CCG.
# Processing DOMO...
# Data for DOMO added to cash_flow_data.csv.
# Processing MCB...
# Data for MCB added to cash_flow_data.csv.
# Processing PGEN...
# Data for PGEN added to cash_flow_data.csv.
# Processing NPCE...
# Data for NPCE added to cash_flow_data.csv.
# Processing ONEW...
# Data for ONEW added to cash_flow_data.csv.
# Processing NVEC...
# Data for NVEC added to cash_flow_data.csv.
# Processing EPIX...
# Data for EPIX added to cash_flow_data.csv.
# Processing LYTS...
# Data for LYTS added to cash_flow_data.csv.
# Processing FARO...
# Data for FARO added to cash_flow_data.csv.
# Processing TMC...
# Data for TMC added to cash_flow_data.csv.
# Processing GFR...
# Data for GFR added to cash_flow_data.csv.
# Processing ESQ...
# Data for ESQ added to cash_flow_data.csv.
# Processing THRD...
# Data for THRD added to cash_flow_data.csv.
# Processing CCNE...
# Data for CCNE added to cash_flow_data.csv.
# Processing PBPB...
# Data for PBPB added to cash_flow_data.csv.
# Processing NBN...
# Data for NBN added to cash_flow_data.csv.
# Processing STRW...
# Data for STRW added to cash_flow_data.csv.
# Processing FSBC...
# Data for FSBC added to cash_flow_data.csv.
# Processing BHRB...
# Data for BHRB added to cash_flow_data.csv.
# Processing LXEO...
# Data for LXEO added to cash_flow_data.csv.
# Processing IAUX...
# Data for IAUX added to cash_flow_data.csv.
# Processing LAW...
# Data for LAW added to cash_flow_data.csv.
# Processing MGTX...
# Data for MGTX added to cash_flow_data.csv.
# Processing RMR...
# Data for RMR added to cash_flow_data.csv.
# Processing NGNE...
# Data for NGNE added to cash_flow_data.csv.
# Processing AROW...
# Data for AROW added to cash_flow_data.csv.
# Processing GBLI...
# Data for GBLI added to cash_flow_data.csv.
# Processing ACTG...
# Data for ACTG added to cash_flow_data.csv.
# Processing INZY...
# Data for INZY added to cash_flow_data.csv.
# Processing ITOS...
# Data for ITOS added to cash_flow_data.csv.
# Processing STEM...
# Data for STEM added to cash_flow_data.csv.
# Processing ARMN...
# Data for ARMN added to cash_flow_data.csv.
# Processing MODV...
# Data for MODV added to cash_flow_data.csv.
# Processing NCMI...
# Data for NCMI added to cash_flow_data.csv.
# Processing ANRO...
# Data for ANRO added to cash_flow_data.csv.
# Processing NETD...
# Data for NETD added to cash_flow_data.csv.
# Processing VALU...
# Data for VALU added to cash_flow_data.csv.
# Processing HRZN...
# Data for HRZN added to cash_flow_data.csv.
# Processing OPY...
# Data for OPY added to cash_flow_data.csv.
# Processing VNET...
# Data for VNET added to cash_flow_data.csv.
# Processing SGU...
# Data for SGU added to cash_flow_data.csv.
# Processing ZYXI...
# Data for ZYXI added to cash_flow_data.csv.
# Processing OSPN...
# Data for OSPN added to cash_flow_data.csv.
# Processing 33L...
# Data for 33L added to cash_flow_data.csv.
# Processing B2W...
# Data for B2W added to cash_flow_data.csv.
# Processing MMSMY...
# No cash flow data available for MMSMY.
# Processing GYUAF...
# No cash flow data available for GYUAF.
# Processing 300011...
# Data for 300011 added to cash_flow_data.csv.
# Processing LVS...
# Data for LVS added to cash_flow_data.csv.
# Processing 7225...
# Data for 7225 added to cash_flow_data.csv.
# Processing ISU...
# No cash flow data available for ISU.
# Processing NUTEX...
# No cash flow data available for NUTEX.
# Processing 9686...
# No cash flow data available for 9686.
# Processing AT0000A370Z6...
# No cash flow data available for AT0000A370Z6.
# Processing LMMFF...
# No cash flow data available for LMMFF.
# Processing APEOF...
# Data for APEOF added to cash_flow_data.csv.
# Processing CZO...
# Data for CZO added to cash_flow_data.csv.
# Processing 267250...
# Data for 267250 added to cash_flow_data.csv.
# Processing TEND...
# No cash flow data available for TEND.
# Processing 0MM3...
# No cash flow data available for 0MM3.
# Processing EGS21451C017...
# No cash flow data available for EGS21451C017.
# Processing B2LN34...
# No cash flow data available for B2LN34.
# Processing TINPLATE...
# No cash flow data available for TINPLATE.
# Processing EDDYF...
# Data for EDDYF added to cash_flow_data.csv.
# Processing 200541...
# Data for 200541 added to cash_flow_data.csv.
# Processing IBULHSGFIN.AJ...
# No cash flow data available for IBULHSGFIN.AJ.
# Processing OSL...
# No cash flow data available for OSL.
# Processing 3661...
# No cash flow data available for 3661.
# Processing 6UA...
# No cash flow data available for 6UA.
# Processing PX0...
# Failed to fetch data for PX0. Status code: 502
# Processing 065484...
# No cash flow data available for 065484.
# Processing HY5A...
# No cash flow data available for HY5A.
# Processing HVY...
# No cash flow data available for HVY.
# Processing CVS0...
# Data for CVS0 added to cash_flow_data.csv.
# Processing GVLMY...
# No cash flow data available for GVLMY.
# Processing UNTY...
# Data for UNTY added to cash_flow_data.csv.
# Processing BLEVF...
# No cash flow data available for BLEVF.
# Processing REXR.PR.B...
# Data for REXR.PR.B added to cash_flow_data.csv.
# Processing 076702...
# No cash flow data available for 076702.
# Processing PNP...
# Data for PNP added to cash_flow_data.csv.
# Processing WF6...
# Data for WF6 added to cash_flow_data.csv.
# Processing 001308...
# Data for 001308 added to cash_flow_data.csv.
# Processing AKGRT...
# Data for AKGRT added to cash_flow_data.csv.
# Processing CPER...
# No cash flow data available for CPER.
# Processing 0N7X...
# Data for 0N7X added to cash_flow_data.csv.
# Processing SOUHY...
# No cash flow data available for SOUHY.
# Processing TMV...
# No cash flow data available for TMV.
# Processing CS6...
# Data for CS6 added to cash_flow_data.csv.
# Processing 076262...
# No cash flow data available for 076262.
# Processing AT0000A2NXY1...
# No cash flow data available for AT0000A2NXY1.
# Processing 002505...
# Data for 002505 added to cash_flow_data.csv.
# Processing VSACU...
# Data for VSACU added to cash_flow_data.csv.
# Processing MYIDF...
# Data for MYIDF added to cash_flow_data.csv.
# Processing 0JJM...
# Data for 0JJM added to cash_flow_data.csv.
# Processing CNHI...
# Data for CNHI added to cash_flow_data.csv.
# Processing R5XA...
# Data for R5XA added to cash_flow_data.csv.
# Processing TWP.R...
# Data for TWP.R added to cash_flow_data.csv.
# Processing KIND.SDB...
# Data for KIND.SDB added to cash_flow_data.csv.
# Processing GCY...
# Data for GCY added to cash_flow_data.csv.
# Processing BULL.SILVER.X4.AVA...
# No cash flow data available for BULL.SILVER.X4.AVA.
# Processing C0229A...
# No cash flow data available for C0229A.
# Processing OETO...
# No cash flow data available for OETO.
# Processing STEELCAS...
# No cash flow data available for STEELCAS.
# Processing D9F2...
# No cash flow data available for D9F2.
# Processing BBMD...
# Data for BBMD added to cash_flow_data.csv.
# Processing CITY...
# No cash flow data available for CITY.
# Processing NZ2...
# No cash flow data available for NZ2.
# Processing AT0000A2WSQ8...
# Data for AT0000A2WSQ8 added to cash_flow_data.csv.
# Processing 011150...
# Data for 011150 added to cash_flow_data.csv.
# Processing 0583...
# No cash flow data available for 0583.
# Processing IUE...
# No cash flow data available for IUE.
# Processing 9803...
# No cash flow data available for 9803.
# Processing NERG...
# No cash flow data available for NERG.
# Processing CY9D...
# Data for CY9D added to cash_flow_data.csv.
# Processing 83A...
# Data for 83A added to cash_flow_data.csv.
# Processing MMM...
# Data for MMM added to cash_flow_data.csv.
# Processing 131030...
# Data for 131030 added to cash_flow_data.csv.
# Processing ISEC...
# No cash flow data available for ISEC.
# Processing VE...
# No cash flow data available for VE.
# Processing LB4A...
# Data for LB4A added to cash_flow_data.csv.
# Processing 49MW...
# No cash flow data available for 49MW.
# Processing FOODSIN...
# No cash flow data available for FOODSIN.
# Processing PW2...
# Data for PW2 added to cash_flow_data.csv.
# Processing FPOR11...
# No cash flow data available for FPOR11.
# Processing 068790...
# Data for 068790 added to cash_flow_data.csv.
# Processing IDVA...
# Data for IDVA added to cash_flow_data.csv.
# Processing T2V1...
# Data for T2V1 added to cash_flow_data.csv.
# Processing UREKA...
# Data for UREKA added to cash_flow_data.csv.
# Processing 1CO1...
# Data for 1CO1 added to cash_flow_data.csv.
# Processing LU2290522684...
# No cash flow data available for LU2290522684.
# Processing MSKY...
# Data for MSKY added to cash_flow_data.csv.
# Processing WDIT24...
# No cash flow data available for WDIT24.
# Processing 600999...
# Data for 600999 added to cash_flow_data.csv.
# Processing DEFI...
# No cash flow data available for DEFI.
# Processing BJ8...
# No cash flow data available for BJ8.
# Processing 6BF...
# Data for 6BF added to cash_flow_data.csv.
# Processing J0Z...
# Data for J0Z added to cash_flow_data.csv.
# Processing 0UG9...
# Data for 0UG9 added to cash_flow_data.csv.
# Processing MMC...
# Data for MMC added to cash_flow_data.csv.
# Processing P7V...
# Data for P7V added to cash_flow_data.csv.
# Processing 052134...
# No cash flow data available for 052134.
# Processing SPU...
# Data for SPU added to cash_flow_data.csv.
# Processing 30Z...
# Data for 30Z added to cash_flow_data.csv.
# Processing JX90...
# No cash flow data available for JX90.
# Processing ZNHH...
# Data for ZNHH added to cash_flow_data.csv.
# Processing BEN.H...
# Data for BEN.H added to cash_flow_data.csv.
# Processing RAM...
# Data for RAM added to cash_flow_data.csv.
# Processing 7504...
# No cash flow data available for 7504.
# Processing HYPR...
# Data for HYPR added to cash_flow_data.csv.
# Processing XPCI11...
# No cash flow data available for XPCI11.
# Processing 5KD...
# Data for 5KD added to cash_flow_data.csv.
# Processing CHSN...
# No cash flow data available for CHSN.
# Processing 6LQ...
# Data for 6LQ added to cash_flow_data.csv.
# Processing FRYA...
# Data for FRYA added to cash_flow_data.csv.
# Processing 300187...
# Data for 300187 added to cash_flow_data.csv.
# Processing ALWEC...
# No cash flow data available for ALWEC.
# Processing 001339...
# Data for 001339 added to cash_flow_data.csv.
# Processing 83S2...
# No cash flow data available for 83S2.
# Processing CNPBP...
# Data for CNPBP added to cash_flow_data.csv.
# Processing SWUT...
# No cash flow data available for SWUT.
# Processing GX6...
# Data for GX6 added to cash_flow_data.csv.
# Processing WO7...
# Data for WO7 added to cash_flow_data.csv.
# Processing 4MDT...
# No cash flow data available for 4MDT.
# Processing YC2...
# No cash flow data available for YC2.
# Processing BTTX...
# Data for BTTX added to cash_flow_data.csv.
# Processing BBN...
# No cash flow data available for BBN.
# Processing RFG...
# No cash flow data available for RFG.
# Processing ENV...
# Data for ENV added to cash_flow_data.csv.
# Processing FPNUF...
# Data for FPNUF added to cash_flow_data.csv.
# Processing NYTTO...
# Data for NYTTO added to cash_flow_data.csv.
# Processing FLAP...
# Data for FLAP added to cash_flow_data.csv.
# Processing SAH...
# Data for SAH added to cash_flow_data.csv.
# Processing S94...
# Data for S94 added to cash_flow_data.csv.
# Processing MTNOY...
# No cash flow data available for MTNOY.
# Processing IDAM...
# No cash flow data available for IDAM.
# Processing DS3...
# Data for DS3 added to cash_flow_data.csv.
# Processing BWAQR...
# No cash flow data available for BWAQR.
# Processing BBQ...
# No cash flow data available for BBQ.
# Processing TL01...
# Data for TL01 added to cash_flow_data.csv.
# Processing BBH...
# No cash flow data available for BBH.
# Processing CITZ...
# No cash flow data available for CITZ.
# Processing K43...
# Data for K43 added to cash_flow_data.csv.
# Processing ZEEMEDIA...
# No cash flow data available for ZEEMEDIA.
# Processing UC9A6Y...
# No cash flow data available for UC9A6Y.
# Processing BBRYF...
# No cash flow data available for BBRYF.
# Processing ALODC...
# No cash flow data available for ALODC.
# Processing 1OXY...
# Data for 1OXY added to cash_flow_data.csv.
# Processing HTD...
# No cash flow data available for HTD.
# Processing 4LMT...
# No cash flow data available for 4LMT.
# Processing SMZ1...
# No cash flow data available for SMZ1.
# Processing NVG...
# No cash flow data available for NVG.
# Processing P9N...
# Data for P9N added to cash_flow_data.csv.
# Processing FRD...
# Data for FRD added to cash_flow_data.csv.
# Processing HHU...
# No cash flow data available for HHU.
# Processing 300669...
# Data for 300669 added to cash_flow_data.csv.
# Processing WHITF...
# No cash flow data available for WHITF.
# Processing WDFCD...
# Data for WDFCD added to cash_flow_data.csv.
# Processing 1776...
# Data for 1776 added to cash_flow_data.csv.
# Processing 6V2...
# Data for 6V2 added to cash_flow_data.csv.
# Processing ORA...
# Data for ORA added to cash_flow_data.csv.
# Processing CCAP...
# Data for CCAP added to cash_flow_data.csv.
# Processing GFI...
# No cash flow data available for GFI.
# Processing L7G...
# Data for L7G added to cash_flow_data.csv.
# Processing 6BE...
# Data for 6BE added to cash_flow_data.csv.
# Processing IOMT...
# No cash flow data available for IOMT.
# Processing SOBA...
# Data for SOBA added to cash_flow_data.csv.
# Processing NPABW...
# Data for NPABW added to cash_flow_data.csv.
# Processing DA4B...
# Data for DA4B added to cash_flow_data.csv.
# Processing LRC...
# Data for LRC added to cash_flow_data.csv.
# Processing NVE...
# Data for NVE added to cash_flow_data.csv.
# Processing USX1...
# Data for USX1 added to cash_flow_data.csv.
# Processing HSZ...
# Data for HSZ added to cash_flow_data.csv.
# Processing ZAL...
# Data for ZAL added to cash_flow_data.csv.
# Processing KBC...
# No cash flow data available for KBC.
# Processing AEDAS...
# No cash flow data available for AEDAS.
# Processing 301468...
# Data for 301468 added to cash_flow_data.csv.
# Processing GSRI...
# Data for GSRI added to cash_flow_data.csv.
# Processing 15M1...
# No cash flow data available for 15M1.
# Processing OFED...
# Data for OFED added to cash_flow_data.csv.
# Processing DUK...
# Data for DUK added to cash_flow_data.csv.
# Processing 2QG...
# No cash flow data available for 2QG.
# Processing SSOF...
# No cash flow data available for SSOF.
# Processing 5Z7...
# No cash flow data available for 5Z7.
# Processing 061...
# Data for 061 added to cash_flow_data.csv.
# Processing RR5...
# Data for RR5 added to cash_flow_data.csv.
# Processing CGUN...
# No cash flow data available for CGUN.
# Processing UPXI...
# Data for UPXI added to cash_flow_data.csv.
# Processing DMP...
# Data for DMP added to cash_flow_data.csv.
# Processing GB00BLDYK618...
# No cash flow data available for GB00BLDYK618.
# Processing RKM...
# No cash flow data available for RKM.
# Processing OI2...
# Data for OI2 added to cash_flow_data.csv.
# Processing 4142...
# Data for 4142 added to cash_flow_data.csv.
# Processing EMYB...
# Data for EMYB added to cash_flow_data.csv.
# Processing AT0000A393Y1...
# No cash flow data available for AT0000A393Y1.
# Processing INVK...
# Failed to fetch data for INVK. Status code: 200
# Processing MDD...
# No cash flow data available for MDD.
# Processing 05B...
# No cash flow data available for 05B.
# Processing 2760...
# Data for 2760 added to cash_flow_data.csv.
# Processing NTDOYN...
# No cash flow data available for NTDOYN.
# Processing DWDE...
# No cash flow data available for DWDE.
# Processing 4LRA...
# Data for 4LRA added to cash_flow_data.csv.
# Processing JP3206000006...
# No cash flow data available for JP3206000006.
# Processing 2769...
# Data for 2769 added to cash_flow_data.csv.
# Processing PP51...
# No cash flow data available for PP51.
# Processing MDG.B5...
# No cash flow data available for MDG.B5.
# Processing 688768...
# Data for 688768 added to cash_flow_data.csv.
# Processing 002945...
# Data for 002945 added to cash_flow_data.csv.
# Processing MOHCY...
# Data for MOHCY added to cash_flow_data.csv.
# Processing AHPA...
# Data for AHPA added to cash_flow_data.csv.
# Processing AJ91...
# No cash flow data available for AJ91.
# Processing 180400...
# No cash flow data available for 180400.
# Processing CVNA...
# Data for CVNA added to cash_flow_data.csv.
# Processing 1491...
# No cash flow data available for 1491.
# Processing COPH...
# Data for COPH added to cash_flow_data.csv.
# Processing SCM...
# Data for SCM added to cash_flow_data.csv.
# Processing UGDIF...
# Data for UGDIF added to cash_flow_data.csv.
# Processing 1UB...
# Data for 1UB added to cash_flow_data.csv.
# Processing MDM...
# No cash flow data available for MDM.
# Processing 4E0...
# Data for 4E0 added to cash_flow_data.csv.
# Processing FR...
# Data for FR added to cash_flow_data.csv.
# Processing PEAS...
# Data for PEAS added to cash_flow_data.csv.
# Processing 4HPQ...
# No cash flow data available for 4HPQ.
# Processing 002419...
# Data for 002419 added to cash_flow_data.csv.
# Processing 8WZ...
# Data for 8WZ added to cash_flow_data.csv.
# Processing BHP1...
# No cash flow data available for BHP1.
# Processing 0V1N...
# Data for 0V1N added to cash_flow_data.csv.
# Processing 3563...
# Data for 3563 added to cash_flow_data.csv.
# Processing 0JK4...
# Data for 0JK4 added to cash_flow_data.csv.
# Processing IWS...
# No cash flow data available for IWS.
# Processing CENTUM...
# No cash flow data available for CENTUM.
# Processing 9537...
# No cash flow data available for 9537.
# Processing H1ES34...
# Data for H1ES34 added to cash_flow_data.csv.
# Processing PRKAB...
# Data for PRKAB added to cash_flow_data.csv.
# Processing PKB...
# No cash flow data available for PKB.
# Processing HUI...
# Data for HUI added to cash_flow_data.csv.
# Processing BAIEMKOAA...
# No cash flow data available for BAIEMKOAA.
# Processing BDC...
# Data for BDC added to cash_flow_data.csv.
# Processing AKO1L...
# Data for AKO1L added to cash_flow_data.csv.
# Processing F12...
# Data for F12 added to cash_flow_data.csv.
# Processing ARRJ...
# Data for ARRJ added to cash_flow_data.csv.
# Processing XWEL...
# Data for XWEL added to cash_flow_data.csv.
# Processing SAN...
# Data for SAN added to cash_flow_data.csv.
# Processing 603288...
# Data for 603288 added to cash_flow_data.csv.
# Processing 8QJ...
# Data for 8QJ added to cash_flow_data.csv.
# Processing ALDBL...
# No cash flow data available for ALDBL.
# Processing ACCA...
# No cash flow data available for ACCA.
# Processing 44B...
# No cash flow data available for 44B.
# Processing DUR...
# Data for DUR added to cash_flow_data.csv.
# Processing TNE5...
# Data for TNE5 added to cash_flow_data.csv.
# Processing MGS...
# Data for MGS added to cash_flow_data.csv.
# Processing VINAYAKPOL...
# No cash flow data available for VINAYAKPOL.
# Processing TTNN...
# No cash flow data available for TTNN.
# Processing XS2577518488...
# No cash flow data available for XS2577518488.
# Processing 6D40...
# Data for 6D40 added to cash_flow_data.csv.
# Processing VMR1...
# No cash flow data available for VMR1.
# Processing TGPRO...
# Data for TGPRO added to cash_flow_data.csv.
# Processing RSH...
# Data for RSH added to cash_flow_data.csv.
# Processing AIG...
# Data for AIG added to cash_flow_data.csv.
# Processing SKH1...
# Failed to fetch data for SKH1. Status code: 200
# Processing ISI...
# Data for ISI added to cash_flow_data.csv.
# Processing M1CK34...
# Data for M1CK34 added to cash_flow_data.csv.
# Processing CGEMY...
# No cash flow data available for CGEMY.
# Processing IRN...
# No cash flow data available for IRN.
# Processing DK0060055861...
# No cash flow data available for DK0060055861.
# Processing DSYA...
# Data for DSYA added to cash_flow_data.csv.
# Processing ALGBE...
# No cash flow data available for ALGBE.
# Processing USB...
# Data for USB added to cash_flow_data.csv.
# Processing ADS...
# Data for ADS added to cash_flow_data.csv.
# Processing OPP.PR.B...
# No cash flow data available for OPP.PR.B.
# Processing SEE...
# Failed to fetch data for SEE. Status code: 502
# Processing PLDADEL00013...
# No cash flow data available for PLDADEL00013.
# Processing AOMFF...
# No cash flow data available for AOMFF.
# Processing BL43...
# Data for BL43 added to cash_flow_data.csv.
# Processing 0IIR...
# Data for 0IIR added to cash_flow_data.csv.
# Processing FSL...
# No cash flow data available for FSL.
# Processing SOWN...
# No cash flow data available for SOWN.
# Processing 0JRJ...
# Data for 0JRJ added to cash_flow_data.csv.
# Processing CHO1...
# Data for CHO1 added to cash_flow_data.csv.
# Processing SH9...
# Data for SH9 added to cash_flow_data.csv.
# Processing 2839...
# No cash flow data available for 2839.
# Processing KEK...
# Data for KEK added to cash_flow_data.csv.
# Processing KRYPF...
# No cash flow data available for KRYPF.
# Processing 51M...
# No cash flow data available for 51M.
# Processing FSE...
# Data for FSE added to cash_flow_data.csv.
# Processing MEOBF...
# Data for MEOBF added to cash_flow_data.csv.
# Processing DSY...
# Data for DSY added to cash_flow_data.csv.
# Processing BAZA3F...
# No cash flow data available for BAZA3F.
# Processing 301360...
# Data for 301360 added to cash_flow_data.csv.
# Processing 210...
# Data for 210 added to cash_flow_data.csv.
# Processing ELECON...
# No cash flow data available for ELECON.
# Processing IBKR...
# Data for IBKR added to cash_flow_data.csv.
# Processing 6788...
# No cash flow data available for 6788.
# Processing ATSK011PREM1...
# No cash flow data available for ATSK011PREM1.
# Processing CGEO...
# No cash flow data available for CGEO.
# Processing 3O8...
# Data for 3O8 added to cash_flow_data.csv.
# Processing BANDHANBNK...
# No cash flow data available for BANDHANBNK.
# Processing 6UP...
# No cash flow data available for 6UP.
# Processing 49Y0...
# Data for 49Y0 added to cash_flow_data.csv.
# Processing 300664...
# Data for 300664 added to cash_flow_data.csv.
# Processing 1SPOT...
# Data for 1SPOT added to cash_flow_data.csv.
# Processing LNU...
# No cash flow data available for LNU.
# Processing 6IV...
# Data for 6IV added to cash_flow_data.csv.
# Processing AROS.PR.REF.B...
# Data for AROS.PR.REF.B added to cash_flow_data.csv.
# Processing ZLDAF...
# No cash flow data available for ZLDAF.
# Processing 3374...
# No cash flow data available for 3374.
# Processing ALPHALOGIC...
# No cash flow data available for ALPHALOGIC.
# Processing IVU...
# Data for IVU added to cash_flow_data.csv.
# Processing TPS...
# No cash flow data available for TPS.
# Processing RETZ...
# Failed to fetch data for RETZ. Status code: 200
# Processing 5548...
# Data for 5548 added to cash_flow_data.csv.
# Processing 6805...
# No cash flow data available for 6805.
# Processing CRIV3F...
# No cash flow data available for CRIV3F.
# Processing 3181...
# No cash flow data available for 3181.
# Processing 5LY...
# No cash flow data available for 5LY.
# Processing 4070.SABE...
# No cash flow data available for 4070.SABE.
# Processing HROW...
# Data for HROW added to cash_flow_data.csv.
# Processing MDRX...
# Data for MDRX added to cash_flow_data.csv.
# Processing 4BY...
# No cash flow data available for 4BY.
# Processing 0VOO...
# No cash flow data available for 0VOO.
# Processing MSSAW...
# Data for MSSAW added to cash_flow_data.csv.
# Processing VCC...
# Data for VCC added to cash_flow_data.csv.
# Processing X8D...
# Data for X8D added to cash_flow_data.csv.
# Processing VSSYW...
# Data for VSSYW added to cash_flow_data.csv.
# Processing HBB...
# Data for HBB added to cash_flow_data.csv.
# Processing EGO...
# Data for EGO added to cash_flow_data.csv.
# Processing AT0000A2H102...
# No cash flow data available for AT0000A2H102.
# Processing EWWCL...
# No cash flow data available for EWWCL.
# Processing LSSB25.PR.RO...
# No cash flow data available for LSSB25.PR.RO.
# Processing P8T...
# Data for P8T added to cash_flow_data.csv.
# Processing 300903...
# Data for 300903 added to cash_flow_data.csv.
# Processing GALACTICO...
# No cash flow data available for GALACTICO.
# Processing BJ4...
# Data for BJ4 added to cash_flow_data.csv.
# Processing CORZQ...
# Data for CORZQ added to cash_flow_data.csv.
# Processing 301117...
# Data for 301117 added to cash_flow_data.csv.
# Processing AT0000A2KD30...
# No cash flow data available for AT0000A2KD30.
# Processing DNA2...
# Data for DNA2 added to cash_flow_data.csv.
# Processing 8493...
# No cash flow data available for 8493.
# Processing ETPHF...
# No cash flow data available for ETPHF.
# Processing 2ZT0...
# No cash flow data available for 2ZT0.
# Processing RIVT...
# No cash flow data available for RIVT.
# Processing TAKOF...
# Data for TAKOF added to cash_flow_data.csv.
# Processing 900904...
# Data for 900904 added to cash_flow_data.csv.
# Processing VIVANZA...
# No cash flow data available for VIVANZA.
# Processing STM...
# Data for STM added to cash_flow_data.csv.
# Processing MJ8...
# No cash flow data available for MJ8.
# Processing 1I3...
# Data for 1I3 added to cash_flow_data.csv.
# Processing 0MTS...
# Data for 0MTS added to cash_flow_data.csv.
# Processing 1DK...
# No cash flow data available for 1DK.
# Processing 32Z...
# No cash flow data available for 32Z.
# Processing F42771...
# No cash flow data available for F42771.
# Processing 058028...
# No cash flow data available for 058028.
# Processing HITE...
# No cash flow data available for HITE.
# Processing MC8...
# Data for MC8 added to cash_flow_data.csv.
# Processing MIH...
# Data for MIH added to cash_flow_data.csv.
# Processing ADEVF...
# Data for ADEVF added to cash_flow_data.csv.
# Processing AVO...
# Data for AVO added to cash_flow_data.csv.
# Processing IRC...
# Data for IRC added to cash_flow_data.csv.
# Processing BRCA...
# Data for BRCA added to cash_flow_data.csv.
# Processing HJGP...
# Data for HJGP added to cash_flow_data.csv.
# Processing TRASTOR...
# No cash flow data available for TRASTOR.
# Processing 1587...
# Data for 1587 added to cash_flow_data.csv.
# Processing 6392...
# Data for 6392 added to cash_flow_data.csv.
# Processing ENLV...
# Data for ENLV added to cash_flow_data.csv.
# Processing SIMAT...
# Data for SIMAT added to cash_flow_data.csv.
# Processing A17U...
# No cash flow data available for A17U.
# Processing 263050...
# Data for 263050 added to cash_flow_data.csv.
# Processing 3031...
# No cash flow data available for 3031.
# Processing 6591...
# Data for 6591 added to cash_flow_data.csv.
# Processing 8370...
# No cash flow data available for 8370.
# Processing UTIP...
# No cash flow data available for UTIP.
# Processing CHARAN...
# Data for CHARAN added to cash_flow_data.csv.
# Processing CZTA...
# Data for CZTA added to cash_flow_data.csv.
# Processing 709...
# Data for 709 added to cash_flow_data.csv.
# Processing SKIS.B...
# Data for SKIS.B added to cash_flow_data.csv.
# Processing SIAM.R...
# Data for SIAM.R added to cash_flow_data.csv.
# Processing 6725...
# No cash flow data available for 6725.
# Processing BUR...
# Data for BUR added to cash_flow_data.csv.
# Processing OXLCN...
# No cash flow data available for OXLCN.
# Processing CKALF...
# No cash flow data available for CKALF.
# Processing SII...
# Data for SII added to cash_flow_data.csv.
# Processing MFRVF...
# Data for MFRVF added to cash_flow_data.csv.
# Processing AABWL...
# No cash flow data available for AABWL.
# Processing DHARFIN...
# No cash flow data available for DHARFIN.
# Processing 1COST...
# Data for 1COST added to cash_flow_data.csv.
# Processing 286940...
# Data for 286940 added to cash_flow_data.csv.
# Processing P8W0...
# No cash flow data available for P8W0.
# Processing 1HOOD...
# Data for 1HOOD added to cash_flow_data.csv.
# Processing OCEL...
# Data for OCEL added to cash_flow_data.csv.
# Processing AB2...
# No cash flow data available for AB2.
# Processing G7A...
# Data for G7A added to cash_flow_data.csv.
# Processing BKE...
# Data for BKE added to cash_flow_data.csv.
# Processing 2120...
# No cash flow data available for 2120.
# Processing VICR...
# Data for VICR added to cash_flow_data.csv.
# Processing ZJS1...
# Data for ZJS1 added to cash_flow_data.csv.
# Processing M6X3...
# Data for M6X3 added to cash_flow_data.csv.
# Processing 708524...
# No cash flow data available for 708524.
# Processing JDCMF...
# Data for JDCMF added to cash_flow_data.csv.
# Processing AGYO...
# Data for AGYO added to cash_flow_data.csv.
# Processing HAIA...
# Data for HAIA added to cash_flow_data.csv.
# Processing 08D...
# Data for 08D added to cash_flow_data.csv.
# Processing 0LKC...
# Data for 0LKC added to cash_flow_data.csv.
# Processing OAR...
# No cash flow data available for OAR.
# Processing 2N8...
# Data for 2N8 added to cash_flow_data.csv.
# Processing BSSC...
# No cash flow data available for BSSC.
# Processing USY1...
# Data for USY1 added to cash_flow_data.csv.
# Processing PLTK...
# Data for PLTK added to cash_flow_data.csv.
# Processing BHSC...
# Data for BHSC added to cash_flow_data.csv.
# Processing UC2X14...
# No cash flow data available for UC2X14.
# Processing PHAL...
# Data for PHAL added to cash_flow_data.csv.
# Processing 1MS...
# Data for 1MS added to cash_flow_data.csv.
# Processing S5HE...
# No cash flow data available for S5HE.
# Processing UD7C...
# Data for UD7C added to cash_flow_data.csv.
# Processing 215570...
# No cash flow data available for 215570.
# Processing REVE11...
# No cash flow data available for REVE11.
# Processing AT0000A2QK35...
# No cash flow data available for AT0000A2QK35.
# Processing WN30...
# No cash flow data available for WN30.
# Processing EPH...
# No cash flow data available for EPH.
# Processing NVIVQ...
# Data for NVIVQ added to cash_flow_data.csv.
# Processing 6RV...
# Data for 6RV added to cash_flow_data.csv.
# Processing 710395...
# No cash flow data available for 710395.
# Processing FKKFY...
# No cash flow data available for FKKFY.
# Processing DMXCF...
# Data for DMXCF added to cash_flow_data.csv.
# Processing 0NRE...
# Data for 0NRE added to cash_flow_data.csv.
# Processing 9393...
# Data for 9393 added to cash_flow_data.csv.
# Processing 3541...
# No cash flow data available for 3541.
# Processing 3161...
# No cash flow data available for 3161.
# Processing LX83...
# No cash flow data available for LX83.
# Processing 002261...
# Data for 002261 added to cash_flow_data.csv.
# Processing 512890...
# No cash flow data available for 512890.
# Processing 517200...
# Data for 517200 added to cash_flow_data.csv.
# Processing OPC...
# Data for OPC added to cash_flow_data.csv.
# Processing ULBI...
# Data for ULBI added to cash_flow_data.csv.
# Processing 1WR...
# Data for 1WR added to cash_flow_data.csv.
# Processing 1PM...
# Data for 1PM added to cash_flow_data.csv.
# Processing UGH...
# Data for UGH added to cash_flow_data.csv.
# Processing F23300...
# No cash flow data available for F23300.
# Processing CYL...
# Data for CYL added to cash_flow_data.csv.
# Processing CEEJAY...
# No cash flow data available for CEEJAY.
# Processing TDSA...
# No cash flow data available for TDSA.
# Processing 2011...
# No cash flow data available for 2011.
# Processing JGLCF...
# No cash flow data available for JGLCF.
# Processing 6561...
# No cash flow data available for 6561.
# Processing 9509...
# No cash flow data available for 9509.
# Processing SMME...
# Data for SMME added to cash_flow_data.csv.
# Processing BCV...
# No cash flow data available for BCV.
# Processing ASEKY...
# Data for ASEKY added to cash_flow_data.csv.
# Processing DUBA...
# No cash flow data available for DUBA.
# Processing AMCI...
# Data for AMCI added to cash_flow_data.csv.
# Processing KOTAKBANK...
# No cash flow data available for KOTAKBANK.
# Processing 5PZ...
# No cash flow data available for 5PZ.
# Processing 513320...
# Data for 513320 added to cash_flow_data.csv.
# Processing LAMDA...
# Data for LAMDA added to cash_flow_data.csv.
# Processing 6457...
# No cash flow data available for 6457.
# Processing AVHIU...
# Data for AVHIU added to cash_flow_data.csv.
# Processing BBA...
# No cash flow data available for BBA.
# Processing GLCO...
# No cash flow data available for GLCO.
# Processing T4N...
# No cash flow data available for T4N.
# Processing 6661...
# Data for 6661 added to cash_flow_data.csv.
# Processing AT0000A2FJQ2...
# No cash flow data available for AT0000A2FJQ2.
# Processing FPOA...
# Failed to fetch data for FPOA. Status code: 200
# Processing 2615...
# Data for 2615 added to cash_flow_data.csv.
# Processing KDSKF...
# Data for KDSKF added to cash_flow_data.csv.
# Processing GY5...
# Data for GY5 added to cash_flow_data.csv.
# Processing HAY...
# No cash flow data available for HAY.
# Processing 8303...
# Data for 8303 added to cash_flow_data.csv.
# Processing EIA...
# Data for EIA added to cash_flow_data.csv.
# Processing SANDHAR...
# No cash flow data available for SANDHAR.
# Processing 3SZN...
# No cash flow data available for 3SZN.
# Processing 7AZ...
# Data for 7AZ added to cash_flow_data.csv.
# Processing INDOTHAI...
# No cash flow data available for INDOTHAI.
# Processing 1K0...
# Data for 1K0 added to cash_flow_data.csv.
# Processing AT0000A2SSV6...
# Data for AT0000A2SSV6 added to cash_flow_data.csv.
# Processing 250...
# Data for 250 added to cash_flow_data.csv.
# Processing 3356...
# No cash flow data available for 3356.
# Processing USG...
# No cash flow data available for USG.
# Processing ABNB...
# Data for ABNB added to cash_flow_data.csv.
# Processing BITRF...
# No cash flow data available for BITRF.
# Processing SB1...
# No cash flow data available for SB1.
# Processing GZIC...
# Data for GZIC added to cash_flow_data.csv.
# Processing ETHEREUM.XBT...
# No cash flow data available for ETHEREUM.XBT.
# Processing TWSA...
# No cash flow data available for TWSA.
# Processing SF7...
# Data for SF7 added to cash_flow_data.csv.
# Processing 603666...
# Data for 603666 added to cash_flow_data.csv.
# Processing VWEWW...
# Data for VWEWW added to cash_flow_data.csv.
# Processing 6037...
# No cash flow data available for 6037.
# Processing EPMT...
# Data for EPMT added to cash_flow_data.csv.
# Processing 7368...
# No cash flow data available for 7368.
# Processing TARMAT...
# No cash flow data available for TARMAT.
# Processing POQ...
# Data for POQ added to cash_flow_data.csv.
# Processing D2AS34...
# Data for D2AS34 added to cash_flow_data.csv.
# Processing HGPO11...
# No cash flow data available for HGPO11.
# Processing POW...
# Data for POW added to cash_flow_data.csv.
# Processing 0RUJ...
# No cash flow data available for 0RUJ.
# Processing NVAX...
# Data for NVAX added to cash_flow_data.csv.
# Processing 081580...
# Data for 081580 added to cash_flow_data.csv.
# Processing 711153...
# No cash flow data available for 711153.
# Processing WARRIX.R...
# Data for WARRIX.R added to cash_flow_data.csv.
# Processing 2172...
# No cash flow data available for 2172.
# Processing 510550...
# No cash flow data available for 510550.
# Processing 300832...
# Data for 300832 added to cash_flow_data.csv.
# Processing NS.PR.A...
# Data for NS.PR.A added to cash_flow_data.csv.
# Processing GVYM...
# Data for GVYM added to cash_flow_data.csv.
# Processing 1798...
# Data for 1798 added to cash_flow_data.csv.
# All requested data processed.

# %%
csv_file_name = 'company_profiles.csv'

# Check if the CSV file already exists to decide on writing headers or not
write_header = not os.path.exists(csv_file_name)

# Iterate over each ticker symbol
for symbol in tickers:
    print(f"Processing {symbol}...")
    url = f"https://api.twelvedata.com/profile?symbol={symbol}&apikey={api_key}"
    
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        
        # Handle cases where the API response might not be what is expected
        if isinstance(data, dict) and not data.get('code'):  # Check if the response is a dictionary and does not contain an error code
            # Convert the dictionary to a DataFrame
            df_profile = pd.DataFrame([data])
            
            # Append DataFrame to the CSV file
            df_profile.to_csv(csv_file_name, mode='a', index=False, header=write_header)
            
            # Ensure the header is not written again in subsequent writes
            write_header = False
            
            print(f"Profile data for {symbol} added to {csv_file_name}.")
        else:
            print(f"No profile data available for {symbol} or error in response.")
    else:
        print(f"Failed to fetch data for {symbol}. Status code: {response.status_code}")
    
    # Wait for 12 seconds before processing the next ticker
    time.sleep(1.5)

print("All requested profile data processed.")
# Out:
# Processing MSFT...
# Profile data for MSFT added to company_profiles.csv.
# Processing AAPL...
# Profile data for AAPL added to company_profiles.csv.
# Processing NVDA...
# Profile data for NVDA added to company_profiles.csv.
# Processing AMZN...
# Profile data for AMZN added to company_profiles.csv.
# Processing GOOGL...
# Profile data for GOOGL added to company_profiles.csv.
# Processing META...
# Profile data for META added to company_profiles.csv.
# Processing BRK.B...
# Profile data for BRK.B added to company_profiles.csv.
# Processing LLY...
# Profile data for LLY added to company_profiles.csv.
# Processing TSM...
# Profile data for TSM added to company_profiles.csv.
# Processing AVGO...
# Profile data for AVGO added to company_profiles.csv.
# Processing TSLA...
# Profile data for TSLA added to company_profiles.csv.
# Processing V...
# Profile data for V added to company_profiles.csv.
# Processing NVO...
# Profile data for NVO added to company_profiles.csv.
# Processing JPM...
# Profile data for JPM added to company_profiles.csv.
# Processing WMT...
# Profile data for WMT added to company_profiles.csv.
# Processing UNH...
# Profile data for UNH added to company_profiles.csv.
# Processing MA...
# Profile data for MA added to company_profiles.csv.
# Processing XOM...
# Profile data for XOM added to company_profiles.csv.
# Processing ASML...
# Profile data for ASML added to company_profiles.csv.
# Processing JNJ...
# Profile data for JNJ added to company_profiles.csv.
# Processing HD...
# Profile data for HD added to company_profiles.csv.
# Processing PG...
# Profile data for PG added to company_profiles.csv.
# Processing COST...
# Profile data for COST added to company_profiles.csv.
# Processing TM...
# Profile data for TM added to company_profiles.csv.
# Processing AMD...
# Profile data for AMD added to company_profiles.csv.
# Processing MRK...
# Profile data for MRK added to company_profiles.csv.
# Processing ABBV...
# Profile data for ABBV added to company_profiles.csv.
# Processing ORCL...
# Profile data for ORCL added to company_profiles.csv.
# Processing CRM...
# Profile data for CRM added to company_profiles.csv.
# Processing CVX...
# Profile data for CVX added to company_profiles.csv.
# Processing BAC...
# Profile data for BAC added to company_profiles.csv.
# Processing NFLX...
# Profile data for NFLX added to company_profiles.csv.
# Processing ADBE...
# Profile data for ADBE added to company_profiles.csv.
# Processing KO...
# Profile data for KO added to company_profiles.csv.
# Processing ACN...
# Profile data for ACN added to company_profiles.csv.
# Processing PEP...
# Profile data for PEP added to company_profiles.csv.
# Processing FMX...
# Profile data for FMX added to company_profiles.csv.
# Processing SAP...
# Profile data for SAP added to company_profiles.csv.
# Processing TMO...
# Profile data for TMO added to company_profiles.csv.
# Processing LIN...
# Profile data for LIN added to company_profiles.csv.
# Processing MCD...
# Profile data for MCD added to company_profiles.csv.
# Processing NVS...
# Profile data for NVS added to company_profiles.csv.
# Processing ABT...
# Profile data for ABT added to company_profiles.csv.
# Processing DIS...
# Profile data for DIS added to company_profiles.csv.
# Processing SHEL...
# Profile data for SHEL added to company_profiles.csv.
# Processing AZN...
# Profile data for AZN added to company_profiles.csv.
# Processing WFC...
# Profile data for WFC added to company_profiles.csv.
# Processing CSCO...
# Profile data for CSCO added to company_profiles.csv.
# Processing TMUS...
# Profile data for TMUS added to company_profiles.csv.
# Processing DHR...
# Profile data for DHR added to company_profiles.csv.
# Processing BABA...
# Profile data for BABA added to company_profiles.csv.
# Processing INTU...
# Profile data for INTU added to company_profiles.csv.
# Processing INTC...
# Profile data for INTC added to company_profiles.csv.
# Processing QCOM...
# Profile data for QCOM added to company_profiles.csv.
# Processing AMAT...
# Profile data for AMAT added to company_profiles.csv.
# Processing GE...
# Profile data for GE added to company_profiles.csv.
# Processing IBM...
# Profile data for IBM added to company_profiles.csv.
# Processing CMCSA...
# Profile data for CMCSA added to company_profiles.csv.
# Processing VZ...
# Profile data for VZ added to company_profiles.csv.
# Processing PDD...
# Profile data for PDD added to company_profiles.csv.
# Processing UBER...
# Profile data for UBER added to company_profiles.csv.
# Processing CAT...
# Profile data for CAT added to company_profiles.csv.
# Processing AXP...
# Profile data for AXP added to company_profiles.csv.
# Processing NOW...
# Profile data for NOW added to company_profiles.csv.
# Processing TXN...
# Profile data for TXN added to company_profiles.csv.
# Processing BX...
# Profile data for BX added to company_profiles.csv.
# Processing NKE...
# Profile data for NKE added to company_profiles.csv.
# Processing UNP...
# Profile data for UNP added to company_profiles.csv.
# Processing TTE...
# Profile data for TTE added to company_profiles.csv.
# Processing AMGN...
# Profile data for AMGN added to company_profiles.csv.
# Processing PFE...
# Profile data for PFE added to company_profiles.csv.
# Processing HSBC...
# Profile data for HSBC added to company_profiles.csv.
# Processing BHP...
# Profile data for BHP added to company_profiles.csv.
# Processing MS...
# Profile data for MS added to company_profiles.csv.
# Processing LOW...
# Profile data for LOW added to company_profiles.csv.
# Processing ISRG...
# Profile data for ISRG added to company_profiles.csv.
# Processing PM...
# Profile data for PM added to company_profiles.csv.
# Processing HDB...
# Profile data for HDB added to company_profiles.csv.
# Processing RY...
# Profile data for RY added to company_profiles.csv.
# Processing SPGI...
# Profile data for SPGI added to company_profiles.csv.
# Processing COP...
# Profile data for COP added to company_profiles.csv.
# Processing SYK...
# Profile data for SYK added to company_profiles.csv.
# Processing HON...
# Profile data for HON added to company_profiles.csv.
# Processing LRCX...
# Profile data for LRCX added to company_profiles.csv.
# Processing GS...
# Profile data for GS added to company_profiles.csv.
# Processing UPS...
# Profile data for UPS added to company_profiles.csv.
# Processing PLD...
# Profile data for PLD added to company_profiles.csv.
# Processing MUFG...
# Profile data for MUFG added to company_profiles.csv.
# Processing UL...
# Profile data for UL added to company_profiles.csv.
# Processing BA...
# Profile data for BA added to company_profiles.csv.
# Processing T...
# Profile data for T added to company_profiles.csv.
# Processing BLK...
# Profile data for BLK added to company_profiles.csv.
# Processing SCHW...
# Profile data for SCHW added to company_profiles.csv.
# Processing BUD...
# Profile data for BUD added to company_profiles.csv.
# Processing BKNG...
# Profile data for BKNG added to company_profiles.csv.
# Processing RTX...
# Profile data for RTX added to company_profiles.csv.
# Processing SNY...
# Profile data for SNY added to company_profiles.csv.
# Processing ETN...
# Profile data for ETN added to company_profiles.csv.
# Processing ELV...
# Profile data for ELV added to company_profiles.csv.
# Processing NEE...
# Profile data for NEE added to company_profiles.csv.
# Processing TJX...
# Profile data for TJX added to company_profiles.csv.
# Processing VRTX...
# Profile data for VRTX added to company_profiles.csv.
# Processing MDT...
# Profile data for MDT added to company_profiles.csv.
# Processing PGR...
# Profile data for PGR added to company_profiles.csv.
# Processing SONY...
# Profile data for SONY added to company_profiles.csv.
# Processing FMC...
# Profile data for FMC added to company_profiles.csv.
# Processing CIVI...
# Profile data for CIVI added to company_profiles.csv.
# Processing UI...
# Profile data for UI added to company_profiles.csv.
# Processing AZEK...
# Profile data for AZEK added to company_profiles.csv.
# Processing YMM...
# Profile data for YMM added to company_profiles.csv.
# Processing RHP...
# Profile data for RHP added to company_profiles.csv.
# Processing BZ...
# Profile data for BZ added to company_profiles.csv.
# Processing TKO...
# Profile data for TKO added to company_profiles.csv.
# Processing NYT...
# Profile data for NYT added to company_profiles.csv.
# Processing GPS...
# Profile data for GPS added to company_profiles.csv.
# Processing ALTR...
# Profile data for ALTR added to company_profiles.csv.
# Processing NFE...
# Profile data for NFE added to company_profiles.csv.
# Processing XRAY...
# Profile data for XRAY added to company_profiles.csv.
# Processing CCCS...
# Profile data for CCCS added to company_profiles.csv.
# Processing SPSC...
# Profile data for SPSC added to company_profiles.csv.
# Processing STAG...
# Profile data for STAG added to company_profiles.csv.
# Processing IVZ...
# Profile data for IVZ added to company_profiles.csv.
# Processing HAS...
# Profile data for HAS added to company_profiles.csv.
# Processing DAR...
# Profile data for DAR added to company_profiles.csv.
# Processing RMBS...
# Profile data for RMBS added to company_profiles.csv.
# Processing HQY...
# Profile data for HQY added to company_profiles.csv.
# Processing RGLD...
# Profile data for RGLD added to company_profiles.csv.
# Processing ICL...
# Profile data for ICL added to company_profiles.csv.
# Processing BILL...
# Profile data for BILL added to company_profiles.csv.
# Processing VOYA...
# Profile data for VOYA added to company_profiles.csv.
# Processing CFR...
# Profile data for CFR added to company_profiles.csv.
# Processing ITCI...
# Profile data for ITCI added to company_profiles.csv.
# Processing ENSG...
# Profile data for ENSG added to company_profiles.csv.
# Processing MAT...
# Profile data for MAT added to company_profiles.csv.
# Processing FOUR...
# Profile data for FOUR added to company_profiles.csv.
# Processing GNRC...
# Profile data for GNRC added to company_profiles.csv.
# Processing THO...
# Profile data for THO added to company_profiles.csv.
# Processing BRX...
# Profile data for BRX added to company_profiles.csv.
# Processing IBP...
# Profile data for IBP added to company_profiles.csv.
# Processing WTS...
# Profile data for WTS added to company_profiles.csv.
# Processing CGNX...
# Profile data for CGNX added to company_profiles.csv.
# Processing CHRD...
# Profile data for CHRD added to company_profiles.csv.
# Processing CACC...
# Profile data for CACC added to company_profiles.csv.
# Processing AAON...
# Profile data for AAON added to company_profiles.csv.
# Processing BERY...
# Profile data for BERY added to company_profiles.csv.
# Processing MMYT...
# Profile data for MMYT added to company_profiles.csv.
# Processing LBTYK...
# Profile data for LBTYK added to company_profiles.csv.
# Processing ALSN...
# Profile data for ALSN added to company_profiles.csv.
# Processing CBSH...
# Profile data for CBSH added to company_profiles.csv.
# Processing EXEL...
# Profile data for EXEL added to company_profiles.csv.
# Processing NOV...
# Profile data for NOV added to company_profiles.csv.
# Processing ADT...
# Profile data for ADT added to company_profiles.csv.
# Processing BFAM...
# Profile data for BFAM added to company_profiles.csv.
# Processing CRSP...
# Profile data for CRSP added to company_profiles.csv.
# Processing HRB...
# Profile data for HRB added to company_profiles.csv.
# Processing MTZ...
# Profile data for MTZ added to company_profiles.csv.
# Processing MASI...
# Profile data for MASI added to company_profiles.csv.
# Processing MTSI...
# Profile data for MTSI added to company_profiles.csv.
# Processing RLI...
# Profile data for RLI added to company_profiles.csv.
# Processing DDS...
# Profile data for DDS added to company_profiles.csv.
# Processing LSTR...
# Profile data for LSTR added to company_profiles.csv.
# Processing AGNC...
# Profile data for AGNC added to company_profiles.csv.
# Processing WFG...
# Profile data for WFG added to company_profiles.csv.
# Processing STWD...
# Profile data for STWD added to company_profiles.csv.
# Processing VNT...
# Profile data for VNT added to company_profiles.csv.
# Processing IONS...
# Profile data for IONS added to company_profiles.csv.
# Processing CAVA...
# Profile data for CAVA added to company_profiles.csv.
# Processing ANF...
# Profile data for ANF added to company_profiles.csv.
# Processing OGE...
# Profile data for OGE added to company_profiles.csv.
# Processing OLN...
# Profile data for OLN added to company_profiles.csv.
# Processing CMA...
# Profile data for CMA added to company_profiles.csv.
# Processing LYFT...
# Profile data for LYFT added to company_profiles.csv.
# Processing UGP...
# Profile data for UGP added to company_profiles.csv.
# Processing AM...
# Profile data for AM added to company_profiles.csv.
# Processing VNOM...
# Profile data for VNOM added to company_profiles.csv.
# Processing CART...
# Profile data for CART added to company_profiles.csv.
# Processing ARW...
# Profile data for ARW added to company_profiles.csv.
# Processing TNET...
# Profile data for TNET added to company_profiles.csv.
# Processing CR...
# Profile data for CR added to company_profiles.csv.
# Processing SFM...
# Profile data for SFM added to company_profiles.csv.
# Processing CSAN...
# Profile data for CSAN added to company_profiles.csv.
# Processing KVYO...
# Profile data for KVYO added to company_profiles.csv.
# Processing ATKR...
# Profile data for ATKR added to company_profiles.csv.
# Processing AN...
# Profile data for AN added to company_profiles.csv.
# Processing POST...
# Profile data for POST added to company_profiles.csv.
# Processing HXL...
# Profile data for HXL added to company_profiles.csv.
# Processing VFC...
# Profile data for VFC added to company_profiles.csv.
# Processing SIGI...
# Profile data for SIGI added to company_profiles.csv.
# Processing ATI...
# Profile data for ATI added to company_profiles.csv.
# Processing BROS...
# Profile data for BROS added to company_profiles.csv.
# Processing NOVT...
# Profile data for NOVT added to company_profiles.csv.
# Processing ALGM...
# Profile data for ALGM added to company_profiles.csv.
# Processing GTLS...
# Profile data for GTLS added to company_profiles.csv.
# Processing BBIO...
# Profile data for BBIO added to company_profiles.csv.
# Processing HLNE...
# Profile data for HLNE added to company_profiles.csv.
# Processing SSB...
# Profile data for SSB added to company_profiles.csv.
# Processing FLR...
# Profile data for FLR added to company_profiles.csv.
# Processing CMC...
# Profile data for CMC added to company_profiles.csv.
# Processing KGC...
# Profile data for KGC added to company_profiles.csv.
# Processing BYD...
# Profile data for BYD added to company_profiles.csv.
# Processing PNFP...
# Profile data for PNFP added to company_profiles.csv.
# Processing WAL...
# Profile data for WAL added to company_profiles.csv.
# Processing QLYS...
# Profile data for QLYS added to company_profiles.csv.
# Processing NE...
# Profile data for NE added to company_profiles.csv.
# Processing MUR...
# Profile data for MUR added to company_profiles.csv.
# Processing NEU...
# Profile data for NEU added to company_profiles.csv.
# Processing REYN...
# Profile data for REYN added to company_profiles.csv.
# Processing WH...
# Profile data for WH added to company_profiles.csv.
# Processing NSIT...
# Profile data for NSIT added to company_profiles.csv.
# Processing TMHC...
# Profile data for TMHC added to company_profiles.csv.
# Processing CHX...
# Profile data for CHX added to company_profiles.csv.
# Processing G...
# Profile data for G added to company_profiles.csv.
# Processing GXO...
# Profile data for GXO added to company_profiles.csv.
# Processing FAF...
# Profile data for FAF added to company_profiles.csv.
# Processing ELP...
# Profile data for ELP added to company_profiles.csv.
# Processing FRSH...
# Profile data for FRSH added to company_profiles.csv.
# Processing CAE...
# Profile data for CAE added to company_profiles.csv.
# Processing MARA...
# Profile data for MARA added to company_profiles.csv.
# Processing DRS...
# Profile data for DRS added to company_profiles.csv.
# Processing BC...
# Profile data for BC added to company_profiles.csv.
# Processing ESAB...
# Profile data for ESAB added to company_profiles.csv.
# Processing MNSO...
# Profile data for MNSO added to company_profiles.csv.
# Processing BPOP...
# Profile data for BPOP added to company_profiles.csv.
# Processing LFUS...
# Profile data for LFUS added to company_profiles.csv.
# Processing WTFC...
# Profile data for WTFC added to company_profiles.csv.
# Processing ALTM...
# Profile data for ALTM added to company_profiles.csv.
# Processing TKR...
# Profile data for TKR added to company_profiles.csv.
# Processing RRR...
# Profile data for RRR added to company_profiles.csv.
# Processing GRFS...
# Profile data for GRFS added to company_profiles.csv.
# Processing OBDC...
# Profile data for OBDC added to company_profiles.csv.
# Processing CIGI...
# Profile data for CIGI added to company_profiles.csv.
# Processing RCM...
# Profile data for RCM added to company_profiles.csv.
# Processing SMAR...
# Profile data for SMAR added to company_profiles.csv.
# Processing FYBR...
# Profile data for FYBR added to company_profiles.csv.
# Processing MLI...
# Profile data for MLI added to company_profiles.csv.
# Processing GIL...
# Profile data for GIL added to company_profiles.csv.
# Processing WHR...
# Profile data for WHR added to company_profiles.csv.
# Processing FTAI...
# Profile data for FTAI added to company_profiles.csv.
# Processing OMF...
# Profile data for OMF added to company_profiles.csv.
# Processing PBF...
# Profile data for PBF added to company_profiles.csv.
# Processing BPMC...
# Profile data for BPMC added to company_profiles.csv.
# Processing PB...
# Profile data for PB added to company_profiles.csv.
# Processing BLCO...
# Profile data for BLCO added to company_profiles.csv.
# Processing MTH...
# Profile data for MTH added to company_profiles.csv.
# Processing CIG...
# Profile data for CIG added to company_profiles.csv.
# Processing ENLC...
# Profile data for ENLC added to company_profiles.csv.
# Processing ZION...
# Profile data for ZION added to company_profiles.csv.
# Processing TRNO...
# Profile data for TRNO added to company_profiles.csv.
# Processing ESNT...
# Profile data for ESNT added to company_profiles.csv.
# Processing ESI...
# Profile data for ESI added to company_profiles.csv.
# Processing ADC...
# Profile data for ADC added to company_profiles.csv.
# Processing BRZE...
# Profile data for BRZE added to company_profiles.csv.
# Processing LANC...
# Profile data for LANC added to company_profiles.csv.
# Processing TENB...
# Profile data for TENB added to company_profiles.csv.
# Processing MSM...
# Profile data for MSM added to company_profiles.csv.
# Processing MXCT...
# Profile data for MXCT added to company_profiles.csv.
# Processing BALY...
# Profile data for BALY added to company_profiles.csv.
# Processing SRI...
# Profile data for SRI added to company_profiles.csv.
# Processing IVVD...
# Profile data for IVVD added to company_profiles.csv.
# Processing BWMN...
# Profile data for BWMN added to company_profiles.csv.
# Processing EQBK...
# Profile data for EQBK added to company_profiles.csv.
# Processing SD...
# Profile data for SD added to company_profiles.csv.
# Processing DJCO...
# Profile data for DJCO added to company_profiles.csv.
# Processing ATLC...
# Profile data for ATLC added to company_profiles.csv.
# Processing LSEA...
# Profile data for LSEA added to company_profiles.csv.
# Processing DENN...
# Profile data for DENN added to company_profiles.csv.
# Processing SMBC...
# Profile data for SMBC added to company_profiles.csv.
# Processing GUTS...
# Profile data for GUTS added to company_profiles.csv.
# Processing ASLE...
# Profile data for ASLE added to company_profiles.csv.
# Processing CCBG...
# Profile data for CCBG added to company_profiles.csv.
# Processing VPG...
# Profile data for VPG added to company_profiles.csv.
# Processing LWLG...
# Profile data for LWLG added to company_profiles.csv.
# Processing OFIX...
# Profile data for OFIX added to company_profiles.csv.
# Processing AEON...
# Profile data for AEON added to company_profiles.csv.
# Processing LIND...
# Profile data for LIND added to company_profiles.csv.
# Processing LND...
# Profile data for LND added to company_profiles.csv.
# Processing MTW...
# Profile data for MTW added to company_profiles.csv.
# Processing CTLP...
# Profile data for CTLP added to company_profiles.csv.
# Processing RSVR...
# Profile data for RSVR added to company_profiles.csv.
# Processing ABUS...
# Profile data for ABUS added to company_profiles.csv.
# Processing AMNB...
# Profile data for AMNB added to company_profiles.csv.
# Processing NN...
# Profile data for NN added to company_profiles.csv.
# Processing LAND...
# Profile data for LAND added to company_profiles.csv.
# Processing FPH...
# Profile data for FPH added to company_profiles.csv.
# Processing HCAT...
# Profile data for HCAT added to company_profiles.csv.
# Processing ESPR...
# Profile data for ESPR added to company_profiles.csv.
# Processing JOUT...
# Profile data for JOUT added to company_profiles.csv.
# Processing ALNT...
# Profile data for ALNT added to company_profiles.csv.
# Processing RXT...
# Profile data for RXT added to company_profiles.csv.
# Processing CATX...
# Profile data for CATX added to company_profiles.csv.
# Processing GCBC...
# Profile data for GCBC added to company_profiles.csv.
# Processing ANNX...
# Profile data for ANNX added to company_profiles.csv.
# Processing RGP...
# Profile data for RGP added to company_profiles.csv.
# Processing EGY...
# Profile data for EGY added to company_profiles.csv.
# Processing TPB...
# Profile data for TPB added to company_profiles.csv.
# Processing ZH...
# Profile data for ZH added to company_profiles.csv.
# Processing VTRU...
# Profile data for VTRU added to company_profiles.csv.
# Processing DGICA...
# Profile data for DGICA added to company_profiles.csv.
# Processing CWCO...
# Profile data for CWCO added to company_profiles.csv.
# Processing RCEL...
# Profile data for RCEL added to company_profiles.csv.
# Processing CLFD...
# Profile data for CLFD added to company_profiles.csv.
# Processing DGICB...
# Profile data for DGICB added to company_profiles.csv.
# Processing AXGN...
# Profile data for AXGN added to company_profiles.csv.
# Processing ZIMV...
# Profile data for ZIMV added to company_profiles.csv.
# Processing ALCC...
# Profile data for ALCC added to company_profiles.csv.
# Processing TRDA...
# Profile data for TRDA added to company_profiles.csv.
# Processing ADTN...
# Profile data for ADTN added to company_profiles.csv.
# Processing HONE...
# Profile data for HONE added to company_profiles.csv.
# Processing CAC...
# Profile data for CAC added to company_profiles.csv.
# Processing SRDX...
# Profile data for SRDX added to company_profiles.csv.
# Processing AVAH...
# Profile data for AVAH added to company_profiles.csv.
# Processing HAFC...
# Profile data for HAFC added to company_profiles.csv.
# Processing AURA...
# Profile data for AURA added to company_profiles.csv.
# Processing STTK...
# Profile data for STTK added to company_profiles.csv.
# Processing MCS...
# Profile data for MCS added to company_profiles.csv.
# Processing TBPH...
# Profile data for TBPH added to company_profiles.csv.
# Processing TGB...
# Profile data for TGB added to company_profiles.csv.
# Processing KODK...
# Profile data for KODK added to company_profiles.csv.
# Processing TERN...
# Profile data for TERN added to company_profiles.csv.
# Processing HTBI...
# Profile data for HTBI added to company_profiles.csv.
# Processing MGX...
# Profile data for MGX added to company_profiles.csv.
# Processing NTGR...
# Profile data for NTGR added to company_profiles.csv.
# Processing NFBK...
# Profile data for NFBK added to company_profiles.csv.
# Processing TRC...
# Profile data for TRC added to company_profiles.csv.
# Processing BETR...
# Profile data for BETR added to company_profiles.csv.
# Processing ORC...
# Profile data for ORC added to company_profiles.csv.
# Processing GDEV...
# Profile data for GDEV added to company_profiles.csv.
# Processing URG...
# Profile data for URG added to company_profiles.csv.
# Processing RDZN...
# Profile data for RDZN added to company_profiles.csv.
# Processing WTI...
# Profile data for WTI added to company_profiles.csv.
# Processing PNNT...
# Profile data for PNNT added to company_profiles.csv.
# Processing GHRS...
# Profile data for GHRS added to company_profiles.csv.
# Processing GATO...
# Profile data for GATO added to company_profiles.csv.
# Processing EHAB...
# Profile data for EHAB added to company_profiles.csv.
# Processing GLAD...
# Profile data for GLAD added to company_profiles.csv.
# Processing TSAT...
# Profile data for TSAT added to company_profiles.csv.
# Processing MED...
# Profile data for MED added to company_profiles.csv.
# Processing BBCP...
# Profile data for BBCP added to company_profiles.csv.
# Processing BLZE...
# Profile data for BLZE added to company_profiles.csv.
# Processing CELC...
# Profile data for CELC added to company_profiles.csv.
# Processing XERS...
# Profile data for XERS added to company_profiles.csv.
# Processing SVM...
# Profile data for SVM added to company_profiles.csv.
# Processing MVIS...
# Profile data for MVIS added to company_profiles.csv.
# Processing WASH...
# Profile data for WASH added to company_profiles.csv.
# Processing GLRE...
# Profile data for GLRE added to company_profiles.csv.
# Processing IVR...
# Profile data for IVR added to company_profiles.csv.
# Processing AVNW...
# Profile data for AVNW added to company_profiles.csv.
# Processing ANSC...
# Profile data for ANSC added to company_profiles.csv.
# Processing OCS...
# Profile data for OCS added to company_profiles.csv.
# Processing OSG...
# Profile data for OSG added to company_profiles.csv.
# Processing DHIL...
# Profile data for DHIL added to company_profiles.csv.
# Processing EAF...
# Profile data for EAF added to company_profiles.csv.
# Processing THFF...
# Profile data for THFF added to company_profiles.csv.
# Processing CVRX...
# Profile data for CVRX added to company_profiles.csv.
# Processing SLAM...
# Profile data for SLAM added to company_profiles.csv.
# Processing AVXL...
# Profile data for AVXL added to company_profiles.csv.
# Processing AMRN...
# Profile data for AMRN added to company_profiles.csv.
# Processing CRMT...
# Profile data for CRMT added to company_profiles.csv.
# Processing FFWM...
# Profile data for FFWM added to company_profiles.csv.
# Processing DCGO...
# Profile data for DCGO added to company_profiles.csv.
# Processing OLP...
# Profile data for OLP added to company_profiles.csv.
# Processing AUDC...
# Profile data for AUDC added to company_profiles.csv.
# Processing ALRS...
# Profile data for ALRS added to company_profiles.csv.
# Processing BTMD...
# Profile data for BTMD added to company_profiles.csv.
# Processing GDOT...
# Profile data for GDOT added to company_profiles.csv.
# Processing NYXH...
# Profile data for NYXH added to company_profiles.csv.
# Processing SPFI...
# Profile data for SPFI added to company_profiles.csv.
# Processing FBLG...
# Profile data for FBLG added to company_profiles.csv.
# Processing ACRE...
# Profile data for ACRE added to company_profiles.csv.
# Processing PGC...
# Profile data for PGC added to company_profiles.csv.
# Processing CLOV...
# Profile data for CLOV added to company_profiles.csv.
# Processing CCG...
# Profile data for CCG added to company_profiles.csv.
# Processing DOMO...
# Profile data for DOMO added to company_profiles.csv.
# Processing MCB...
# Profile data for MCB added to company_profiles.csv.
# Processing PGEN...
# Profile data for PGEN added to company_profiles.csv.
# Processing NPCE...
# Profile data for NPCE added to company_profiles.csv.
# Processing ONEW...
# Profile data for ONEW added to company_profiles.csv.
# Processing NVEC...
# Profile data for NVEC added to company_profiles.csv.
# Processing EPIX...
# Profile data for EPIX added to company_profiles.csv.
# Processing LYTS...
# Profile data for LYTS added to company_profiles.csv.
# Processing FARO...
# Profile data for FARO added to company_profiles.csv.
# Processing TMC...
# Profile data for TMC added to company_profiles.csv.
# Processing GFR...
# Profile data for GFR added to company_profiles.csv.
# Processing ESQ...
# Profile data for ESQ added to company_profiles.csv.
# Processing THRD...
# Profile data for THRD added to company_profiles.csv.
# Processing CCNE...
# Profile data for CCNE added to company_profiles.csv.
# Processing PBPB...
# Profile data for PBPB added to company_profiles.csv.
# Processing NBN...
# Profile data for NBN added to company_profiles.csv.
# Processing STRW...
# Profile data for STRW added to company_profiles.csv.
# Processing FSBC...
# Profile data for FSBC added to company_profiles.csv.
# Processing BHRB...
# Profile data for BHRB added to company_profiles.csv.
# Processing LXEO...
# Profile data for LXEO added to company_profiles.csv.
# Processing IAUX...
# Profile data for IAUX added to company_profiles.csv.
# Processing LAW...
# Profile data for LAW added to company_profiles.csv.
# Processing MGTX...
# Profile data for MGTX added to company_profiles.csv.
# Processing RMR...
# Profile data for RMR added to company_profiles.csv.
# Processing NGNE...
# Profile data for NGNE added to company_profiles.csv.
# Processing AROW...
# Profile data for AROW added to company_profiles.csv.
# Processing GBLI...
# Profile data for GBLI added to company_profiles.csv.
# Processing ACTG...
# Profile data for ACTG added to company_profiles.csv.
# Processing INZY...
# Profile data for INZY added to company_profiles.csv.
# Processing ITOS...
# Profile data for ITOS added to company_profiles.csv.
# Processing STEM...
# Profile data for STEM added to company_profiles.csv.
# Processing ARMN...
# Profile data for ARMN added to company_profiles.csv.
# Processing MODV...
# Profile data for MODV added to company_profiles.csv.
# Processing NCMI...
# Profile data for NCMI added to company_profiles.csv.
# Processing ANRO...
# Profile data for ANRO added to company_profiles.csv.
# Processing NETD...
# Profile data for NETD added to company_profiles.csv.
# Processing VALU...
# Profile data for VALU added to company_profiles.csv.
# Processing HRZN...
# Profile data for HRZN added to company_profiles.csv.
# Processing OPY...
# Profile data for OPY added to company_profiles.csv.
# Processing VNET...
# Profile data for VNET added to company_profiles.csv.
# Processing SGU...
# Profile data for SGU added to company_profiles.csv.
# Processing ZYXI...
# Profile data for ZYXI added to company_profiles.csv.
# Processing OSPN...
# Profile data for OSPN added to company_profiles.csv.
# Processing 33L...
# Profile data for 33L added to company_profiles.csv.
# Processing B2W...
# Profile data for B2W added to company_profiles.csv.
# Processing MMSMY...
# Profile data for MMSMY added to company_profiles.csv.
# Processing GYUAF...
# Profile data for GYUAF added to company_profiles.csv.
# Processing 300011...
# Profile data for 300011 added to company_profiles.csv.
# Processing LVS...
# Profile data for LVS added to company_profiles.csv.
# Processing 7225...
# Profile data for 7225 added to company_profiles.csv.
# Processing ISU...
# Profile data for ISU added to company_profiles.csv.
# Processing NUTEX...
# Profile data for NUTEX added to company_profiles.csv.
# Processing 9686...
# Profile data for 9686 added to company_profiles.csv.
# Processing AT0000A370Z6...
# Profile data for AT0000A370Z6 added to company_profiles.csv.
# Processing LMMFF...
# Profile data for LMMFF added to company_profiles.csv.
# Processing APEOF...
# Profile data for APEOF added to company_profiles.csv.
# Processing CZO...
# Profile data for CZO added to company_profiles.csv.
# Processing 267250...
# Profile data for 267250 added to company_profiles.csv.
# Processing TEND...
# Profile data for TEND added to company_profiles.csv.
# Processing 0MM3...
# Profile data for 0MM3 added to company_profiles.csv.
# Processing EGS21451C017...
# Profile data for EGS21451C017 added to company_profiles.csv.
# Processing B2LN34...
# Profile data for B2LN34 added to company_profiles.csv.
# Processing TINPLATE...
# Profile data for TINPLATE added to company_profiles.csv.
# Processing EDDYF...
# Profile data for EDDYF added to company_profiles.csv.
# Processing 200541...
# Profile data for 200541 added to company_profiles.csv.
# Processing IBULHSGFIN.AJ...
# Profile data for IBULHSGFIN.AJ added to company_profiles.csv.
# Processing OSL...
# Profile data for OSL added to company_profiles.csv.
# Processing 3661...
# Profile data for 3661 added to company_profiles.csv.
# Processing 6UA...
# Profile data for 6UA added to company_profiles.csv.
# Processing PX0...
# Profile data for PX0 added to company_profiles.csv.
# Processing 065484...
# Profile data for 065484 added to company_profiles.csv.
# Processing HY5A...
# Profile data for HY5A added to company_profiles.csv.
# Processing HVY...
# Profile data for HVY added to company_profiles.csv.
# Processing CVS0...
# Profile data for CVS0 added to company_profiles.csv.
# Processing GVLMY...
# Profile data for GVLMY added to company_profiles.csv.
# Processing UNTY...
# Profile data for UNTY added to company_profiles.csv.
# Processing BLEVF...
# Profile data for BLEVF added to company_profiles.csv.
# Processing REXR.PR.B...
# Profile data for REXR.PR.B added to company_profiles.csv.
# Processing 076702...
# Profile data for 076702 added to company_profiles.csv.
# Processing PNP...
# Profile data for PNP added to company_profiles.csv.
# Processing WF6...
# Profile data for WF6 added to company_profiles.csv.
# Processing 001308...
# Profile data for 001308 added to company_profiles.csv.
# Processing AKGRT...
# Profile data for AKGRT added to company_profiles.csv.
# Processing CPER...
# Profile data for CPER added to company_profiles.csv.
# Processing 0N7X...
# Profile data for 0N7X added to company_profiles.csv.
# Processing SOUHY...
# Profile data for SOUHY added to company_profiles.csv.
# Processing TMV...
# Profile data for TMV added to company_profiles.csv.
# Processing CS6...
# Profile data for CS6 added to company_profiles.csv.
# Processing 076262...
# Profile data for 076262 added to company_profiles.csv.
# Processing AT0000A2NXY1...
# Profile data for AT0000A2NXY1 added to company_profiles.csv.
# Processing 002505...
# Profile data for 002505 added to company_profiles.csv.
# Processing VSACU...
# Profile data for VSACU added to company_profiles.csv.
# Processing MYIDF...
# Profile data for MYIDF added to company_profiles.csv.
# Processing 0JJM...
# Profile data for 0JJM added to company_profiles.csv.
# Processing CNHI...
# Profile data for CNHI added to company_profiles.csv.
# Processing R5XA...
# Profile data for R5XA added to company_profiles.csv.
# Processing TWP.R...
# Profile data for TWP.R added to company_profiles.csv.
# Processing KIND.SDB...
# Profile data for KIND.SDB added to company_profiles.csv.
# Processing GCY...
# Profile data for GCY added to company_profiles.csv.
# Processing BULL.SILVER.X4.AVA...
# Profile data for BULL.SILVER.X4.AVA added to company_profiles.csv.
# Processing C0229A...
# Profile data for C0229A added to company_profiles.csv.
# Processing OETO...
# Profile data for OETO added to company_profiles.csv.
# Processing STEELCAS...
# Profile data for STEELCAS added to company_profiles.csv.
# Processing D9F2...
# Profile data for D9F2 added to company_profiles.csv.
# Processing BBMD...
# Profile data for BBMD added to company_profiles.csv.
# Processing CITY...
# Profile data for CITY added to company_profiles.csv.
# Processing NZ2...
# Profile data for NZ2 added to company_profiles.csv.
# Processing AT0000A2WSQ8...
# Profile data for AT0000A2WSQ8 added to company_profiles.csv.
# Processing 011150...
# Profile data for 011150 added to company_profiles.csv.
# Processing 0583...
# Profile data for 0583 added to company_profiles.csv.
# Processing IUE...
# Failed to fetch data for IUE. Status code: 502
# Processing 9803...
# Failed to fetch data for 9803. Status code: 502
# Processing NERG...
# Profile data for NERG added to company_profiles.csv.
# Processing CY9D...
# Profile data for CY9D added to company_profiles.csv.
# Processing 83A...
# Profile data for 83A added to company_profiles.csv.
# Processing MMM...
# Profile data for MMM added to company_profiles.csv.
# Processing 131030...
# Profile data for 131030 added to company_profiles.csv.
# Processing ISEC...
# Profile data for ISEC added to company_profiles.csv.
# Processing VE...
# Profile data for VE added to company_profiles.csv.
# Processing LB4A...
# Profile data for LB4A added to company_profiles.csv.
# Processing 49MW...
# Profile data for 49MW added to company_profiles.csv.
# Processing FOODSIN...
# Profile data for FOODSIN added to company_profiles.csv.
# Processing PW2...
# Profile data for PW2 added to company_profiles.csv.
# Processing FPOR11...
# Profile data for FPOR11 added to company_profiles.csv.
# Processing 068790...
# Profile data for 068790 added to company_profiles.csv.
# Processing IDVA...
# Profile data for IDVA added to company_profiles.csv.
# Processing T2V1...
# Profile data for T2V1 added to company_profiles.csv.
# Processing UREKA...
# Profile data for UREKA added to company_profiles.csv.
# Processing 1CO1...
# Profile data for 1CO1 added to company_profiles.csv.
# Processing LU2290522684...
# Profile data for LU2290522684 added to company_profiles.csv.
# Processing MSKY...
# Profile data for MSKY added to company_profiles.csv.
# Processing WDIT24...
# Profile data for WDIT24 added to company_profiles.csv.
# Processing 600999...
# Profile data for 600999 added to company_profiles.csv.
# Processing DEFI...
# Profile data for DEFI added to company_profiles.csv.
# Processing BJ8...
# Profile data for BJ8 added to company_profiles.csv.
# Processing 6BF...
# Profile data for 6BF added to company_profiles.csv.
# Processing J0Z...
# Profile data for J0Z added to company_profiles.csv.
# Processing 0UG9...
# Profile data for 0UG9 added to company_profiles.csv.
# Processing MMC...
# Profile data for MMC added to company_profiles.csv.
# Processing P7V...
# Profile data for P7V added to company_profiles.csv.
# Processing 052134...
# Profile data for 052134 added to company_profiles.csv.
# Processing SPU...
# Profile data for SPU added to company_profiles.csv.
# Processing 30Z...
# Profile data for 30Z added to company_profiles.csv.
# Processing JX90...
# Profile data for JX90 added to company_profiles.csv.
# Processing ZNHH...
# Profile data for ZNHH added to company_profiles.csv.
# Processing BEN.H...
# Profile data for BEN.H added to company_profiles.csv.
# Processing RAM...
# Profile data for RAM added to company_profiles.csv.
# Processing 7504...
# Profile data for 7504 added to company_profiles.csv.
# Processing HYPR...
# Profile data for HYPR added to company_profiles.csv.
# Processing XPCI11...
# Profile data for XPCI11 added to company_profiles.csv.
# Processing 5KD...
# Profile data for 5KD added to company_profiles.csv.
# Processing CHSN...
# Profile data for CHSN added to company_profiles.csv.
# Processing 6LQ...
# Profile data for 6LQ added to company_profiles.csv.
# Processing FRYA...
# Profile data for FRYA added to company_profiles.csv.
# Processing 300187...
# Profile data for 300187 added to company_profiles.csv.
# Processing ALWEC...
# Profile data for ALWEC added to company_profiles.csv.
# Processing 001339...
# Profile data for 001339 added to company_profiles.csv.
# Processing 83S2...
# Profile data for 83S2 added to company_profiles.csv.
# Processing CNPBP...
# Profile data for CNPBP added to company_profiles.csv.
# Processing SWUT...
# Profile data for SWUT added to company_profiles.csv.
# Processing GX6...
# Profile data for GX6 added to company_profiles.csv.
# Processing WO7...
# Profile data for WO7 added to company_profiles.csv.
# Processing 4MDT...
# Profile data for 4MDT added to company_profiles.csv.
# Processing YC2...
# Profile data for YC2 added to company_profiles.csv.
# Processing BTTX...
# Profile data for BTTX added to company_profiles.csv.
# Processing BBN...
# Profile data for BBN added to company_profiles.csv.
# Processing RFG...
# Profile data for RFG added to company_profiles.csv.
# Processing ENV...
# Profile data for ENV added to company_profiles.csv.
# Processing FPNUF...
# Profile data for FPNUF added to company_profiles.csv.
# Processing NYTTO...
# Profile data for NYTTO added to company_profiles.csv.
# Processing FLAP...
# Profile data for FLAP added to company_profiles.csv.
# Processing SAH...
# Profile data for SAH added to company_profiles.csv.
# Processing S94...
# Profile data for S94 added to company_profiles.csv.
# Processing MTNOY...
# Profile data for MTNOY added to company_profiles.csv.
# Processing IDAM...
# Profile data for IDAM added to company_profiles.csv.
# Processing DS3...
# Profile data for DS3 added to company_profiles.csv.
# Processing BWAQR...
# Profile data for BWAQR added to company_profiles.csv.
# Processing BBQ...
# Profile data for BBQ added to company_profiles.csv.
# Processing TL01...
# Profile data for TL01 added to company_profiles.csv.
# Processing BBH...
# Profile data for BBH added to company_profiles.csv.
# Processing CITZ...
# Profile data for CITZ added to company_profiles.csv.
# Processing K43...
# Profile data for K43 added to company_profiles.csv.
# Processing ZEEMEDIA...
# Profile data for ZEEMEDIA added to company_profiles.csv.
# Processing UC9A6Y...
# Profile data for UC9A6Y added to company_profiles.csv.
# Processing BBRYF...
# Profile data for BBRYF added to company_profiles.csv.
# Processing ALODC...
# Profile data for ALODC added to company_profiles.csv.
# Processing 1OXY...
# Profile data for 1OXY added to company_profiles.csv.
# Processing HTD...
# Profile data for HTD added to company_profiles.csv.
# Processing 4LMT...
# Profile data for 4LMT added to company_profiles.csv.
# Processing SMZ1...
# Profile data for SMZ1 added to company_profiles.csv.
# Processing NVG...
# Profile data for NVG added to company_profiles.csv.
# Processing P9N...
# Profile data for P9N added to company_profiles.csv.
# Processing FRD...
# Profile data for FRD added to company_profiles.csv.
# Processing HHU...
# Profile data for HHU added to company_profiles.csv.
# Processing 300669...
# Profile data for 300669 added to company_profiles.csv.
# Processing WHITF...
# Profile data for WHITF added to company_profiles.csv.
# Processing WDFCD...
# Profile data for WDFCD added to company_profiles.csv.
# Processing 1776...
# Profile data for 1776 added to company_profiles.csv.
# Processing 6V2...
# Profile data for 6V2 added to company_profiles.csv.
# Processing ORA...
# Profile data for ORA added to company_profiles.csv.
# Processing CCAP...
# Profile data for CCAP added to company_profiles.csv.
# Processing GFI...
# Profile data for GFI added to company_profiles.csv.
# Processing L7G...
# Profile data for L7G added to company_profiles.csv.
# Processing 6BE...
# Profile data for 6BE added to company_profiles.csv.
# Processing IOMT...
# Profile data for IOMT added to company_profiles.csv.
# Processing SOBA...
# Profile data for SOBA added to company_profiles.csv.
# Processing NPABW...
# Profile data for NPABW added to company_profiles.csv.
# Processing DA4B...
# Profile data for DA4B added to company_profiles.csv.
# Processing LRC...
# Profile data for LRC added to company_profiles.csv.
# Processing NVE...
# Profile data for NVE added to company_profiles.csv.
# Processing USX1...
# Profile data for USX1 added to company_profiles.csv.
# Processing HSZ...
# Profile data for HSZ added to company_profiles.csv.
# Processing ZAL...
# Profile data for ZAL added to company_profiles.csv.
# Processing KBC...
# Profile data for KBC added to company_profiles.csv.
# Processing AEDAS...
# Profile data for AEDAS added to company_profiles.csv.
# Processing 301468...
# Profile data for 301468 added to company_profiles.csv.
# Processing GSRI...
# Profile data for GSRI added to company_profiles.csv.
# Processing 15M1...
# Profile data for 15M1 added to company_profiles.csv.
# Processing OFED...
# Profile data for OFED added to company_profiles.csv.
# Processing DUK...
# Profile data for DUK added to company_profiles.csv.
# Processing 2QG...
# Profile data for 2QG added to company_profiles.csv.
# Processing SSOF...
# Profile data for SSOF added to company_profiles.csv.
# Processing 5Z7...
# Profile data for 5Z7 added to company_profiles.csv.
# Processing 061...
# Profile data for 061 added to company_profiles.csv.
# Processing RR5...
# Profile data for RR5 added to company_profiles.csv.
# Processing CGUN...
# Profile data for CGUN added to company_profiles.csv.
# Processing UPXI...
# Profile data for UPXI added to company_profiles.csv.
# Processing DMP...
# Profile data for DMP added to company_profiles.csv.
# Processing GB00BLDYK618...
# Profile data for GB00BLDYK618 added to company_profiles.csv.
# Processing RKM...
# Profile data for RKM added to company_profiles.csv.
# Processing OI2...
# Profile data for OI2 added to company_profiles.csv.
# Processing 4142...
# Profile data for 4142 added to company_profiles.csv.
# Processing EMYB...
# Profile data for EMYB added to company_profiles.csv.
# Processing AT0000A393Y1...
# Profile data for AT0000A393Y1 added to company_profiles.csv.
# Processing INVK...
# No profile data available for INVK or error in response.
# Processing MDD...
# Profile data for MDD added to company_profiles.csv.
# Processing 05B...
# Profile data for 05B added to company_profiles.csv.
# Processing 2760...
# Profile data for 2760 added to company_profiles.csv.
# Processing NTDOYN...
# Profile data for NTDOYN added to company_profiles.csv.
# Processing DWDE...
# Profile data for DWDE added to company_profiles.csv.
# Processing 4LRA...
# Profile data for 4LRA added to company_profiles.csv.
# Processing JP3206000006...
# Profile data for JP3206000006 added to company_profiles.csv.
# Processing 2769...
# Profile data for 2769 added to company_profiles.csv.
# Processing PP51...
# Profile data for PP51 added to company_profiles.csv.
# Processing MDG.B5...
# Profile data for MDG.B5 added to company_profiles.csv.
# Processing 688768...
# Profile data for 688768 added to company_profiles.csv.
# Processing 002945...
# Profile data for 002945 added to company_profiles.csv.
# Processing MOHCY...
# Profile data for MOHCY added to company_profiles.csv.
# Processing AHPA...
# Profile data for AHPA added to company_profiles.csv.
# Processing AJ91...
# Profile data for AJ91 added to company_profiles.csv.
# Processing 180400...
# Profile data for 180400 added to company_profiles.csv.
# Processing CVNA...
# Profile data for CVNA added to company_profiles.csv.
# Processing 1491...
# Profile data for 1491 added to company_profiles.csv.
# Processing COPH...
# Profile data for COPH added to company_profiles.csv.
# Processing SCM...
# Profile data for SCM added to company_profiles.csv.
# Processing UGDIF...
# Profile data for UGDIF added to company_profiles.csv.
# Processing 1UB...
# Profile data for 1UB added to company_profiles.csv.
# Processing MDM...
# Profile data for MDM added to company_profiles.csv.
# Processing 4E0...
# Profile data for 4E0 added to company_profiles.csv.
# Processing FR...
# Profile data for FR added to company_profiles.csv.
# Processing PEAS...
# Profile data for PEAS added to company_profiles.csv.
# Processing 4HPQ...
# Profile data for 4HPQ added to company_profiles.csv.
# Processing 002419...
# Profile data for 002419 added to company_profiles.csv.
# Processing 8WZ...
# Profile data for 8WZ added to company_profiles.csv.
# Processing BHP1...
# Profile data for BHP1 added to company_profiles.csv.
# Processing 0V1N...
# Profile data for 0V1N added to company_profiles.csv.
# Processing 3563...
# Profile data for 3563 added to company_profiles.csv.
# Processing 0JK4...
# Profile data for 0JK4 added to company_profiles.csv.
# Processing IWS...
# Profile data for IWS added to company_profiles.csv.
# Processing CENTUM...
# Profile data for CENTUM added to company_profiles.csv.
# Processing 9537...
# Profile data for 9537 added to company_profiles.csv.
# Processing H1ES34...
# Profile data for H1ES34 added to company_profiles.csv.
# Processing PRKAB...
# Profile data for PRKAB added to company_profiles.csv.
# Processing PKB...
# Profile data for PKB added to company_profiles.csv.
# Processing HUI...
# Profile data for HUI added to company_profiles.csv.
# Processing BAIEMKOAA...
# Profile data for BAIEMKOAA added to company_profiles.csv.
# Processing BDC...
# Profile data for BDC added to company_profiles.csv.
# Processing AKO1L...
# Profile data for AKO1L added to company_profiles.csv.
# Processing F12...
# Profile data for F12 added to company_profiles.csv.
# Processing ARRJ...
# Profile data for ARRJ added to company_profiles.csv.
# Processing XWEL...
# Profile data for XWEL added to company_profiles.csv.
# Processing SAN...
# Profile data for SAN added to company_profiles.csv.
# Processing 603288...
# Profile data for 603288 added to company_profiles.csv.
# Processing 8QJ...
# Profile data for 8QJ added to company_profiles.csv.
# Processing ALDBL...
# Profile data for ALDBL added to company_profiles.csv.
# Processing ACCA...
# Profile data for ACCA added to company_profiles.csv.
# Processing 44B...
# Profile data for 44B added to company_profiles.csv.
# Processing DUR...
# Profile data for DUR added to company_profiles.csv.
# Processing TNE5...
# Profile data for TNE5 added to company_profiles.csv.
# Processing MGS...
# Profile data for MGS added to company_profiles.csv.
# Processing VINAYAKPOL...
# Profile data for VINAYAKPOL added to company_profiles.csv.
# Processing TTNN...
# Profile data for TTNN added to company_profiles.csv.
# Processing XS2577518488...
# Profile data for XS2577518488 added to company_profiles.csv.
# Processing 6D40...
# Profile data for 6D40 added to company_profiles.csv.
# Processing VMR1...
# Profile data for VMR1 added to company_profiles.csv.
# Processing TGPRO...
# Profile data for TGPRO added to company_profiles.csv.
# Processing RSH...
# ...
# Processing BAZA3F...
# Profile data for BAZA3F added to company_profiles.csv.
# Processing 301360...
# Profile data for 301360 added to company_profiles.csv.
# Processing 210...
# Profile data for 210 added to company_profiles.csv.
# Processing ELECON...
# Profile data for ELECON added to company_profiles.csv.
# Processing IBKR...
# Profile data for IBKR added to company_profiles.csv.
# Processing 6788...
# Profile data for 6788 added to company_profiles.csv.
# Processing ATSK011PREM1...
# Profile data for ATSK011PREM1 added to company_profiles.csv.
# Processing CGEO...
# Profile data for CGEO added to company_profiles.csv.
# Processing 3O8...
# Profile data for 3O8 added to company_profiles.csv.
# Processing BANDHANBNK...
# Profile data for BANDHANBNK added to company_profiles.csv.
# Processing 6UP...
# Profile data for 6UP added to company_profiles.csv.
# Processing 49Y0...
# Profile data for 49Y0 added to company_profiles.csv.
# Processing 300664...
# Profile data for 300664 added to company_profiles.csv.
# Processing 1SPOT...
# Profile data for 1SPOT added to company_profiles.csv.
# Processing LNU...
# Profile data for LNU added to company_profiles.csv.
# Processing 6IV...
# Profile data for 6IV added to company_profiles.csv.
# Processing AROS.PR.REF.B...
# Profile data for AROS.PR.REF.B added to company_profiles.csv.
# Processing ZLDAF...
# Profile data for ZLDAF added to company_profiles.csv.
# Processing 3374...
# Profile data for 3374 added to company_profiles.csv.
# Processing ALPHALOGIC...
# Profile data for ALPHALOGIC added to company_profiles.csv.
# Processing IVU...
# Profile data for IVU added to company_profiles.csv.
# Processing TPS...
# Profile data for TPS added to company_profiles.csv.
# Processing RETZ...
# No profile data available for RETZ or error in response.
# Processing 5548...
# Profile data for 5548 added to company_profiles.csv.
# Processing 6805...
# Profile data for 6805 added to company_profiles.csv.
# Processing CRIV3F...
# Profile data for CRIV3F added to company_profiles.csv.
# Processing 3181...
# Profile data for 3181 added to company_profiles.csv.
# Processing 5LY...
# Profile data for 5LY added to company_profiles.csv.
# Processing 4070.SABE...
# Profile data for 4070.SABE added to company_profiles.csv.
# Processing HROW...
# Profile data for HROW added to company_profiles.csv.
# Processing MDRX...
# Profile data for MDRX added to company_profiles.csv.
# Processing 4BY...
# Profile data for 4BY added to company_profiles.csv.
# Processing 0VOO...
# Profile data for 0VOO added to company_profiles.csv.
# Processing MSSAW...
# Profile data for MSSAW added to company_profiles.csv.
# Processing VCC...
# Profile data for VCC added to company_profiles.csv.
# Processing X8D...
# Profile data for X8D added to company_profiles.csv.
# Processing VSSYW...
# Profile data for VSSYW added to company_profiles.csv.
# Processing HBB...
# Profile data for HBB added to company_profiles.csv.
# Processing EGO...
# Profile data for EGO added to company_profiles.csv.
# Processing AT0000A2H102...
# Profile data for AT0000A2H102 added to company_profiles.csv.
# Processing EWWCL...
# Profile data for EWWCL added to company_profiles.csv.
# Processing LSSB25.PR.RO...
# Profile data for LSSB25.PR.RO added to company_profiles.csv.
# Processing P8T...
# Profile data for P8T added to company_profiles.csv.
# Processing 300903...
# Profile data for 300903 added to company_profiles.csv.
# Processing GALACTICO...
# Profile data for GALACTICO added to company_profiles.csv.
# Processing BJ4...
# Profile data for BJ4 added to company_profiles.csv.
# Processing CORZQ...
# Profile data for CORZQ added to company_profiles.csv.
# Processing 301117...
# Profile data for 301117 added to company_profiles.csv.
# Processing AT0000A2KD30...
# Profile data for AT0000A2KD30 added to company_profiles.csv.
# Processing DNA2...
# Profile data for DNA2 added to company_profiles.csv.
# Processing 8493...
# Profile data for 8493 added to company_profiles.csv.
# Processing ETPHF...
# Profile data for ETPHF added to company_profiles.csv.
# Processing 2ZT0...
# Profile data for 2ZT0 added to company_profiles.csv.
# Processing RIVT...
# Profile data for RIVT added to company_profiles.csv.
# Processing TAKOF...
# Profile data for TAKOF added to company_profiles.csv.
# Processing 900904...
# Profile data for 900904 added to company_profiles.csv.
# Processing VIVANZA...
# Profile data for VIVANZA added to company_profiles.csv.
# Processing STM...
# Profile data for STM added to company_profiles.csv.
# Processing MJ8...
# Profile data for MJ8 added to company_profiles.csv.
# Processing 1I3...
# Profile data for 1I3 added to company_profiles.csv.
# Processing 0MTS...
# Profile data for 0MTS added to company_profiles.csv.
# Processing 1DK...
# Profile data for 1DK added to company_profiles.csv.
# Processing 32Z...
# Profile data for 32Z added to company_profiles.csv.
# Processing F42771...
# Profile data for F42771 added to company_profiles.csv.
# Processing 058028...
# Profile data for 058028 added to company_profiles.csv.
# Processing HITE...
# No profile data available for HITE or error in response.
# Processing MC8...
# Profile data for MC8 added to company_profiles.csv.
# Processing MIH...
# Profile data for MIH added to company_profiles.csv.
# Processing ADEVF...
# Profile data for ADEVF added to company_profiles.csv.
# Processing AVO...
# Profile data for AVO added to company_profiles.csv.
# Processing IRC...
# Profile data for IRC added to company_profiles.csv.
# Processing BRCA...
# Profile data for BRCA added to company_profiles.csv.
# Processing HJGP...
# Profile data for HJGP added to company_profiles.csv.
# Processing TRASTOR...
# Profile data for TRASTOR added to company_profiles.csv.
# Processing 1587...
# Profile data for 1587 added to company_profiles.csv.
# Processing 6392...
# Profile data for 6392 added to company_profiles.csv.
# Processing ENLV...
# Profile data for ENLV added to company_profiles.csv.
# Processing SIMAT...
# Profile data for SIMAT added to company_profiles.csv.
# Processing A17U...
# Profile data for A17U added to company_profiles.csv.
# Processing 263050...
# Profile data for 263050 added to company_profiles.csv.
# Processing 3031...
# Profile data for 3031 added to company_profiles.csv.
# Processing 6591...
# Profile data for 6591 added to company_profiles.csv.
# Processing 8370...
# Profile data for 8370 added to company_profiles.csv.
# Processing UTIP...
# Profile data for UTIP added to company_profiles.csv.
# Processing CHARAN...
# Profile data for CHARAN added to company_profiles.csv.
# Processing CZTA...
# Profile data for CZTA added to company_profiles.csv.
# Processing 709...
# Profile data for 709 added to company_profiles.csv.
# Processing SKIS.B...
# Profile data for SKIS.B added to company_profiles.csv.
# Processing SIAM.R...
# Profile data for SIAM.R added to company_profiles.csv.
# Processing 6725...
# Profile data for 6725 added to company_profiles.csv.
# Processing BUR...
# Profile data for BUR added to company_profiles.csv.
# Processing OXLCN...
# Profile data for OXLCN added to company_profiles.csv.
# Processing CKALF...
# Profile data for CKALF added to company_profiles.csv.
# Processing SII...
# Profile data for SII added to company_profiles.csv.
# Processing MFRVF...
# Profile data for MFRVF added to company_profiles.csv.
# Processing AABWL...
# Profile data for AABWL added to company_profiles.csv.
# Processing DHARFIN...
# Profile data for DHARFIN added to company_profiles.csv.
# Processing 1COST...
# Profile data for 1COST added to company_profiles.csv.
# Processing 286940...
# Profile data for 286940 added to company_profiles.csv.
# Processing P8W0...
# Profile data for P8W0 added to company_profiles.csv.
# Processing 1HOOD...
# Profile data for 1HOOD added to company_profiles.csv.
# Processing OCEL...
# Profile data for OCEL added to company_profiles.csv.
# Processing AB2...
# Profile data for AB2 added to company_profiles.csv.
# Processing G7A...
# Profile data for G7A added to company_profiles.csv.
# Processing BKE...
# Profile data for BKE added to company_profiles.csv.
# Processing 2120...
# Profile data for 2120 added to company_profiles.csv.
# Processing VICR...
# Profile data for VICR added to company_profiles.csv.
# Processing ZJS1...
# Profile data for ZJS1 added to company_profiles.csv.
# Processing M6X3...
# Profile data for M6X3 added to company_profiles.csv.
# Processing 708524...
# Profile data for 708524 added to company_profiles.csv.
# Processing JDCMF...
# Profile data for JDCMF added to company_profiles.csv.
# Processing AGYO...
# Profile data for AGYO added to company_profiles.csv.
# Processing HAIA...
# Profile data for HAIA added to company_profiles.csv.
# Processing 08D...
# Profile data for 08D added to company_profiles.csv.
# Processing 0LKC...
# Profile data for 0LKC added to company_profiles.csv.
# Processing OAR...
# Profile data for OAR added to company_profiles.csv.
# Processing 2N8...
# Profile data for 2N8 added to company_profiles.csv.
# Processing BSSC...
# Profile data for BSSC added to company_profiles.csv.
# Processing USY1...
# Profile data for USY1 added to company_profiles.csv.
# Processing PLTK...
# Profile data for PLTK added to company_profiles.csv.
# Processing BHSC...
# Profile data for BHSC added to company_profiles.csv.
# Processing UC2X14...
# Profile data for UC2X14 added to company_profiles.csv.
# Processing PHAL...
# Profile data for PHAL added to company_profiles.csv.
# Processing 1MS...
# Profile data for 1MS added to company_profiles.csv.
# Processing S5HE...
# Profile data for S5HE added to company_profiles.csv.
# Processing UD7C...
# Profile data for UD7C added to company_profiles.csv.
# Processing 215570...
# Profile data for 215570 added to company_profiles.csv.
# Processing REVE11...
# Profile data for REVE11 added to company_profiles.csv.
# Processing AT0000A2QK35...
# Profile data for AT0000A2QK35 added to company_profiles.csv.
# Processing WN30...
# Profile data for WN30 added to company_profiles.csv.
# Processing EPH...
# Profile data for EPH added to company_profiles.csv.
# Processing NVIVQ...
# Profile data for NVIVQ added to company_profiles.csv.
# Processing 6RV...
# Profile data for 6RV added to company_profiles.csv.
# Processing 710395...
# Profile data for 710395 added to company_profiles.csv.
# Processing FKKFY...
# Profile data for FKKFY added to company_profiles.csv.
# Processing DMXCF...
# Profile data for DMXCF added to company_profiles.csv.
# Processing 0NRE...
# Profile data for 0NRE added to company_profiles.csv.
# Processing 9393...
# Profile data for 9393 added to company_profiles.csv.
# Processing 3541...
# Profile data for 3541 added to company_profiles.csv.
# Processing 3161...
# Profile data for 3161 added to company_profiles.csv.
# Processing LX83...
# Profile data for LX83 added to company_profiles.csv.
# Processing 002261...
# Profile data for 002261 added to company_profiles.csv.
# Processing 512890...
# Profile data for 512890 added to company_profiles.csv.
# Processing 517200...
# Profile data for 517200 added to company_profiles.csv.
# Processing OPC...
# Profile data for OPC added to company_profiles.csv.
# Processing ULBI...
# Profile data for ULBI added to company_profiles.csv.
# Processing 1WR...
# Profile data for 1WR added to company_profiles.csv.
# Processing 1PM...
# Profile data for 1PM added to company_profiles.csv.
# Processing UGH...
# Profile data for UGH added to company_profiles.csv.
# Processing F23300...
# Profile data for F23300 added to company_profiles.csv.
# Processing CYL...
# Profile data for CYL added to company_profiles.csv.
# Processing CEEJAY...
# Profile data for CEEJAY added to company_profiles.csv.
# Processing TDSA...
# Profile data for TDSA added to company_profiles.csv.
# Processing 2011...
# Profile data for 2011 added to company_profiles.csv.
# Processing JGLCF...
# Profile data for JGLCF added to company_profiles.csv.
# Processing 6561...
# Profile data for 6561 added to company_profiles.csv.
# Processing 9509...
# Profile data for 9509 added to company_profiles.csv.
# Processing SMME...
# Profile data for SMME added to company_profiles.csv.
# Processing BCV...
# Profile data for BCV added to company_profiles.csv.
# Processing ASEKY...
# Profile data for ASEKY added to company_profiles.csv.
# Processing DUBA...
# Profile data for DUBA added to company_profiles.csv.
# Processing AMCI...
# Profile data for AMCI added to company_profiles.csv.
# Processing KOTAKBANK...
# Profile data for KOTAKBANK added to company_profiles.csv.
# Processing 5PZ...
# Profile data for 5PZ added to company_profiles.csv.
# Processing 513320...
# Profile data for 513320 added to company_profiles.csv.
# Processing LAMDA...
# Profile data for LAMDA added to company_profiles.csv.
# Processing 6457...
# Profile data for 6457 added to company_profiles.csv.
# Processing AVHIU...
# Profile data for AVHIU added to company_profiles.csv.
# Processing BBA...
# Profile data for BBA added to company_profiles.csv.
# Processing GLCO...
# Profile data for GLCO added to company_profiles.csv.
# Processing T4N...
# Profile data for T4N added to company_profiles.csv.
# Processing 6661...
# Profile data for 6661 added to company_profiles.csv.
# Processing AT0000A2FJQ2...
# Profile data for AT0000A2FJQ2 added to company_profiles.csv.
# Processing FPOA...
# No profile data available for FPOA or error in response.
# Processing 2615...
# Profile data for 2615 added to company_profiles.csv.
# Processing KDSKF...
# Profile data for KDSKF added to company_profiles.csv.
# Processing GY5...
# Profile data for GY5 added to company_profiles.csv.
# Processing HAY...
# Profile data for HAY added to company_profiles.csv.
# Processing 8303...
# Profile data for 8303 added to company_profiles.csv.
# Processing EIA...
# Profile data for EIA added to company_profiles.csv.
# Processing SANDHAR...
# Profile data for SANDHAR added to company_profiles.csv.
# Processing 3SZN...
# Profile data for 3SZN added to company_profiles.csv.
# Processing 7AZ...
# Profile data for 7AZ added to company_profiles.csv.
# Processing INDOTHAI...
# Profile data for INDOTHAI added to company_profiles.csv.
# Processing 1K0...
# Profile data for 1K0 added to company_profiles.csv.
# Processing AT0000A2SSV6...
# Profile data for AT0000A2SSV6 added to company_profiles.csv.
# Processing 250...
# Profile data for 250 added to company_profiles.csv.
# Processing 3356...
# Profile data for 3356 added to company_profiles.csv.
# Processing USG...
# Profile data for USG added to company_profiles.csv.
# Processing ABNB...
# Profile data for ABNB added to company_profiles.csv.
# Processing BITRF...
# Profile data for BITRF added to company_profiles.csv.
# Processing SB1...
# Profile data for SB1 added to company_profiles.csv.
# Processing GZIC...
# Profile data for GZIC added to company_profiles.csv.
# Processing ETHEREUM.XBT...
# Profile data for ETHEREUM.XBT added to company_profiles.csv.
# Processing TWSA...
# Profile data for TWSA added to company_profiles.csv.
# Processing SF7...
# Profile data for SF7 added to company_profiles.csv.
# Processing 603666...
# Profile data for 603666 added to company_profiles.csv.
# Processing VWEWW...
# Profile data for VWEWW added to company_profiles.csv.
# Processing 6037...
# Profile data for 6037 added to company_profiles.csv.
# Processing EPMT...
# Profile data for EPMT added to company_profiles.csv.
# Processing 7368...
# Profile data for 7368 added to company_profiles.csv.
# Processing TARMAT...
# Profile data for TARMAT added to company_profiles.csv.
# Processing POQ...
# Profile data for POQ added to company_profiles.csv.
# Processing D2AS34...
# Profile data for D2AS34 added to company_profiles.csv.
# Processing HGPO11...
# Profile data for HGPO11 added to company_profiles.csv.
# Processing POW...
# Profile data for POW added to company_profiles.csv.
# Processing 0RUJ...
# Profile data for 0RUJ added to company_profiles.csv.
# Processing NVAX...
# Profile data for NVAX added to company_profiles.csv.
# Processing 081580...
# Profile data for 081580 added to company_profiles.csv.
# Processing 711153...
# Profile data for 711153 added to company_profiles.csv.
# Processing WARRIX.R...
# Profile data for WARRIX.R added to company_profiles.csv.
# Processing 2172...
# Profile data for 2172 added to company_profiles.csv.
# Processing 510550...
# Profile data for 510550 added to company_profiles.csv.
# Processing 300832...
# Profile data for 300832 added to company_profiles.csv.
# Processing NS.PR.A...
# Profile data for NS.PR.A added to company_profiles.csv.
# Processing GVYM...
# Profile data for GVYM added to company_profiles.csv.
# Processing 1798...
# Profile data for 1798 added to company_profiles.csv.
# All requested profile data processed.
